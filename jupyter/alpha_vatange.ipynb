# %%
import pandas as pd
import numpy as np
import requests

# %%
api_key='aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'

# %%
symbol = 'AAPL'

# %%
def get_data(symbol):
    
    return requests.get(f'https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}').json()
        #f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={symbol}&outputsize=full&apikey={api_key}').json()

# %%
companies = []

# %%
tickers = ['F','GS']

# %%
for tick in tickers:
    res = get_data(tick)
    companies.append(pd.DataFrame(res['historical']).set_index('date'))

# %%
res = get_data('AAPL')['historical']

# %%
# (iDF[['close']].rename(columns={'close':'GS'}) for iDF in companies)
pd.concat(companies, axis=1, join='outer').head(1)
# Out:
#              open  high    low  close  adjClose      volume  unadjustedVolume  \
# date
# 2015-03-09  15.98  16.1  15.93  16.03     12.48  17132400.0        17132400.0
#
#             change  changePercent   vwap  ...     low   close  adjClose  \
# date                                      ...
# 2015-03-09   -0.05         -0.313  16.02  ...  186.57  187.93    175.86
#
#                volume  unadjustedVolume  change  changePercent       vwap  \
# date
# 2015-03-09  2233700.0         2233700.0   -0.63         -0.336  187.76333
#
#                    label  changeOverTime
# date
# 2015-03-09  March 09, 15        -0.00336
#
# [1 rows x 24 columns]

# %%
df1 =pd.DataFrame.from_dict(F,orient='index',columns=['close']).rename(columns={'close':'F'})

# %%
pd.DataFrame(get_data('GS')['historical']).set_index('date')
# Out:
#               open    high     low   close  adjClose      volume  \
# date
# 2015-03-09  127.96  129.57  125.06  127.14    117.63  88528500.0
# 2015-03-10  126.41  127.22  123.80  124.51    115.20  68856600.0
# 2015-03-11  124.75  124.77  122.11  122.24    113.10  68939000.0
# 2015-03-12  122.31  124.90  121.63  124.45    115.14  48362700.0
# 2015-03-13  124.40  125.40  122.58  123.59    114.35  51827300.0
# ...            ...     ...     ...     ...       ...         ...
# 2020-03-02  282.28  301.44  277.72  298.81    298.81  85349300.0
# 2020-03-03  303.67  304.00  285.80  289.32    289.32  79868900.0
# 2020-03-04  296.44  303.40  293.13  302.74    302.74  54794600.0
# 2020-03-05  295.52  299.55  291.41  292.92    292.92  46893200.0
# 2020-03-06  282.00  290.82  281.23  289.03    289.03  56491800.0
#
#             unadjustedVolume  change  changePercent       vwap         label  \
# date
# 2015-03-09        88528500.0    0.82          0.641  127.25667  March 09, 15
# 2015-03-10        68856600.0    1.90          1.503  125.17667  March 10, 15
# 2015-03-11        68939000.0    2.51          2.012  123.04000  March 11, 15
# 2015-03-12        48362700.0   -2.14         -1.750  123.66000  March 12, 15
# 2015-03-13        51827300.0    0.81          0.651  123.85667  March 13, 15
# ...                      ...     ...            ...        ...           ...
# 2020-03-02        85349300.0  -16.53         -5.856  292.65667  March 02, 20
# 2020-03-03        79868900.0   14.35          4.726  293.04000  March 03, 20
# 2020-03-04        54794600.0   -6.30         -2.125  299.75667  March 04, 20
# 2020-03-05        46893200.0    2.60          0.880  294.62667  March 05, 20
# 2020-03-06        56491800.0   -7.03         -2.493  287.02667  March 06, 20
#
#             changeOverTime
# date
# 2015-03-09         0.00641
# 2015-03-10         0.01503
# 2015-03-11         0.02012
# 2015-03-12        -0.01750
# 2015-03-13         0.00651
# ...                    ...
# 2020-03-02        -0.05856
# 2020-03-03         0.04726
# 2020-03-04        -0.02125
# 2020-03-05         0.00880
# 2020-03-06        -0.02493
#
# [1259 rows x 12 columns]

# %%
df2 =pd.DataFrame.from_dict(GS,orient='index',columns=['close']).rename(columns={'close':'GS'})

# %%
df1
# Out:
#                F
# 1972-06-01  2.25
# 1972-06-02  2.24
# 1972-06-05  2.24
# 1972-06-06  2.22
# 1972-06-07  2.21
# ...          ...
# 2020-02-27  6.97
# 2020-02-28  6.96
# 2020-03-02  7.20
# 2020-03-03  6.97
# 2020-03-04  7.08
#
# [12052 rows x 1 columns]

# %%
pd.DataFrame().join([df1,df2],how='outer').dropna( how='any')
# Out:
#                 F      GS
# 1999-05-04  36.68   70.38
# 1999-05-05  36.83   69.13
# 1999-05-06  35.76   67.94
# 1999-05-07  37.11   74.69
# 1999-05-10  36.65   70.50
# ...           ...     ...
# 2020-02-27   6.97  205.69
# 2020-02-28   6.96  200.77
# 2020-03-02   7.20  209.47
# 2020-03-03   6.97  203.43
# 2020-03-04   7.08  208.74
#
# [5244 rows x 2 columns]

# %%
requests.get(f'https://api.worldtradingdata.com/api/v1/ticker_list?type=stocks&api_token=aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy').json()
# Out:
# {'message': 'You have reached your request limit for the day. Upgrade to get more daily requests.'}

# %%
get_symbol = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={symbol}&apikey={api_key}'

# %%
res = requests.get(get_stock).json()

# %%
requests.get(f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={api_key}').json();

# %%
requests.get(get_symbol).json();

# %%
from datetime import date, datetime
import time
from enum import Enum

class Urls(Enum):
    STOCK_PRICE = 'https://financialmodelingprep.com/api/v3/historical-price-full'
    VOLUME_PRICE = 'https://financialmodelingprep.com/api/v3/volume-price-full'
    API_KEY = 'aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'
    
def url(ticker):
    from_date = time.mktime(datetime(2005, 1, 1).timetuple())
    to_date = time.mktime(datetime.now().timetuple())
    print(from_date)
    print(to_date)
    return f'https://api.worldtradingdata.com/api/v1/history?symbol={ticker}&api_token={Urls.API_KEY.value}'
#     return f'https://finnhub.io/api/v1/stock/candle?symbol={ticker}&resolution=1&from={from_date}&to={to_date}&token={Urls.API_KEY.value}'
#'https://finnhub.io/api/v1/stock/candle?symbol=AAPL&resolution=1&from=04537600.0&to=1572910590&token=bpi2rsvrh5rbgl0l7vv0').json()

# %%
x = url('GS')
# Out:
# 1104537600.0
# 1583625841.0

# %%
x
# Out:
# 'https://api.worldtradingdata.com/api/v1/history?symbol=GS&api_token=aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'

# %%
import requests

z = requests.get(x).json()

# %%
import pandas as pd
df= pd.DataFrame.from_dict(z['history'], orient='index')

# %%
# Out:
# {'2020-03-06': {'open': '190.68',
#   'close': '192.85',
#   'high': '196.30',
#   'low': '189.28',
#   'volume': '5071909'},
#  '2020-03-05': {'open': '201.33',
#   'close': '198.79',
#   'high': '203.47',
#   'low': '196.95',
#   'volume': '4151707'},
#  '2020-03-04': {'open': '205.84',
#   'close': '208.74',
#   'high': '208.92',
#   'low': '202.70',
#   'volume': '3520352'},
#  '2020-03-03': {'open': '209.00',
#   'close': '203.43',
#   'high': '211.79',
#   'low': '202.12',
#   'volume': '5677200'},
#  '2020-03-02': {'open': '201.41',
#   'close': '209.47',
#   'high': '209.62',
#   'low': '197.63',
#   'volume': '5285526'},
#  '2020-02-28': {'open': '199.09',
#   'close': '200.77',
#   'high': '202.25',
#   'low': '194.85',
#   'volume': '6740665'},
#  '2020-02-27': {'open': '210.49',
#   'close': '205.69',
#   'high': '213.48',
#   'low': '205.37',
#   'volume': '5848188'},
#  '2020-02-26': {'open': '218.70',
#   'close': '215.78',
#   'high': '220.00',
#   'low': '214.76',
#   'volume': '4172156'},
#  '2020-02-25': {'open': '224.78',
#   'close': '217.61',
#   'high': '225.87',
#   'low': '215.89',
#   'volume': '5343512'},
#  '2020-02-24': {'open': '223.23',
#   'close': '224.54',
#   'high': '226.69',
#   'low': '222.54',
#   'volume': '4139814'},
#  '2020-02-21': {'open': '230.91',
#   'close': '230.62',
#   'high': '231.80',
#   'low': '228.37',
#   'volume': '3082273'},
#  '2020-02-20': {'open': '236.41',
#   'close': '232.73',
#   'high': '236.90',
#   'low': '231.25',
#   'volume': '3183748'},
#  '2020-02-19': {'open': '235.00',
#   'close': '237.33',
#   'high': '237.80',
#   'low': '233.28',
#   'volume': '2207061'},
#  '2020-02-18': {'open': '236.55',
#   'close': '233.21',
#   'high': '237.07',
#   'low': '231.20',
#   'volume': '2737383'},
#  '2020-02-14': {'open': '237.94',
#   'close': '237.08',
#   'high': '239.01',
#   'low': '236.23',
#   'volume': '1718742'},
#  '2020-02-13': {'open': '237.85',
#   'close': '238.35',
#   'high': '238.97',
#   'low': '236.57',
#   'volume': '1461372'},
#  '2020-02-12': {'open': '238.01',
#   'close': '238.65',
#   'high': '241.18',
#   'low': '237.72',
#   'volume': '2119549'},
#  '2020-02-11': {'open': '239.00',
#   'close': '236.46',
#   'high': '239.55',
#   'low': '236.22',
#   'volume': '2238902'},
#  '2020-02-10': {'open': '237.40',
#   'close': '237.36',
#   'high': '237.87',
#   'low': '235.46',
#   'volume': '2591280'},
#  '2020-02-07': {'open': '239.75',
#   'close': '238.00',
#   'high': '240.52',
#   'low': '236.55',
#   'volume': '3006894'},
#  '2020-02-06': {'open': '245.35',
#   'close': '241.82',
#   'high': '245.77',
#   'low': '241.18',
#   'volume': '2225886'},
#  '2020-02-05': {'open': '244.99',
#   'close': '244.30',
#   'high': '245.13',
#   'low': '243.00',
#   'volume': '3126622'},
#  '2020-02-04': {'open': '242.88',
#   'close': '241.94',
#   'high': '243.74',
#   'low': '241.55',
#   'volume': '3052654'},
#  '2020-02-03': {'open': '238.36',
#   'close': '239.01',
#   'high': '242.39',
#   'low': '238.05',
#   'volume': '2733171'},
#  '2020-01-31': {'open': '241.99',
#   'close': '237.75',
#   'high': '242.89',
#   'low': '236.88',
#   'volume': '3482838'},
#  '2020-01-30': {'open': '237.69',
#   'close': '244.13',
#   'high': '244.34',
#   'low': '236.73',
#   'volume': '3261733'},
#  '2020-01-29': {'open': '244.52',
#   'close': '240.12',
#   'high': '246.50',
#   'low': '239.57',
#   'volume': '3713664'},
#  '2020-01-28': {'open': '239.49',
#   'close': '242.58',
#   'high': '243.58',
#   'low': '238.05',
#   'volume': '3123389'},
#  '2020-01-27': {'open': '236.37',
#   'close': '238.14',
#   'high': '238.99',
#   'low': '235.01',
#   'volume': '2506445'},
#  '2020-01-24': {'open': '245.07',
#   'close': '241.92',
#   'high': '245.71',
#   'low': '240.60',
#   'volume': '2877351'},
#  '2020-01-23': {'open': '244.50',
#   'close': '245.58',
#   'high': '247.00',
#   'low': '242.88',
#   'volume': '2806820'},
#  '2020-01-22': {'open': '246.61',
#   'close': '247.05',
#   'high': '248.52',
#   'low': '246.34',
#   'volume': '2031016'},
#  '2020-01-21': {'open': '247.21',
#   'close': '245.70',
#   'high': '248.85',
#   'low': '245.60',
#   'volume': '2492363'},
#  '2020-01-17': {'open': '250.23',
#   'close': '249.46',
#   'high': '250.46',
#   'low': '248.00',
#   'volume': '3108371'},
#  '2020-01-16': {'open': '247.01',
#   'close': '249.72',
#   'high': '249.82',
#   'low': '246.23',
#   'volume': '3968405'},
#  '2020-01-15': {'open': '242.00',
#   'close': '245.21',
#   'high': '249.50',
#   'low': '239.16',
#   'volume': '5411198'},
#  '2020-01-14': {'open': '245.32',
#   'close': '245.66',
#   'high': '248.52',
#   'low': '244.60',
#   'volume': '4309141'},
#  '2020-01-13': {'open': '244.44',
#   'close': '245.21',
#   'high': '246.11',
#   'low': '243.00',
#   'volume': '3321364'},
#  '2020-01-10': {'open': '242.75',
#   'close': '242.11',
#   'high': '243.39',
#   'low': '241.39',
#   'volume': '2249212'},
#  '2020-01-09': {'open': '241.34',
#   'close': '242.60',
#   'high': '243.40',
#   'low': '239.82',
#   'volume': '3982130'},
#  '2020-01-08': {'open': '235.68',
#   'close': '237.76',
#   'high': '239.75',
#   'low': '235.48',
#   'volume': '3564884'},
#  '2020-01-07': {'open': '235.00',
#   'close': '235.49',
#   'high': '237.77',
#   'low': '234.76',
#   'volume': '5393171'},
#  '2020-01-06': {'open': '229.93',
#   'close': '233.95',
#   'high': '234.02',
#   'low': '229.49',
#   'volume': '3329354'},
#  '2020-01-03': {'open': '231.60',
#   'close': '231.58',
#   'high': '232.61',
#   'low': '230.30',
#   'volume': '2276089'},
#  '2020-01-02': {'open': '231.00',
#   'close': '234.32',
#   'high': '234.64',
#   'low': '230.16',
#   'volume': '3737791'},
#  '2019-12-31': {'open': '229.71',
#   'close': '229.93',
#   'high': '229.97',
#   'low': '228.67',
#   'volume': '1447336'},
#  '2019-12-30': {'open': '231.68',
#   'close': '229.80',
#   'high': '231.68',
#   'low': '229.50',
#   'volume': '1494667'},
#  '2019-12-27': {'open': '231.81',
#   'close': '230.66',
#   'high': '232.21',
#   'low': '230.47',
#   'volume': '1343887'},
#  '2019-12-26': {'open': '230.26',
#   'close': '231.21',
#   'high': '232.20',
#   'low': '229.99',
#   'volume': '1704161'},
#  '2019-12-24': {'open': '228.98',
#   'close': '229.91',
#   'high': '229.95',
#   'low': '228.37',
#   'volume': '467722'},
#  '2019-12-23': {'open': '229.66',
#   'close': '229.09',
#   'high': '230.48',
#   'low': '228.41',
#   'volume': '1671705'},
#  '2019-12-20': {'open': '230.96',
#   'close': '228.93',
#   'high': '231.29',
#   'low': '228.62',
#   'volume': '3716158'},
#  '2019-12-19': {'open': '230.95',
#   'close': '229.94',
#   'high': '231.39',
#   'low': '228.96',
#   'volume': '2420063'},
#  '2019-12-18': {'open': '231.97',
#   'close': '230.45',
#   'high': '232.20',
#   'low': '229.94',
#   'volume': '2280912'},
#  '2019-12-17': {'open': '230.00',
#   'close': '231.15',
#   'high': '232.07',
#   'low': '228.80',
#   'volume': '3590439'},
#  '2019-12-16': {'open': '228.50',
#   'close': '228.04',
#   'high': '230.70',
#   'low': '227.87',
#   'volume': '3219426'},
#  '2019-12-13': {'open': '226.72',
#   'close': '225.00',
#   'high': '227.99',
#   'low': '223.70',
#   'volume': '1908510'},
#  '2019-12-12': {'open': '221.91',
#   'close': '226.05',
#   'high': '226.78',
#   'low': '220.60',
#   'volume': '2975577'},
#  '2019-12-11': {'open': '222.25',
#   'close': '221.19',
#   'high': '222.85',
#   'low': '220.84',
#   'volume': '1778596'},
#  '2019-12-10': {'open': '221.67',
#   'close': '221.88',
#   'high': '222.88',
#   'low': '220.55',
#   'volume': '1854483'},
#  '2019-12-09': {'open': '224.61',
#   'close': '221.81',
#   'high': '224.65',
#   'low': '221.77',
#   'volume': '2149451'},
#  '2019-12-06': {'open': '219.95',
#   'close': '224.61',
#   'high': '225.40',
#   'low': '218.82',
#   'volume': '4229733'},
#  '2019-12-05': {'open': '217.15',
#   'close': '217.14',
#   'high': '217.63',
#   'low': '215.42',
#   'volume': '1329572'},
#  '2019-12-04': {'open': '213.54',
#   'close': '215.94',
#   'high': '216.99',
#   'low': '212.38',
#   'volume': '1583647'},
#  '2019-12-03': {'open': '215.43',
#   'close': '212.24',
#   'high': '215.43',
#   'low': '210.00',
#   'volume': '3279762'},
#  '2019-12-02': {'open': '220.97',
#   'close': '217.64',
#   'high': '221.80',
#   'low': '217.08',
#   'volume': '2119133'},
#  '2019-11-29': {'open': '220.88',
#   'close': '221.35',
#   'high': '222.00',
#   'low': '220.41',
#   'volume': '770438'},
#  '2019-11-27': {'open': '223.45',
#   'close': '222.95',
#   'high': '224.28',
#   'low': '221.86',
#   'volume': '1615085'},
#  '2019-11-26': {'open': '222.68',
#   'close': '222.45',
#   'high': '222.76',
#   'low': '221.11',
#   'volume': '1926961'},
#  '2019-11-25': {'open': '220.89',
#   'close': '222.75',
#   'high': '223.95',
#   'low': '220.89',
#   'volume': '2181836'},
#  '2019-11-22': {'open': '218.00',
#   'close': '220.28',
#   'high': '220.71',
#   'low': '218.00',
#   'volume': '1529121'},
#  '2019-11-21': {'open': '218.60',
#   'close': '218.23',
#   'high': '219.32',
#   'low': '216.82',
#   'volume': '1677745'},
#  '2019-11-20': {'open': '218.36',
#   'close': '217.91',
#   'high': '219.47',
#   'low': '216.40',
#   'volume': '2177738'},
#  '2019-11-19': {'open': '220.56',
#   'close': '220.04',
#   'high': '220.68',
#   'low': '218.31',
#   'volume': '1817120'},
#  '2019-11-18': {'open': '219.73',
#   'close': '219.73',
#   'high': '219.95',
#   'low': '218.04',
#   'volume': '1603539'},
#  '2019-11-15': {'open': '220.00',
#   'close': '220.25',
#   'high': '221.09',
#   'low': '219.04',
#   'volume': '1693160'},
#  '2019-11-14': {'open': '218.79',
#   'close': '219.43',
#   'high': '220.47',
#   'low': '218.03',
#   'volume': '1483216'},
#  '2019-11-13': {'open': '218.39',
#   'close': '219.32',
#   'high': '219.84',
#   'low': '217.01',
#   'volume': '1769133'},
#  '2019-11-12': {'open': '218.56',
#   'close': '220.41',
#   'high': '221.11',
#   'low': '217.93',
#   'volume': '1891598'},
#  '2019-11-11': {'open': '220.90',
#   'close': '219.03',
#   'high': '221.41',
#   'low': '218.52',
#   'volume': '2755038'},
#  '2019-11-08': {'open': '223.00',
#   'close': '222.91',
#   'high': '223.23',
#   'low': '221.10',
#   'volume': '1610873'},
#  '2019-11-07': {'open': '220.77',
#   'close': '223.29',
#   'high': '224.77',
#   'low': '220.41',
#   'volume': '3748660'},
#  '2019-11-06': {'open': '218.01',
#   'close': '218.42',
#   'high': '219.07',
#   'low': '216.55',
#   'volume': '1863038'},
#  '2019-11-05': {'open': '220.80',
#   'close': '218.64',
#   'high': '221.78',
#   'low': '218.47',
#   'volume': '2525109'},
#  '2019-11-04': {'open': '219.70',
#   'close': '219.87',
#   'high': '220.69',
#   'low': '218.57',
#   'volume': '2538122'},
#  '2019-11-01': {'open': '215.26',
#   'close': '217.39',
#   'high': '217.89',
#   'low': '214.75',
#   'volume': '2112310'},
#  '2019-10-31': {'open': '215.15',
#   'close': '213.38',
#   'high': '215.36',
#   'low': '211.32',
#   'volume': '1876214'},
#  '2019-10-30': {'open': '217.02',
#   'close': '215.81',
#   'high': '217.05',
#   'low': '213.81',
#   'volume': '1584888'},
#  '2019-10-29': {'open': '217.22',
#   'close': '217.64',
#   'high': '219.28',
#   'low': '216.45',
#   'volume': '2030786'},
#  '2019-10-28': {'open': '216.32',
#   'close': '217.75',
#   'high': '218.92',
#   'low': '215.69',
#   'volume': '2707775'},
#  '2019-10-25': {'open': '210.18',
#   'close': '214.23',
#   'high': '215.42',
#   'low': '210.18',
#   'volume': '2602050'},
#  '2019-10-24': {'open': '211.61',
#   'close': '211.05',
#   'high': '213.15',
#   'low': '209.78',
#   'volume': '1273179'},
#  '2019-10-23': {'open': '209.22',
#   'close': '211.32',
#   'high': '212.02',
#   'low': '209.00',
#   'volume': '1583225'},
#  '2019-10-22': {'open': '209.59',
#   'close': '209.60',
#   'high': '211.65',
#   'low': '208.31',
#   'volume': '1885431'},
#  '2019-10-21': {'open': '208.67',
#   'close': '209.25',
#   'high': '210.86',
#   'low': '207.68',
#   'volume': '1958379'},
#  '2019-10-18': {'open': '204.99',
#   'close': '206.52',
#   'high': '208.06',
#   'low': '204.99',
#   'volume': '2207607'},
#  '2019-10-17': {'open': '208.29',
#   'close': '206.46',
#   'high': '208.93',
#   'low': '204.39',
#   'volume': '2893459'},
#  '2019-10-16': {'open': '206.17',
#   'close': '207.42',
#   'high': '208.62',
#   'low': '206.10',
#   'volume': '3447187'},
#  '2019-10-15': {'open': '202.00',
#   'close': '206.46',
#   'high': '208.24',
#   'low': '198.61',
#   'volume': '8303263'},
#  '2019-10-14': {'open': '203.83',
#   'close': '205.82',
#   'high': '206.17',
#   'low': '202.92',
#   'volume': '2303649'},
#  '2019-10-11': {'open': '203.72',
#   'close': '204.68',
#   'high': '207.29',
#   'low': '203.72',
#   'volume': '3342623'},
#  '2019-10-10': {'open': '197.59',
#   'close': '199.87',
#   'high': '201.32',
#   'low': '197.54',
#   'volume': '2114131'},
#  '2019-10-09': {'open': '198.19',
#   'close': '196.85',
#   'high': '198.98',
#   'low': '196.68',
#   'volume': '2457007'},
#  '2019-10-08': {'open': '197.60',
#   'close': '197.37',
#   'high': '198.95',
#   'low': '195.92',
#   'volume': '2674425'},
#  '2019-10-07': {'open': '200.79',
#   'close': '200.40',
#   'high': '202.53',
#   'low': '199.47',
#   'volume': '2210318'},
#  '2019-10-04': {'open': '196.99',
#   'close': '200.80',
#   'high': '201.23',
#   'low': '196.04',
#   'volume': '3028781'},
#  '2019-10-03': {'open': '197.61',
#   'close': '197.24',
#   'high': '198.37',
#   'low': '193.99',
#   'volume': '2923698'},
#  '2019-10-02': {'open': '201.69',
#   'close': '198.25',
#   'high': '201.88',
#   'low': '197.60',
#   'volume': '3395299'},
#  '2019-10-01': {'open': '207.01',
#   'close': '202.69',
#   'high': '209.38',
#   'low': '202.61',
#   'volume': '3171507'},
#  '2019-09-30': {'open': '209.71',
#   'close': '207.23',
#   'high': '209.71',
#   'low': '206.83',
#   'volume': '1798010'},
#  '2019-09-27': {'open': '209.85',
#   'close': '208.97',
#   'high': '210.55',
#   'low': '208.09',
#   'volume': '1531374'},
#  '2019-09-26': {'open': '209.05',
#   'close': '208.22',
#   'high': '209.97',
#   'low': '208.11',
#   'volume': '1692716'},
#  '2019-09-25': {'open': '207.96',
#   'close': '210.03',
#   'high': '211.09',
#   'low': '207.45',
#   'volume': '1609841'},
#  '2019-09-24': {'open': '214.04',
#   'close': '207.75',
#   'high': '214.20',
#   'low': '206.80',
#   'volume': '2885686'},
#  '2019-09-23': {'open': '212.85',
#   'close': '213.46',
#   'high': '214.11',
#   'low': '211.56',
#   'volume': '1565762'},
#  '2019-09-20': {'open': '214.66',
#   'close': '213.74',
#   'high': '216.68',
#   'low': '213.63',
#   'volume': '5490118'},
#  '2019-09-19': {'open': '217.58',
#   'close': '215.23',
#   'high': '217.93',
#   'low': '215.06',
#   'volume': '1611076'},
#  '2019-09-18': {'open': '214.83',
#   'close': '217.08',
#   'high': '217.89',
#   'low': '213.30',
#   'volume': '2492485'},
#  '2019-09-17': {'open': '215.80',
#   'close': '215.91',
#   'high': '216.14',
#   'low': '212.54',
#   'volume': '2467394'},
#  '2019-09-16': {'open': '217.82',
#   'close': '217.22',
#   'high': '219.33',
#   'low': '216.32',
#   'volume': '2205543'},
#  '2019-09-13': {'open': '220.35',
#   'close': '219.90',
#   'high': '221.50',
#   'low': '219.20',
#   'volume': '2722411'},
#  '2019-09-12': {'open': '216.38',
#   'close': '218.74',
#   'high': '220.76',
#   'low': '215.15',
#   'volume': '2913786'},
#  '2019-09-11': {'open': '215.21',
#   'close': '216.80',
#   'high': '216.85',
#   'low': '213.36',
#   'volume': '1886291'},
#  '2019-09-10': {'open': '213.50',
#   'close': '215.63',
#   'high': '217.09',
#   'low': '213.22',
#   'volume': '2616235'},
#  '2019-09-09': {'open': '209.22',
#   'close': '211.98',
#   'high': '213.88',
#   'low': '208.44',
#   'volume': '2734609'},
#  '2019-09-06': {'open': '207.06',
#   'close': '207.21',
#   'high': '208.25',
#   'low': '205.57',
#   'volume': '1439087'},
#  '2019-09-05': {'open': '205.27',
#   'close': '207.05',
#   'high': '208.93',
#   'low': '205.04',
#   'volume': '2237906'},
#  '2019-09-04': {'open': '201.49',
#   'close': '201.73',
#   'high': '202.10',
#   'low': '200.05',
#   'volume': '1736967'},
#  '2019-09-03': {'open': '201.10',
#   'close': '198.97',
#   'high': '201.61',
#   'low': '196.58',
#   'volume': '2633970'},
#  '2019-08-30': {'open': '204.85',
#   'close': '203.91',
#   'high': '205.21',
#   'low': '203.01',
#   'volume': '1529629'},
#  '2019-08-29': {'open': '201.36',
#   'close': '203.44',
#   'high': '204.37',
#   'low': '201.36',
#   'volume': '1817824'},
#  '2019-08-28': {'open': '196.57',
#   'close': '200.42',
#   'high': '201.47',
#   'low': '196.25',
#   'volume': '1444021'},
#  '2019-08-27': {'open': '200.33',
#   'close': '198.07',
#   'high': '200.86',
#   'low': '196.50',
#   'volume': '1513448'},
#  '2019-08-26': {'open': '198.27',
#   'close': '199.65',
#   'high': '199.71',
#   'low': '198.00',
#   'volume': '1442394'},
#  '2019-08-23': {'open': '200.81',
#   'close': '196.20',
#   'high': '201.88',
#   'low': '195.19',
#   'volume': '2201526'},
#  '2019-08-22': {'open': '202.28',
#   'close': '202.42',
#   'high': '203.45',
#   'low': '200.91',
#   'volume': '1276379'},
#  '2019-08-21': {'open': '202.74',
#   'close': '200.68',
#   'high': '203.02',
#   'low': '200.17',
#   'volume': '1161185'},
#  '2019-08-20': {'open': '200.21',
#   'close': '199.98',
#   'high': '201.99',
#   'low': '199.70',
#   'volume': '1545894'},
#  '2019-08-19': {'open': '203.81',
#   'close': '202.20',
#   'high': '204.45',
#   'low': '201.82',
#   'volume': '1646082'},
#  '2019-08-16': {'open': '197.03',
#   'close': '199.42',
#   'high': '200.67',
#   'low': '197.00',
#   'volume': '1878739'},
#  '2019-08-15': {'open': '195.91',
#   'close': '196.18',
#   'high': '196.97',
#   'low': '193.71',
#   'volume': '1981913'},
#  '2019-08-14': {'open': '199.80',
#   'close': '195.56',
#   'high': '199.91',
#   'low': '195.06',
#   'volume': '3025103'},
#  '2019-08-13': {'open': '201.51',
#   'close': '204.11',
#   'high': '206.60',
#   'low': '200.23',
#   'volume': '2157671'},
#  '2019-08-12': {'open': '203.28',
#   'close': '201.52',
#   'high': '204.15',
#   'low': '200.48',
#   'volume': '1479335'},
#  '2019-08-09': {'open': '205.62',
#   'close': '206.90',
#   'high': '208.30',
#   'low': '203.86',
#   'volume': '1790148'},
#  '2019-08-08': {'open': '207.17',
#   'close': '207.00',
#   'high': '207.80',
#   'low': '203.54',
#   'volume': '2342226'},
#  '2019-08-07': {'open': '201.11',
#   'close': '205.74',
#   'high': '205.96',
#   'low': '199.05',
#   'volume': '2454249'},
#  '2019-08-06': {'open': '203.56',
#   'close': '206.01',
#   'high': '206.07',
#   'low': '200.89',
#   'volume': '2349383'},
#  '2019-08-05': {'open': '205.82',
#   'close': '201.68',
#   'high': '205.82',
#   'low': '199.58',
#   'volume': '2794194'},
#  '2019-08-02': {'open': '211.58',
#   'close': '209.37',
#   'high': '211.58',
#   'low': '205.31',
#   'volume': '2502996'},
#  '2019-08-01': {'open': '219.35',
#   'close': '211.60',
#   'high': '219.95',
#   'low': '210.76',
#   'volume': '3070149'},
#  '2019-07-31': {'open': '221.24',
#   'close': '220.13',
#   'high': '221.98',
#   'low': '219.01',
#   'volume': '1991056'},
#  '2019-07-30': {'open': '218.49',
#   'close': '221.40',
#   'high': '221.99',
#   'low': '217.33',
#   'volume': '1644552'},
#  '2019-07-29': {'open': '221.00',
#   'close': '220.32',
#   'high': '222.13',
#   'low': '220.20',
#   'volume': '1372767'},
#  '2019-07-26': {'open': '220.45',
#   'close': '222.14',
#   'high': '222.24',
#   'low': '220.37',
#   'volume': '2304848'},
#  '2019-07-25': {'open': '221.77',
#   'close': '219.98',
#   'high': '221.77',
#   'low': '218.23',
#   'volume': '2777134'},
#  '2019-07-24': {'open': '219.25',
#   'close': '222.03',
#   'high': '222.09',
#   'low': '218.63',
#   'volume': '3180106'},
#  '2019-07-23': {'open': '214.95',
#   'close': '219.43',
#   'high': '220.00',
#   'low': '214.95',
#   'volume': '3330637'},
#  '2019-07-22': {'open': '213.40',
#   'close': '214.00',
#   'high': '214.86',
#   'low': '212.31',
#   'volume': '1907237'},
#  '2019-07-19': {'open': '214.02',
#   'close': '213.52',
#   'high': '215.77',
#   'low': '213.35',
#   'volume': '1822284'},
#  '2019-07-18': {'open': '212.71',
#   'close': '214.52',
#   'high': '215.83',
#   'low': '211.75',
#   'volume': '2858986'},
#  '2019-07-17': {'open': '213.83',
#   'close': '213.30',
#   'high': '215.78',
#   'low': '213.16',
#   'volume': '2583462'},
#  '2019-07-16': {'open': '214.80',
#   'close': '215.52',
#   'high': '217.33',
#   'low': '212.55',
#   'volume': '5283690'},
#  '2019-07-15': {'open': '214.11',
#   'close': '211.58',
#   'high': '214.60',
#   'low': '209.79',
#   'volume': '2600222'},
#  '2019-07-12': {'open': '212.00',
#   'close': '213.94',
#   'high': '214.19',
#   'low': '210.79',
#   'volume': '2626026'},
#  '2019-07-11': {'open': '206.20',
#   'close': '211.35',
#   'high': '212.59',
#   'low': '206.00',
#   'volume': '3691619'},
#  '2019-07-10': {'open': '207.18',
#   'close': '205.97',
#   'high': '208.99',
#   'low': '205.65',
#   'volume': '1779844'},
#  '2019-07-09': {'open': '203.75',
#   'close': '207.77',
#   'high': '207.94',
#   'low': '203.54',
#   'volume': '1812186'},
#  '2019-07-08': {'open': '206.36',
#   'close': '205.75',
#   'high': '207.25',
#   'low': '204.71',
#   'volume': '1853938'},
#  '2019-07-05': {'open': '206.86',
#   'close': '207.90',
#   'high': '208.76',
#   'low': '206.20',
#   'volume': '1511445'},
#  '2019-07-03': {'open': '207.30',
#   'close': '206.04',
#   'high': '207.40',
#   'low': '205.23',
#   'volume': '978795'},
#  '2019-07-02': {'open': '205.40',
#   'close': '205.98',
#   'high': '206.31',
#   'low': '204.16',
#   'volume': '1626880'},
#  '2019-07-01': {'open': '208.00',
#   'close': '206.86',
#   'high': '209.85',
#   'low': '205.74',
#   'volume': '2468489'},
#  '2019-06-28': {'open': '203.50',
#   'close': '204.60',
#   'high': '205.84',
#   'low': '202.94',
#   'volume': '4854919'},
#  '2019-06-27': {'open': '197.57',
#   'close': '199.32',
#   'high': '199.61',
#   'low': '196.76',
#   'volume': '2239186'},
#  '2019-06-26': {'open': '196.50',
#   'close': '197.01',
#   'high': '197.87',
#   'low': '196.12',
#   'volume': '1649866'},
#  '2019-06-25': {'open': '197.50',
#   'close': '196.06',
#   'high': '197.52',
#   'low': '194.01',
#   'volume': '1828309'},
#  '2019-06-24': {'open': '196.53',
#   'close': '197.49',
#   'high': '199.35',
#   'low': '196.03',
#   'volume': '2069816'},
#  '2019-06-21': {'open': '195.34',
#   'close': '195.94',
#   'high': '198.34',
#   'low': '193.97',
#   'volume': '3365504'},
#  '2019-06-20': {'open': '197.50',
#   'close': '195.70',
#   'high': '198.19',
#   'low': '193.61',
#   'volume': '2749296'},
#  '2019-06-19': {'open': '195.35',
#   'close': '195.64',
#   'high': '197.61',
#   'low': '194.79',
#   'volume': '2196816'},
#  '2019-06-18': {'open': '190.67',
#   'close': '194.98',
#   'high': '197.13',
#   'low': '190.67',
#   'volume': '2362978'},
#  '2019-06-17': {'open': '192.02',
#   'close': '190.83',
#   'high': '193.23',
#   'low': '190.74',
#   'volume': '1155579'},
#  '2019-06-14': {'open': '191.29',
#   'close': '191.66',
#   'high': '192.17',
#   'low': '189.31',
#   'volume': '1403930'},
#  '2019-06-13': {'open': '190.41',
#   'close': '191.45',
#   'high': '192.25',
#   'low': '190.07',
#   'volume': '1411616'},
#  '2019-06-12': {'open': '193.61',
#   'close': '190.22',
#   'high': '194.05',
#   'low': '189.83',
#   'volume': '2059406'},
#  '2019-06-11': {'open': '195.30',
#   'close': '194.73',
#   'high': '196.12',
#   'low': '193.51',
#   'volume': '1632227'},
#  '2019-06-10': {'open': '191.40',
#   'close': '194.12',
#   'high': '197.00',
#   'low': '191.40',
#   'volume': '2372134'},
#  '2019-06-07': {'open': '189.88',
#   'close': '189.81',
#   'high': '190.61',
#   'low': '188.52',
#   'volume': '1838954'},
#  '2019-06-06': {'open': '188.06',
#   'close': '189.81',
#   'high': '190.74',
#   'low': '187.31',
#   'volume': '1653532'},
#  '2019-06-05': {'open': '190.10',
#   'close': '188.44',
#   'high': '190.16',
#   'low': '187.01',
#   'volume': '1968185'},
#  '2019-06-04': {'open': '186.18',
#   'close': '189.88',
#   'high': '189.99',
#   'low': '185.71',
#   'volume': '2421063'},
#  '2019-06-03': {'open': '181.70',
#   'close': '183.19',
#   'high': '183.49',
#   'low': '180.73',
#   'volume': '2857821'},
#  '2019-05-31': {'open': '184.77',
#   'close': '182.49',
#   'high': '184.89',
#   'low': '182.31',
#   'volume': '2640393'},
#  '2019-05-30': {'open': '188.09',
#   'close': '187.37',
#   'high': '189.37',
#   'low': '186.01',
#   'volume': '1919327'},
#  '2019-05-29': {'open': '187.74',
#   'close': '188.05',
#   'high': '188.65',
#   'low': '184.92',
#   'volume': '2815797'},
#  '2019-05-28': {'open': '192.00',
#   'close': '189.44',
#   'high': '193.31',
#   'low': '189.39',
#   'volume': '3039950'},
#  '2019-05-24': {'open': '192.89',
#   'close': '193.00',
#   'high': '194.07',
#   'low': '191.68',
#   'volume': '1637338'},
#  '2019-05-23': {'open': '193.00',
#   'close': '191.97',
#   'high': '193.00',
#   'low': '189.56',
#   'volume': '3184179'},
#  '2019-05-22': {'open': '197.44',
#   'close': '195.52',
#   'high': '198.48',
#   'low': '195.46',
#   'volume': '2427247'},
#  '2019-05-21': {'open': '198.66',
#   'close': '199.11',
#   'high': '199.32',
#   'low': '198.00',
#   'volume': '2327767'},
#  '2019-05-20': {'open': '197.09',
#   'close': '197.24',
#   'high': '197.78',
#   'low': '195.57',
#   'volume': '2483484'},
#  '2019-05-17': {'open': '196.30',
#   'close': '197.43',
#   'high': '199.09',
#   'low': '196.30',
#   'volume': '1928394'},
#  '2019-05-16': {'open': '196.63',
#   'close': '199.14',
#   'high': '200.00',
#   'low': '196.62',
#   'volume': '2008310'},
#  '2019-05-15': {'open': '194.64',
#   'close': '196.40',
#   'high': '197.59',
#   'low': '193.42',
#   'volume': '2271501'},
#  '2019-05-14': {'open': '194.99',
#   'close': '196.28',
#   'high': '198.13',
#   'low': '194.90',
#   'volume': '2463391'},
#  '2019-05-13': {'open': '197.90',
#   'close': '194.97',
#   'high': '197.90',
#   'low': '194.00',
#   'volume': '3605565'},
#  '2019-05-10': {'open': '200.98',
#   'close': '202.05',
#   'high': '202.10',
#   'low': '198.99',
#   'volume': '2089764'},
#  '2019-05-09': {'open': '199.51',
#   'close': '201.63',
#   'high': '202.22',
#   'low': '197.91',
#   'volume': '2333539'},
#  '2019-05-08': {'open': '201.40',
#   'close': '200.95',
#   'high': '203.20',
#   'low': '200.80',
#   'volume': '1817714'},
#  '2019-05-07': {'open': '203.34',
#   'close': '202.63',
#   'high': '204.00',
#   'low': '201.01',
#   'volume': '2839464'},
#  '2019-05-06': {'open': '202.80',
#   'close': '206.43',
#   'high': '206.98',
#   'low': '201.71',
#   'volume': '1927994'},
#  '2019-05-03': {'open': '206.01',
#   'close': '207.52',
#   'high': '208.75',
#   'low': '205.67',
#   'volume': '1897692'},
#  '2019-05-02': {'open': '204.43',
#   'close': '204.99',
#   'high': '206.22',
#   'low': '203.12',
#   'volume': '1514660'},
#  '2019-05-01': {'open': '206.40',
#   'close': '204.73',
#   'high': '208.41',
#   'low': '204.03',
#   'volume': '1981789'},
#  '2019-04-30': {'open': '206.94',
#   'close': '205.92',
#   'high': '207.99',
#   'low': '204.15',
#   'volume': '1833416'},
#  '2019-04-29': {'open': '203.50',
#   'close': '206.92',
#   'high': '208.00',
#   'low': '203.27',
#   'volume': '2997024'},
#  '2019-04-26': {'open': '201.73',
#   'close': '203.08',
#   'high': '203.12',
#   'low': '200.32',
#   'volume': '1543137'},
#  '2019-04-25': {'open': '199.70',
#   'close': '201.40',
#   'high': '202.56',
#   'low': '199.10',
#   'volume': '2075273'},
#  '2019-04-24': {'open': '203.00',
#   'close': '200.54',
#   'high': '203.52',
#   'low': '199.73',
#   'volume': '4606367'},
#  '2019-04-23': {'open': '204.25',
#   'close': '204.14',
#   'high': '205.19',
#   'low': '202.74',
#   'volume': '2121243'},
#  '2019-04-22': {'open': '205.12',
#   'close': '204.60',
#   'high': '205.59',
#   'low': '204.14',
#   'volume': '1591430'},
#  '2019-04-18': {'open': '207.09',
#   'close': '205.91',
#   'high': '207.86',
#   'low': '205.15',
#   'volume': '2874292'},
#  '2019-04-17': {'open': '201.96',
#   'close': '207.90',
#   'high': '208.50',
#   'low': '201.78',
#   'volume': '4195336'},
#  '2019-04-16': {'open': '199.62',
#   'close': '201.84',
#   'high': '202.94',
#   'low': '199.24',
#   'volume': '4852969'},
#  '2019-04-15': {'open': '204.11',
#   'close': '199.91',
#   'high': '205.74',
#   'low': '199.70',
#   'volume': '6617232'},
#  '2019-04-12': {'open': '207.00',
#   'close': '207.84',
#   'high': '209.97',
#   'low': '206.37',
#   'volume': '5096630'},
#  '2019-04-11': {'open': '204.23',
#   'close': '202.83',
#   'high': '205.45',
#   'low': '201.57',
#   'volume': '2802400'},
#  '2019-04-10': {'open': '201.80',
#   'close': '202.98',
#   'high': '203.17',
#   'low': '200.27',
#   'volume': '1907115'},
#  '2019-04-09': {'open': '201.23',
#   'close': '200.62',
#   'high': '201.59',
#   'low': '198.86',
#   'volume': '2400893'},
#  '2019-04-08': {'open': '202.79',
#   'close': '202.54',
#   'high': '203.63',
#   'low': '201.18',
#   'volume': '1891580'},
#  '2019-04-05': {'open': '203.38',
#   'close': '202.38',
#   'high': '205.50',
#   'low': '202.06',
#   'volume': '2447288'},
#  '2019-04-04': {'open': '200.80',
#   'close': '202.23',
#   'high': '204.29',
#   'low': '200.50',
#   'volume': '2582379'},
#  '2019-04-03': {'open': '199.25',
#   'close': '200.86',
#   'high': '201.09',
#   'low': '198.54',
#   'volume': '3227885'},
#  '2019-04-02': {'open': '196.24',
#   'close': '197.50',
#   'high': '197.76',
#   'low': '195.40',
#   'volume': '2246979'},
#  '2019-04-01': {'open': '194.00',
#   'close': '196.74',
#   'high': '198.09',
#   'low': '193.61',
#   'volume': '3562556'},
#  '2019-03-29': {'open': '192.68',
#   'close': '191.99',
#   'high': '193.11',
#   'low': '191.14',
#   'volume': '2632797'},
#  '2019-03-28': {'open': '190.74',
#   'close': '191.18',
#   'high': '191.91',
#   'low': '189.29',
#   'volume': '2343428'},
#  '2019-03-27': {'open': '190.60',
#   'close': '190.03',
#   'high': '191.61',
#   'low': '188.74',
#   'volume': '2343810'},
#  '2019-03-26': {'open': '190.03',
#   'close': '190.69',
#   'high': '192.41',
#   'low': '188.69',
#   'volume': '2910110'},
#  '2019-03-25': {'open': '189.33',
#   'close': '188.51',
#   'high': '191.45',
#   'low': '186.50',
#   'volume': '3751226'},
#  '2019-03-22': {'open': '192.67',
#   'close': '188.96',
#   'high': '193.71',
#   'low': '187.78',
#   'volume': '5703063'},
#  '2019-03-21': {'open': '192.90',
#   'close': '194.58',
#   'high': '195.55',
#   'low': '191.75',
#   'volume': '4031526'},
#  '2019-03-20': {'open': '200.33',
#   'close': '194.32',
#   'high': '200.33',
#   'low': '193.97',
#   'volume': '5033491'},
#  '2019-03-19': {'open': '204.88',
#   'close': '201.12',
#   'high': '206.45',
#   'low': '200.78',
#   'volume': '3284871'},
#  '2019-03-18': {'open': '199.18',
#   'close': '202.47',
#   'high': '203.85',
#   'low': '198.92',
#   'volume': '3355202'},
#  '2019-03-15': {'open': '197.16',
#   'close': '198.26',
#   'high': '198.85',
#   'low': '196.85',
#   'volume': '2985264'},
#  '2019-03-14': {'open': '197.32',
#   'close': '197.47',
#   'high': '198.50',
#   'low': '196.70',
#   'volume': '1482382'},
#  '2019-03-13': {'open': '197.75',
#   'close': '197.25',
#   'high': '198.93',
#   'low': '196.52',
#   'volume': '1904531'},
#  '2019-03-12': {'open': '196.00',
#   'close': '196.63',
#   'high': '197.40',
#   'low': '195.69',
#   'volume': '1977361'},
#  '2019-03-11': {'open': '197.23',
#   'close': '195.97',
#   'high': '198.97',
#   'low': '195.73',
#   'volume': '2669014'},
#  '2019-03-08': {'open': '190.40',
#   'close': '195.24',
#   'high': '195.77',
#   'low': '189.71',
#   'volume': '3162760'},
#  '2019-03-07': {'open': '193.13',
#   'close': '192.77',
#   'high': '193.45',
#   'low': '190.08',
#   'volume': '3567935'},
#  '2019-03-06': {'open': '195.90',
#   'close': '194.74',
#   'high': '197.56',
#   'low': '194.53',
#   'volume': '2247480'},
#  '2019-03-05': {'open': '195.85',
#   'close': '196.00',
#   'high': '196.18',
#   'low': '193.00',
#   'volume': '2338725'},
#  '2019-03-04': {'open': '198.81',
#   'close': '195.98',
#   'high': '200.83',
#   'low': '194.15',
#   'volume': '2683593'},
#  '2019-03-01': {'open': '198.75',
#   'close': '198.20',
#   'high': '201.44',
#   'low': '197.43',
#   'volume': '2580797'},
#  '2019-02-28': {'open': '198.04',
#   'close': '196.70',
#   'high': '198.40',
#   'low': '196.01',
#   'volume': '2964439'},
#  '2019-02-27': {'open': '198.50',
#   'close': '198.10',
#   'high': '199.89',
#   'low': '197.12',
#   'volume': '1804501'},
#  '2019-02-26': {'open': '198.47',
#   'close': '198.90',
#   'high': '200.56',
#   'low': '196.55',
#   'volume': '2499795'},
#  '2019-02-25': {'open': '198.00',
#   'close': '198.65',
#   'high': '201.50',
#   'low': '197.71',
#   'volume': '3032171'},
#  '2019-02-22': {'open': '196.60',
#   'close': '196.00',
#   'high': '197.75',
#   'low': '195.20',
#   'volume': '2626634'},
#  '2019-02-21': {'open': '198.97',
#   'close': '196.36',
#   'high': '199.45',
#   'low': '195.05',
#   'volume': '2786021'},
#  '2019-02-20': {'open': '198.73',
#   'close': '198.60',
#   'high': '199.30',
#   'low': '197.51',
#   'volume': '2265991'},
#  '2019-02-19': {'open': '196.66',
#   'close': '198.67',
#   'high': '199.06',
#   'low': '195.61',
#   'volume': '2558186'},
#  '2019-02-15': {'open': '193.21',
#   'close': '198.50',
#   'high': '198.89',
#   'low': '193.10',
#   'volume': '3065444'},
#  '2019-02-14': {'open': '192.21',
#   'close': '192.53',
#   'high': '194.13',
#   'low': '189.44',
#   'volume': '2864952'},
#  '2019-02-13': {'open': '195.92',
#   'close': '194.69',
#   'high': '198.78',
#   'low': '194.60',
#   'volume': '2757343'},
#  '2019-02-12': {'open': '193.05',
#   'close': '194.49',
#   'high': '195.65',
#   'low': '193.00',
#   'volume': '2392931'},
#  '2019-02-11': {'open': '192.88',
#   'close': '191.33',
#   'high': '193.32',
#   'low': '191.07',
#   'volume': '2056684'},
#  '2019-02-08': {'open': '191.72',
#   'close': '191.67',
#   'high': '192.62',
#   'low': '188.22',
#   'volume': '2757596'},
#  '2019-02-07': {'open': '195.28',
#   'close': '193.07',
#   'high': '195.88',
#   'low': '191.05',
#   'volume': '2948750'},
#  '2019-02-06': {'open': '197.18',
#   'close': '196.62',
#   'high': '199.06',
#   'low': '195.83',
#   'volume': '2063097'},
#  '2019-02-05': {'open': '198.12',
#   'close': '198.01',
#   'high': '199.33',
#   'low': '196.86',
#   'volume': '2601036'},
#  '2019-02-04': {'open': '195.80',
#   'close': '197.72',
#   'high': '197.76',
#   'low': '194.79',
#   'volume': '2400169'},
#  '2019-02-01': {'open': '198.00',
#   'close': '196.54',
#   'high': '199.64',
#   'low': '196.54',
#   'volume': '3174301'},
#  '2019-01-31': {'open': '200.10',
#   'close': '198.01',
#   'high': '202.35',
#   'low': '196.95',
#   'volume': '5604546'},
#  '2019-01-30': {'open': '200.90',
#   'close': '202.48',
#   'high': '203.29',
#   'low': '199.65',
#   'volume': '2773366'},
#  '2019-01-29': {'open': '199.00',
#   'close': '200.50',
#   'high': '201.97',
#   'low': '197.87',
#   'volume': '2694125'},
#  '2019-01-28': {'open': '197.99',
#   'close': '199.72',
#   'high': '200.07',
#   'low': '197.10',
#   'volume': '2369554'},
#  '2019-01-25': {'open': '199.83',
#   'close': '200.74',
#   'high': '201.19',
#   'low': '199.42',
#   'volume': '3275461'},
#  '2019-01-24': {'open': '196.22',
#   'close': '197.80',
#   'high': '199.68',
#   'low': '195.76',
#   'volume': '2632011'},
#  '2019-01-23': {'open': '197.55',
#   'close': '196.90',
#   'high': '198.09',
#   'low': '194.53',
#   'volume': '3410681'},
#  '2019-01-22': {'open': '200.50',
#   'close': '197.68',
#   'high': '201.47',
#   'low': '195.92',
#   'volume': '4648472'},
#  '2019-01-18': {'open': '200.38',
#   'close': '202.54',
#   'high': '203.00',
#   'low': '196.91',
#   'volume': '5650934'},
#  '2019-01-17': {'open': '195.95',
#   'close': '199.09',
#   'high': '199.80',
#   'low': '192.83',
#   'volume': '8176998'},
#  '2019-01-16': {'open': '187.00',
#   'close': '197.08',
#   'high': '198.15',
#   'low': '185.60',
#   'volume': '15194227'},
#  '2019-01-15': {'open': '178.32',
#   'close': '179.91',
#   'high': '179.99',
#   'low': '176.40',
#   'volume': '2911802'},
#  '2019-01-14': {'open': '174.52',
#   'close': '178.72',
#   'high': '179.54',
#   'low': '174.10',
#   'volume': '3361688'},
#  '2019-01-11': {'open': '175.10',
#   'close': '176.93',
#   'high': '177.04',
#   'low': '172.42',
#   'volume': '3183036'},
#  '2019-01-10': {'open': '175.66',
#   'close': '176.00',
#   'high': '178.07',
#   'low': '175.50',
#   'volume': '2808732'},
#  '2019-01-09': {'open': '176.10',
#   'close': '176.47',
#   'high': '177.69',
#   'low': '174.91',
#   'volume': '3321697'},
#  '2019-01-08': {'open': '177.78',
#   'close': '175.37',
#   'high': '178.10',
#   'low': '172.90',
#   'volume': '2692684'},
#  '2019-01-07': {'open': '175.23',
#   'close': '176.02',
#   'high': '177.83',
#   'low': '172.27',
#   'volume': '3152092'},
#  '2019-01-04': {'open': '172.99',
#   'close': '175.05',
#   'high': '176.00',
#   'low': '171.10',
#   'volume': '3788312'},
#  '2019-01-03': {'open': '170.66',
#   'close': '169.51',
#   'high': '171.77',
#   'low': '168.29',
#   'volume': '4060393'},
#  '2019-01-02': {'open': '164.33',
#   'close': '172.03',
#   'high': '172.25',
#   'low': '163.35',
#   'volume': '3999444'},
#  '2018-12-31': {'open': '163.78',
#   'close': '167.05',
#   'high': '167.12',
#   'low': '163.78',
#   'volume': '4550009'},
#  '2018-12-28': {'open': '165.64',
#   'close': '163.03',
#   'high': '165.95',
#   'low': '162.02',
#   'volume': '4110520'},
#  '2018-12-27': {'open': '160.12',
#   'close': '165.41',
#   'high': '165.41',
#   'low': '159.02',
#   'volume': '4972964'},
#  '2018-12-26': {'open': '157.00',
#   'close': '162.93',
#   'high': '163.11',
#   'low': '151.70',
#   'volume': '7054656'},
#  '2018-12-24': {'open': '159.00',
#   'close': '156.35',
#   'high': '160.00',
#   'low': '154.31',
#   'volume': '3783497'},
#  '2018-12-21': {'open': '168.25',
#   'close': '160.05',
#   'high': '169.63',
#   'low': '159.42',
#   'volume': '8960030'},
#  '2018-12-20': {'open': '168.39',
#   'close': '168.41',
#   'high': '171.65',
#   'low': '167.16',
#   'volume': '6488177'},
#  '2018-12-19': {'open': '171.59',
#   'close': '169.25',
#   'high': '174.85',
#   'low': '167.60',
#   'volume': '5316095'},
#  '2018-12-18': {'open': '169.78',
#   'close': '171.50',
#   'high': '173.02',
#   'low': '169.32',
#   'volume': '5150789'},
#  '2018-12-17': {'open': '169.40',
#   'close': '168.01',
#   'high': '171.43',
#   'low': '166.53',
#   'volume': '8395805'},
#  '2018-12-14': {'open': '174.34',
#   'close': '172.77',
#   'high': '176.26',
#   'low': '172.37',
#   'volume': '5078341'},
#  '2018-12-13': {'open': '177.83',
#   'close': '175.92',
#   'high': '178.69',
#   'low': '175.12',
#   'volume': '4008550'},
#  '2018-12-12': {'open': '178.50',
#   'close': '176.70',
#   'high': '180.00',
#   'low': '176.48',
#   'volume': '3677292'},
#  '2018-12-11': {'open': '182.15',
#   'close': '176.80',
#   'high': '184.43',
#   'low': '175.45',
#   'volume': '4713871'},
#  '2018-12-10': {'open': '178.60',
#   'close': '178.83',
#   'high': '179.84',
#   'low': '174.68',
#   'volume': '4528341'},
#  '2018-12-07': {'open': '183.85',
#   'close': '179.67',
#   'high': '186.25',
#   'low': '179.00',
#   'volume': '3921232'},
#  '2018-12-06': {'open': '181.33',
#   'close': '184.09',
#   'high': '184.88',
#   'low': '180.15',
#   'volume': '5275511'},
#  '2018-12-04': {'open': '190.69',
#   'close': '184.31',
#   'high': '191.11',
#   'low': '183.63',
#   'volume': '5797535'},
#  '2018-12-03': {'open': '194.00',
#   'close': '191.63',
#   'high': '195.66',
#   'low': '191.62',
#   'volume': '4015619'},
#  '2018-11-30': {'open': '190.57',
#   'close': '190.69',
#   'high': '191.45',
#   'low': '188.12',
#   'volume': '6219958'},
#  '2018-11-29': {'open': '196.02',
#   'close': '194.85',
#   'high': '197.45',
#   'low': '193.16',
#   'volume': '2666117'},
#  '2018-11-28': {'open': '194.84',
#   'close': '198.35',
#   'high': '198.45',
#   'low': '192.23',
#   'volume': '3762873'},
#  '2018-11-27': {'open': '193.40',
#   'close': '193.65',
#   'high': '194.62',
#   'low': '191.56',
#   'volume': '2345380'},
#  '2018-11-26': {'open': '191.17',
#   'close': '194.34',
#   'high': '195.23',
#   'low': '190.69',
#   'volume': '3143267'},
#  '2018-11-23': {'open': '191.61',
#   'close': '189.10',
#   'high': '191.87',
#   'low': '188.94',
#   'volume': '1862633'},
#  '2018-11-21': {'open': '192.09',
#   'close': '192.60',
#   'high': '195.24',
#   'low': '191.19',
#   'volume': '4111653'},
#  '2018-11-20': {'open': '195.10',
#   'close': '191.34',
#   'high': '195.89',
#   'low': '190.35',
#   'volume': '5513841'},
#  '2018-11-19': {'open': '201.83',
#   'close': '198.22',
#   'high': '202.30',
#   'low': '197.35',
#   'volume': '3419116'},
#  '2018-11-16': {'open': '202.93',
#   'close': '202.12',
#   'high': '204.74',
#   'low': '200.35',
#   'volume': '2829572'},
#  '2018-11-15': {'open': '201.80',
#   'close': '203.74',
#   'high': '204.50',
#   'low': '199.32',
#   'volume': '4260001'},
#  '2018-11-14': {'open': '206.24',
#   'close': '202.49',
#   'high': '207.34',
#   'low': '198.44',
#   'volume': '5742451'},
#  '2018-11-13': {'open': '204.40',
#   'close': '205.05',
#   'high': '209.59',
#   'low': '202.33',
#   'volume': '6984798'},
#  '2018-11-12': {'open': '222.00',
#   'close': '206.05',
#   'high': '222.31',
#   'low': '205.13',
#   'volume': '11019357'},
#  '2018-11-09': {'open': '231.69',
#   'close': '222.65',
#   'high': '231.69',
#   'low': '222.30',
#   'volume': '3721716'},
#  '2018-11-08': {'open': '231.00',
#   'close': '231.65',
#   'high': '234.06',
#   'low': '230.60',
#   'volume': '2404854'},
#  '2018-11-07': {'open': '230.05',
#   'close': '231.28',
#   'high': '232.80',
#   'low': '226.90',
#   'volume': '3514619'},
#  '2018-11-06': {'open': '228.19',
#   'close': '228.20',
#   'high': '229.52',
#   'low': '227.05',
#   'volume': '2275807'},
#  '2018-11-05': {'open': '228.32',
#   'close': '228.72',
#   'high': '231.10',
#   'low': '226.95',
#   'volume': '2565374'},
#  '2018-11-02': {'open': '230.00',
#   'close': '229.69',
#   'high': '231.69',
#   'low': '226.29',
#   'volume': '3698981'},
#  '2018-11-01': {'open': '225.76',
#   'close': '226.97',
#   'high': '228.88',
#   'low': '225.47',
#   'volume': '2557550'},
#  '2018-10-31': {'open': '221.89',
#   'close': '225.37',
#   'high': '229.00',
#   'low': '221.40',
#   'volume': '4369633'},
#  '2018-10-30': {'open': '215.99',
#   'close': '219.28',
#   'high': '220.35',
#   'low': '215.04',
#   'volume': '3897378'},
#  '2018-10-29': {'open': '214.15',
#   'close': '214.49',
#   'high': '218.21',
#   'low': '212.05',
#   'volume': '3278258'},
#  '2018-10-26': {'open': '210.73',
#   'close': '212.36',
#   'high': '214.80',
#   'low': '209.53',
#   'volume': '3558077'},
#  '2018-10-25': {'open': '211.27',
#   'close': '214.01',
#   'high': '215.69',
#   'low': '210.34',
#   'volume': '3179707'},
#  '2018-10-24': {'open': '218.14',
#   'close': '209.18',
#   'high': '218.93',
#   'low': '208.40',
#   'volume': '4152713'},
#  '2018-10-23': {'open': '216.59',
#   'close': '218.56',
#   'high': '219.52',
#   'low': '214.32',
#   'volume': '3318168'},
#  '2018-10-22': {'open': '226.93',
#   'close': '221.60',
#   'high': '228.87',
#   'low': '221.52',
#   'volume': '2736770'},
#  '2018-10-19': {'open': '225.26',
#   'close': '226.96',
#   'high': '228.30',
#   'low': '224.19',
#   'volume': '2759105'},
#  '2018-10-18': {'open': '227.50',
#   'close': '224.95',
#   'high': '228.73',
#   'low': '223.86',
#   'volume': '2995425'},
#  '2018-10-17': {'open': '220.53',
#   'close': '228.28',
#   'high': '228.90',
#   'low': '220.05',
#   'volume': '4953723'},
#  '2018-10-16': {'open': '219.35',
#   'close': '221.70',
#   'high': '222.00',
#   'low': '216.30',
#   'volume': '5924183'},
#  '2018-10-15': {'open': '214.45',
#   'close': '215.22',
#   'high': '217.14',
#   'low': '213.05',
#   'volume': '3333750'},
#  '2018-10-12': {'open': '217.00',
#   'close': '213.87',
#   'high': '217.98',
#   'low': '211.46',
#   'volume': '4161711'},
#  '2018-10-11': {'open': '214.20',
#   'close': '212.97',
#   'high': '216.03',
#   'low': '210.95',
#   'volume': '6217366'},
#  '2018-10-10': {'open': '223.24',
#   'close': '214.89',
#   'high': '223.64',
#   'low': '214.56',
#   'volume': '3955472'},
#  '2018-10-09': {'open': '224.99',
#   'close': '222.91',
#   'high': '225.12',
#   'low': '222.53',
#   'volume': '1863236'},
#  '2018-10-08': {'open': '224.26',
#   'close': '225.35',
#   'high': '226.92',
#   'low': '222.50',
#   'volume': '2523200'},
#  '2018-10-05': {'open': '228.00',
#   'close': '225.71',
#   'high': '228.41',
#   'low': '224.21',
#   'volume': '1722697'},
#  '2018-10-04': {'open': '229.26',
#   'close': '227.48',
#   'high': '231.40',
#   'low': '225.39',
#   'volume': '2903786'},
#  '2018-10-03': {'open': '227.75',
#   'close': '227.78',
#   'high': '229.77',
#   'low': '226.58',
#   'volume': '2574210'},
#  '2018-10-02': {'open': '225.28',
#   'close': '226.07',
#   'high': '226.33',
#   'low': '223.97',
#   'volume': '2272681'},
#  '2018-10-01': {'open': '226.22',
#   'close': '225.33',
#   'high': '227.59',
#   'low': '225.00',
#   'volume': '2451341'},
#  '2018-09-28': {'open': '225.75',
#   'close': '224.24',
#   'high': '227.40',
#   'low': '223.80',
#   'volume': '3097847'},
#  '2018-09-27': {'open': '228.77',
#   'close': '227.74',
#   'high': '229.85',
#   'low': '227.52',
#   'volume': '2451510'},
#  '2018-09-26': {'open': '232.96',
#   'close': '228.88',
#   'high': '233.00',
#   'low': '228.24',
#   'volume': '2372746'},
#  '2018-09-25': {'open': '234.64',
#   'close': '232.50',
#   'high': '234.64',
#   'low': '232.23',
#   'volume': '2003418'},
#  '2018-09-24': {'open': '234.74',
#   'close': '232.90',
#   'high': '235.74',
#   'low': '232.24',
#   'volume': '2056982'},
#  '2018-09-21': {'open': '238.06',
#   'close': '235.34',
#   'high': '238.52',
#   'low': '234.83',
#   'volume': '3760267'},
#  '2018-09-20': {'open': '237.00',
#   'close': '237.40',
#   'high': '238.51',
#   'low': '236.03',
#   'volume': '2502995'},
#  '2018-09-19': {'open': '229.90',
#   'close': '235.58',
#   'high': '236.28',
#   'low': '229.52',
#   'volume': '3716487'},
#  '2018-09-18': {'open': '228.35',
#   'close': '228.89',
#   'high': '229.40',
#   'low': '226.57',
#   'volume': '2498063'},
#  '2018-09-17': {'open': '229.40',
#   'close': '227.89',
#   'high': '230.16',
#   'low': '227.30',
#   'volume': '1918787'},
#  '2018-09-14': {'open': '229.08',
#   'close': '229.24',
#   'high': '230.55',
#   'low': '228.76',
#   'volume': '2228307'},
#  '2018-09-13': {'open': '229.50',
#   'close': '228.33',
#   'high': '229.85',
#   'low': '227.57',
#   'volume': '3003569'},
#  '2018-09-12': {'open': '230.91',
#   'close': '228.15',
#   'high': '231.99',
#   'low': '227.30',
#   'volume': '3577707'},
#  '2018-09-11': {'open': '230.67',
#   'close': '230.21',
#   'high': '231.65',
#   'low': '228.66',
#   'volume': '2719540'},
#  '2018-09-10': {'open': '235.01',
#   'close': '231.91',
#   'high': '235.50',
#   'low': '231.74',
#   'volume': '1948493'},
#  '2018-09-07': {'open': '235.05',
#   'close': '233.91',
#   'high': '235.64',
#   'low': '232.68',
#   'volume': '1952884'},
#  '2018-09-06': {'open': '237.00',
#   'close': '234.52',
#   'high': '238.63',
#   'low': '233.88',
#   'volume': '2651790'},
#  '2018-09-05': {'open': '237.01',
#   'close': '237.56',
#   'high': '239.45',
#   'low': '236.17',
#   'volume': '2092231'},
#  '2018-09-04': {'open': '237.76',
#   'close': '237.66',
#   'high': '238.12',
#   'low': '234.59',
#   'volume': '2083698'},
#  '2018-08-31': {'open': '238.94',
#   'close': '237.81',
#   'high': '239.35',
#   'low': '237.12',
#   'volume': '1965472'},
#  '2018-08-30': {'open': '240.80',
#   'close': '239.40',
#   'high': '241.12',
#   'low': '238.68',
#   'volume': '1963935'},
#  '2018-08-29': {'open': '242.05',
#   'close': '241.40',
#   'high': '242.79',
#   'low': '240.31',
#   'volume': '1911957'},
#  '2018-08-28': {'open': '243.06',
#   'close': '242.37',
#   'high': '245.08',
#   'low': '241.59',
#   'volume': '2951180'},
#  '2018-08-27': {'open': '236.99',
#   'close': '242.60',
#   'high': '243.65',
#   'low': '236.56',
#   'volume': '4106946'},
#  '2018-08-24': {'open': '237.36',
#   'close': '235.11',
#   'high': '237.80',
#   'low': '234.70',
#   'volume': '1948234'},
#  '2018-08-23': {'open': '239.05',
#   'close': '236.34',
#   'high': '239.28',
#   'low': '235.84',
#   'volume': '2065059'},
#  '2018-08-22': {'open': '237.89',
#   'close': '239.34',
#   'high': '239.67',
#   'low': '237.58',
#   'volume': '1870940'},
#  '2018-08-21': {'open': '235.29',
#   'close': '238.65',
#   'high': '239.53',
#   'low': '235.29',
#   'volume': '2437333'},
#  '2018-08-20': {'open': '234.13',
#   'close': '235.78',
#   'high': '235.98',
#   'low': '234.08',
#   'volume': '2604975'},
#  '2018-08-17': {'open': '232.51',
#   'close': '233.38',
#   'high': '233.72',
#   'low': '231.64',
#   'volume': '2107243'},
#  '2018-08-16': {'open': '230.67',
#   'close': '233.00',
#   'high': '233.29',
#   'low': '230.45',
#   'volume': '2438306'},
#  '2018-08-15': {'open': '229.35',
#   'close': '229.25',
#   'high': '231.54',
#   'low': '228.31',
#   'volume': '3218939'},
#  '2018-08-14': {'open': '227.35',
#   'close': '229.56',
#   'high': '230.37',
#   'low': '227.30',
#   'volume': '2359006'},
#  '2018-08-13': {'open': '229.49',
#   'close': '226.86',
#   'high': '229.89',
#   'low': '226.57',
#   'volume': '2663244'},
#  '2018-08-10': {'open': '230.97',
#   'close': '229.61',
#   'high': '231.46',
#   'low': '228.11',
#   'volume': '3863732'},
#  '2018-08-09': {'open': '236.35',
#   'close': '233.78',
#   'high': '236.85',
#   'low': '233.39',
#   'volume': '2952021'},
#  '2018-08-08': {'open': '238.12',
#   'close': '236.37',
#   'high': '239.16',
#   'low': '236.23',
#   'volume': '2522656'},
#  '2018-08-07': {'open': '237.25',
#   'close': '237.83',
#   'high': '239.46',
#   'low': '236.49',
#   'volume': '2399530'},
#  '2018-08-06': {'open': '234.14',
#   'close': '235.93',
#   'high': '236.98',
#   'low': '234.03',
#   'volume': '2259700'},
#  '2018-08-03': {'open': '234.44',
#   'close': '234.09',
#   'high': '235.52',
#   'low': '233.49',
#   'volume': '3053130'},
#  '2018-08-02': {'open': '233.93',
#   'close': '233.99',
#   'high': '235.21',
#   'low': '232.77',
#   'volume': '2580124'},
#  '2018-08-01': {'open': '238.50',
#   'close': '236.04',
#   'high': '239.40',
#   'low': '235.78',
#   'volume': '2510727'},
#  '2018-07-31': {'open': '239.50',
#   'close': '237.43',
#   'high': '239.50',
#   'low': '236.55',
#   'volume': '2504133'},
#  '2018-07-30': {'open': '238.00',
#   'close': '238.95',
#   'high': '239.73',
#   'low': '236.89',
#   'volume': '2454219'},
#  '2018-07-27': {'open': '237.96',
#   'close': '237.64',
#   'high': '238.80',
#   'low': '235.99',
#   'volume': '1999682'},
#  '2018-07-26': {'open': '237.00',
#   'close': '237.11',
#   'high': '238.34',
#   'low': '236.43',
#   'volume': '1885496'},
#  '2018-07-25': {'open': '235.01',
#   'close': '236.69',
#   'high': '236.85',
# ...
#   'high': '163.79',
#   'low': '161.68',
#   'volume': '1677707'},
#  '2016-09-27': {'open': '160.72',
#   'close': '162.89',
#   'high': '163.45',
#   'low': '159.82',
#   'volume': '2602486'},
#  '2016-09-26': {'open': '163.83',
#   'close': '161.48',
#   'high': '163.97',
#   'low': '161.00',
#   'volume': '2772196'},
#  '2016-09-23': {'open': '167.75',
#   'close': '165.13',
#   'high': '168.10',
#   'low': '165.05',
#   'volume': '3420548'},
#  '2016-09-22': {'open': '168.45',
#   'close': '168.02',
#   'high': '169.33',
#   'low': '167.70',
#   'volume': '2467664'},
#  '2016-09-21': {'open': '167.42',
#   'close': '167.03',
#   'high': '168.28',
#   'low': '165.93',
#   'volume': '2333587'},
#  '2016-09-20': {'open': '167.68',
#   'close': '166.47',
#   'high': '168.28',
#   'low': '166.39',
#   'volume': '1533159'},
#  '2016-09-19': {'open': '167.34',
#   'close': '166.21',
#   'high': '168.31',
#   'low': '165.68',
#   'volume': '2030742'},
#  '2016-09-16': {'open': '167.85',
#   'close': '166.00',
#   'high': '168.05',
#   'low': '165.61',
#   'volume': '4534927'},
#  '2016-09-15': {'open': '165.78',
#   'close': '168.08',
#   'high': '168.76',
#   'low': '165.76',
#   'volume': '1666130'},
#  '2016-09-14': {'open': '167.00',
#   'close': '166.16',
#   'high': '167.86',
#   'low': '165.59',
#   'volume': '1995701'},
#  '2016-09-13': {'open': '168.54',
#   'close': '167.00',
#   'high': '169.97',
#   'low': '166.38',
#   'volume': '2788205'},
#  '2016-09-12': {'open': '167.01',
#   'close': '171.06',
#   'high': '171.67',
#   'low': '166.23',
#   'volume': '2647877'},
#  '2016-09-09': {'open': '170.83',
#   'close': '168.57',
#   'high': '172.42',
#   'low': '168.51',
#   'volume': '3411550'},
#  '2016-09-08': {'open': '169.35',
#   'close': '171.66',
#   'high': '171.88',
#   'low': '168.71',
#   'volume': '3031625'},
#  '2016-09-07': {'open': '168.70',
#   'close': '169.67',
#   'high': '170.21',
#   'low': '168.65',
#   'volume': '1584347'},
#  '2016-09-06': {'open': '168.72',
#   'close': '169.33',
#   'high': '169.79',
#   'low': '167.47',
#   'volume': '2034847'},
#  '2016-09-02': {'open': '168.52',
#   'close': '169.18',
#   'high': '169.74',
#   'low': '167.90',
#   'volume': '1747492'},
#  '2016-09-01': {'open': '170.00',
#   'close': '168.51',
#   'high': '170.07',
#   'low': '166.66',
#   'volume': '2843174'},
#  '2016-08-31': {'open': '169.25',
#   'close': '169.46',
#   'high': '170.24',
#   'low': '167.47',
#   'volume': '3688089'},
#  '2016-08-30': {'open': '166.69',
#   'close': '169.37',
#   'high': '169.51',
#   'low': '166.44',
#   'volume': '2931934'},
#  '2016-08-29': {'open': '166.60',
#   'close': '166.87',
#   'high': '167.86',
#   'low': '166.15',
#   'volume': '2620945'},
#  '2016-08-26': {'open': '166.76',
#   'close': '165.97',
#   'high': '168.07',
#   'low': '165.36',
#   'volume': '2402214'},
#  '2016-08-25': {'open': '165.08',
#   'close': '165.90',
#   'high': '166.04',
#   'low': '164.61',
#   'volume': '1441352'},
#  '2016-08-24': {'open': '165.78',
#   'close': '165.30',
#   'high': '166.70',
#   'low': '164.85',
#   'volume': '2035311'},
#  '2016-08-23': {'open': '167.00',
#   'close': '166.08',
#   'high': '167.85',
#   'low': '165.98',
#   'volume': '1965148'},
#  '2016-08-22': {'open': '166.00',
#   'close': '166.26',
#   'high': '166.91',
#   'low': '164.89',
#   'volume': '1448111'},
#  '2016-08-19': {'open': '165.36',
#   'close': '166.23',
#   'high': '166.90',
#   'low': '164.50',
#   'volume': '1840848'},
#  '2016-08-18': {'open': '165.34',
#   'close': '166.06',
#   'high': '166.56',
#   'low': '164.63',
#   'volume': '1750624'},
#  '2016-08-17': {'open': '165.94',
#   'close': '165.67',
#   'high': '166.32',
#   'low': '164.74',
#   'volume': '2061908'},
#  '2016-08-16': {'open': '164.99',
#   'close': '165.65',
#   'high': '166.76',
#   'low': '164.72',
#   'volume': '2523774'},
#  '2016-08-15': {'open': '163.87',
#   'close': '165.55',
#   'high': '165.84',
#   'low': '163.80',
#   'volume': '2221188'},
#  '2016-08-12': {'open': '162.67',
#   'close': '163.25',
#   'high': '163.37',
#   'low': '162.07',
#   'volume': '1440839'},
#  '2016-08-11': {'open': '162.20',
#   'close': '163.86',
#   'high': '164.25',
#   'low': '161.93',
#   'volume': '1827689'},
#  '2016-08-10': {'open': '163.45',
#   'close': '162.19',
#   'high': '163.60',
#   'low': '162.01',
#   'volume': '1656141'},
#  '2016-08-09': {'open': '162.50',
#   'close': '163.44',
#   'high': '164.58',
#   'low': '162.50',
#   'volume': '1956938'},
#  '2016-08-08': {'open': '162.10',
#   'close': '162.83',
#   'high': '163.98',
#   'low': '162.01',
#   'volume': '2266612'},
#  '2016-08-05': {'open': '159.75',
#   'close': '162.09',
#   'high': '162.13',
#   'low': '159.20',
#   'volume': '2676064'},
#  '2016-08-04': {'open': '158.22',
#   'close': '158.05',
#   'high': '158.90',
#   'low': '157.41',
#   'volume': '2005699'},
#  '2016-08-03': {'open': '156.45',
#   'close': '158.34',
#   'high': '158.95',
#   'low': '156.18',
#   'volume': '2284670'},
#  '2016-08-02': {'open': '157.65',
#   'close': '156.06',
#   'high': '158.46',
#   'low': '155.37',
#   'volume': '3182583'},
#  '2016-08-01': {'open': '158.81',
#   'close': '158.18',
#   'high': '159.92',
#   'low': '157.93',
#   'volume': '2315900'},
#  '2016-07-29': {'open': '159.51',
#   'close': '158.81',
#   'high': '160.19',
#   'low': '158.65',
#   'volume': '2388134'},
#  '2016-07-28': {'open': '160.18',
#   'close': '160.53',
#   'high': '160.96',
#   'low': '158.84',
#   'volume': '2047424'},
#  '2016-07-27': {'open': '161.20',
#   'close': '160.99',
#   'high': '162.17',
#   'low': '160.41',
#   'volume': '2317561'},
#  '2016-07-26': {'open': '160.68',
#   'close': '161.16',
#   'high': '161.50',
#   'low': '159.42',
#   'volume': '2147846'},
#  '2016-07-25': {'open': '159.64',
#   'close': '160.51',
#   'high': '161.33',
#   'low': '159.61',
#   'volume': '1956099'},
#  '2016-07-22': {'open': '160.29',
#   'close': '160.41',
#   'high': '160.73',
#   'low': '159.86',
#   'volume': '1811695'},
#  '2016-07-21': {'open': '161.71',
#   'close': '160.05',
#   'high': '161.90',
#   'low': '159.77',
#   'volume': '2997187'},
#  '2016-07-20': {'open': '162.55',
#   'close': '161.77',
#   'high': '162.89',
#   'low': '159.22',
#   'volume': '3547824'},
#  '2016-07-19': {'open': '162.02',
#   'close': '161.41',
#   'high': '164.08',
#   'low': '160.73',
#   'volume': '5399685'},
#  '2016-07-18': {'open': '162.36',
#   'close': '163.33',
#   'high': '164.09',
#   'low': '162.01',
#   'volume': '4731357'},
#  '2016-07-15': {'open': '162.86',
#   'close': '161.64',
#   'high': '163.14',
#   'low': '160.70',
#   'volume': '3076630'},
#  '2016-07-14': {'open': '160.29',
#   'close': '162.54',
#   'high': '163.24',
#   'low': '160.01',
#   'volume': '5087024'},
#  '2016-07-13': {'open': '157.00',
#   'close': '157.92',
#   'high': '158.27',
#   'low': '156.15',
#   'volume': '4275685'},
#  '2016-07-12': {'open': '154.00',
#   'close': '156.92',
#   'high': '157.25',
#   'low': '153.92',
#   'volume': '5119314'},
#  '2016-07-11': {'open': '151.49',
#   'close': '152.19',
#   'high': '152.98',
#   'low': '151.38',
#   'volume': '3042033'},
#  '2016-07-08': {'open': '149.36',
#   'close': '150.38',
#   'high': '150.92',
#   'low': '148.31',
#   'volume': '3281205'},
#  '2016-07-07': {'open': '146.00',
#   'close': '147.00',
#   'high': '148.09',
#   'low': '145.36',
#   'volume': '2578042'},
#  '2016-07-06': {'open': '142.94',
#   'close': '145.58',
#   'high': '145.94',
#   'low': '142.62',
#   'volume': '2941459'},
#  '2016-07-05': {'open': '146.72',
#   'close': '144.45',
#   'high': '146.94',
#   'low': '143.33',
#   'volume': '3942834'},
#  '2016-07-01': {'open': '148.49',
#   'close': '148.25',
#   'high': '150.70',
#   'low': '148.07',
#   'volume': '3096778'},
#  '2016-06-30': {'open': '146.67',
#   'close': '148.58',
#   'high': '148.88',
#   'low': '145.37',
#   'volume': '4528474'},
#  '2016-06-29': {'open': '143.60',
#   'close': '145.50',
#   'high': '145.55',
#   'low': '142.93',
#   'volume': '3803312'},
#  '2016-06-28': {'open': '142.21',
#   'close': '142.41',
#   'high': '142.62',
#   'low': '139.82',
#   'volume': '5040725'},
#  '2016-06-27': {'open': '140.07',
#   'close': '139.51',
#   'high': '141.23',
#   'low': '138.20',
#   'volume': '7395704'},
#  '2016-06-24': {'open': '143.03',
#   'close': '141.86',
#   'high': '146.42',
#   'low': '140.92',
#   'volume': '9441520'},
#  '2016-06-23': {'open': '150.56',
#   'close': '152.66',
#   'high': '152.80',
#   'low': '150.14',
#   'volume': '2938037'},
#  '2016-06-22': {'open': '148.01',
#   'close': '148.14',
#   'high': '150.12',
#   'low': '147.99',
#   'volume': '2485406'},
#  '2016-06-21': {'open': '148.50',
#   'close': '148.35',
#   'high': '148.83',
#   'low': '147.12',
#   'volume': '2424723'},
#  '2016-06-20': {'open': '148.50',
#   'close': '147.75',
#   'high': '150.50',
#   'low': '147.58',
#   'volume': '3337283'},
#  '2016-06-17': {'open': '146.63',
#   'close': '145.64',
#   'high': '148.23',
#   'low': '145.46',
#   'volume': '4296342'},
#  '2016-06-16': {'open': '145.00',
#   'close': '146.63',
#   'high': '146.99',
#   'low': '143.53',
#   'volume': '3495834'},
#  '2016-06-15': {'open': '147.16',
#   'close': '146.16',
#   'high': '148.70',
#   'low': '145.90',
#   'volume': '2980272'},
#  '2016-06-14': {'open': '148.22',
#   'close': '146.19',
#   'high': '149.05',
#   'low': '145.45',
#   'volume': '5069610'},
#  '2016-06-13': {'open': '149.00',
#   'close': '148.63',
#   'high': '151.32',
#   'low': '148.59',
#   'volume': '3385673'},
#  '2016-06-10': {'open': '151.35',
#   'close': '149.89',
#   'high': '151.66',
#   'low': '149.57',
#   'volume': '4335725'},
#  '2016-06-09': {'open': '153.79',
#   'close': '153.17',
#   'high': '154.29',
#   'low': '152.46',
#   'volume': '2712012'},
#  '2016-06-08': {'open': '155.20',
#   'close': '154.64',
#   'high': '156.58',
#   'low': '153.91',
#   'volume': '2426771'},
#  '2016-06-07': {'open': '157.20',
#   'close': '155.17',
#   'high': '157.47',
#   'low': '155.17',
#   'volume': '2488541'},
#  '2016-06-06': {'open': '156.25',
#   'close': '157.06',
#   'high': '157.91',
#   'low': '155.77',
#   'volume': '2540081'},
#  '2016-06-03': {'open': '155.86',
#   'close': '155.67',
#   'high': '156.54',
#   'low': '153.86',
#   'volume': '4328603'},
#  '2016-06-02': {'open': '160.14',
#   'close': '159.28',
#   'high': '160.33',
#   'low': '158.46',
#   'volume': '2257027'},
#  '2016-06-01': {'open': '157.90',
#   'close': '159.97',
#   'high': '160.55',
#   'low': '156.00',
#   'volume': '2581557'},
#  '2016-05-31': {'open': '160.40',
#   'close': '159.48',
#   'high': '161.65',
#   'low': '158.55',
#   'volume': '2915646'},
#  '2016-05-27': {'open': '158.70',
#   'close': '159.53',
#   'high': '160.40',
#   'low': '158.32',
#   'volume': '2157794'},
#  '2016-05-26': {'open': '161.16',
#   'close': '159.22',
#   'high': '161.33',
#   'low': '159.17',
#   'volume': '2576024'},
#  '2016-05-25': {'open': '158.06',
#   'close': '161.25',
#   'high': '162.29',
#   'low': '158.03',
#   'volume': '3259910'},
#  '2016-05-24': {'open': '156.67',
#   'close': '157.59',
#   'high': '158.55',
#   'low': '156.44',
#   'volume': '3039343'},
#  '2016-05-23': {'open': '154.44',
#   'close': '155.45',
#   'high': '156.09',
#   'low': '153.74',
#   'volume': '2767609'},
#  '2016-05-20': {'open': '155.76',
#   'close': '154.51',
#   'high': '156.41',
#   'low': '153.92',
#   'volume': '3247841'},
#  '2016-05-19': {'open': '158.68',
#   'close': '154.70',
#   'high': '159.95',
#   'low': '154.52',
#   'volume': '4711549'},
#  '2016-05-18': {'open': '154.81',
#   'close': '159.94',
#   'high': '160.00',
#   'low': '154.65',
#   'volume': '3652990'},
#  '2016-05-17': {'open': '154.74',
#   'close': '154.65',
#   'high': '157.11',
#   'low': '153.77',
#   'volume': '2701449'},
#  '2016-05-16': {'open': '155.34',
#   'close': '155.38',
#   'high': '156.90',
#   'low': '154.60',
#   'volume': '3177707'},
#  '2016-05-13': {'open': '157.88',
#   'close': '155.34',
#   'high': '159.72',
#   'low': '155.26',
#   'volume': '2549908'},
#  '2016-05-12': {'open': '160.32',
#   'close': '158.07',
#   'high': '161.47',
#   'low': '157.31',
#   'volume': '2447686'},
#  '2016-05-11': {'open': '161.36',
#   'close': '159.42',
#   'high': '162.53',
#   'low': '159.28',
#   'volume': '2095968'},
#  '2016-05-10': {'open': '158.67',
#   'close': '161.42',
#   'high': '161.50',
#   'low': '158.39',
#   'volume': '2379590'},
#  '2016-05-09': {'open': '158.20',
#   'close': '157.51',
#   'high': '159.85',
#   'low': '156.79',
#   'volume': '2097854'},
#  '2016-05-06': {'open': '158.19',
#   'close': '158.85',
#   'high': '160.17',
#   'low': '157.01',
#   'volume': '2306376'},
#  '2016-05-05': {'open': '160.78',
#   'close': '159.53',
#   'high': '160.82',
#   'low': '158.50',
#   'volume': '2366823'},
#  '2016-05-04': {'open': '161.20',
#   'close': '160.07',
#   'high': '162.60',
#   'low': '159.09',
#   'volume': '3203833'},
#  '2016-05-03': {'open': '163.66',
#   'close': '163.14',
#   'high': '164.11',
#   'low': '161.37',
#   'volume': '2776969'},
#  '2016-05-02': {'open': '165.08',
#   'close': '166.18',
#   'high': '167.19',
#   'low': '163.99',
#   'volume': '1998361'},
#  '2016-04-29': {'open': '163.80',
#   'close': '164.11',
#   'high': '164.68',
#   'low': '162.56',
#   'volume': '2890849'},
#  '2016-04-28': {'open': '165.35',
#   'close': '164.29',
#   'high': '167.32',
#   'low': '164.01',
#   'volume': '2527327'},
#  '2016-04-27': {'open': '165.83',
#   'close': '166.92',
#   'high': '168.66',
#   'low': '164.93',
#   'volume': '3323584'},
#  '2016-04-26': {'open': '165.38',
#   'close': '165.84',
#   'high': '166.00',
#   'low': '164.22',
#   'volume': '2250895'},
#  '2016-04-25': {'open': '166.00',
#   'close': '165.09',
#   'high': '167.39',
#   'low': '164.06',
#   'volume': '2472984'},
#  '2016-04-22': {'open': '165.79',
#   'close': '166.75',
#   'high': '167.49',
#   'low': '165.66',
#   'volume': '2680171'},
#  '2016-04-21': {'open': '166.55',
#   'close': '165.32',
#   'high': '168.90',
#   'low': '165.01',
#   'volume': '4164434'},
#  '2016-04-20': {'open': '162.00',
#   'close': '166.98',
#   'high': '167.45',
#   'low': '161.94',
#   'volume': '4800787'},
#  '2016-04-19': {'open': '157.75',
#   'close': '162.65',
#   'high': '163.70',
#   'low': '157.00',
#   'volume': '5830511'},
#  '2016-04-18': {'open': '157.61',
#   'close': '159.02',
#   'high': '160.00',
#   'low': '157.15',
#   'volume': '3030489'},
#  '2016-04-15': {'open': '161.23',
#   'close': '158.52',
#   'high': '161.78',
#   'low': '158.20',
#   'volume': '3467826'},
#  '2016-04-14': {'open': '159.53',
#   'close': '160.91',
#   'high': '162.27',
#   'low': '159.15',
#   'volume': '3067064'},
#  '2016-04-13': {'open': '156.53',
#   'close': '159.85',
#   'high': '159.99',
#   'low': '156.38',
#   'volume': '5149910'},
#  '2016-04-12': {'open': '152.67',
#   'close': '154.31',
#   'high': '155.09',
#   'low': '151.30',
#   'volume': '2732861'},
#  '2016-04-11': {'open': '151.18',
#   'close': '152.20',
#   'high': '153.90',
#   'low': '150.41',
#   'volume': '3464286'},
#  '2016-04-08': {'open': '152.07',
#   'close': '150.28',
#   'high': '152.87',
#   'low': '150.01',
#   'volume': '3122198'},
#  '2016-04-07': {'open': '153.65',
#   'close': '150.41',
#   'high': '154.03',
#   'low': '149.37',
#   'volume': '4786630'},
#  '2016-04-06': {'open': '155.26',
#   'close': '155.19',
#   'high': '156.27',
#   'low': '153.92',
#   'volume': '2927106'},
#  '2016-04-05': {'open': '156.44',
#   'close': '155.35',
#   'high': '156.53',
#   'low': '154.55',
#   'volume': '2822612'},
#  '2016-04-04': {'open': '159.97',
#   'close': '157.77',
#   'high': '160.00',
#   'low': '157.39',
#   'volume': '2478545'},
#  '2016-04-01': {'open': '156.46',
#   'close': '159.82',
#   'high': '160.01',
#   'low': '155.09',
#   'volume': '3372048'},
#  '2016-03-31': {'open': '156.18',
#   'close': '156.98',
#   'high': '157.48',
#   'low': '156.06',
#   'volume': '2927046'},
#  '2016-03-30': {'open': '156.13',
#   'close': '156.50',
#   'high': '158.02',
#   'low': '154.89',
#   'volume': '3130594'},
#  '2016-03-29': {'open': '152.87',
#   'close': '155.03',
#   'high': '155.35',
#   'low': '151.50',
#   'volume': '2919290'},
#  '2016-03-28': {'open': '153.14',
#   'close': '153.84',
#   'high': '154.64',
#   'low': '152.38',
#   'volume': '2308573'},
#  '2016-03-24': {'open': '152.40',
#   'close': '153.00',
#   'high': '153.04',
#   'low': '150.13',
#   'volume': '3693399'},
#  '2016-03-23': {'open': '154.25',
#   'close': '154.08',
#   'high': '155.55',
#   'low': '153.59',
#   'volume': '3633242'},
#  '2016-03-22': {'open': '155.50',
#   'close': '154.20',
#   'high': '155.59',
#   'low': '153.36',
#   'volume': '3521394'},
#  '2016-03-21': {'open': '157.24',
#   'close': '156.29',
#   'high': '158.90',
#   'low': '155.75',
#   'volume': '4410029'},
#  '2016-03-18': {'open': '153.91',
#   'close': '157.60',
#   'high': '158.18',
#   'low': '153.87',
#   'volume': '7413169'},
#  '2016-03-17': {'open': '150.39',
#   'close': '152.91',
#   'high': '153.98',
#   'low': '148.75',
#   'volume': '2085484'},
#  ...}

# %%
df = df.astype('float')

# %%
df.pct_change()
# Out:
#                 open     close      high       low    volume
# 2020-03-06       NaN       NaN       NaN       NaN       NaN
# 2020-03-05  0.055853  0.030801  0.036526  0.040522 -0.181431
# 2020-03-04  0.022401  0.050053  0.026785  0.029195 -0.152071
# 2020-03-03  0.015352 -0.025438  0.013737 -0.002861  0.612680
# 2020-03-02 -0.036316  0.029691 -0.010246 -0.022215 -0.068991
# ...              ...       ...       ...       ...       ...
# 1999-05-10  0.048286 -0.001841  0.033319  0.010791  0.501165
# 1999-05-07 -0.074135  0.059433  0.016190 -0.049822  0.974024
# 1999-05-06  0.000883 -0.090374 -0.071094  0.004644 -0.499665
# 1999-05-05  0.023971  0.017515  0.003603 -0.011184  2.040906
# 1999-05-04  0.010771  0.018082  0.109436  0.055648  2.392750
#
# [5246 rows x 5 columns]
