# %%
import pandas as pd
import numpy as np
import requests

# %%
api_key='aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'

# %%
symbol = 'AAPL'

# %%
class Urls(Enum):
    STOCK_PRICE = 'https://financialmodelingprep.com/api/v3/historical-price-full'
    VOLUME_PRICE = 'https://financialmodelingprep.com/api/v3/volume-price-full'
    API_KEY = 'aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'


def get_data(symbol):
    
    return requests.get(f'https://api.worldtradingdata.com/api/v1/history?symbol={ticker}&api_token={Urls.API_KEY.value}').json()
        #f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={symbol}&outputsize=full&apikey={api_key}').json()

# %%
companies = []

# %%
tickers = ['F','GS']

# %%
for tick in tickers:
    res = get_data(tick)
    companies.append(pd.DataFrame(res['historical']).set_index('date'))

# %%
res = get_data('AAPL')['historical']

# %%
res
# Out:
# [{'date': '2015-03-09',
#   'open': 127.96,
#   'high': 129.57,
#   'low': 125.06,
#   'close': 127.14,
#   'adjClose': 117.63,
#   'volume': 88528500.0,
#   'unadjustedVolume': 88528500.0,
#   'change': 0.82,
#   'changePercent': 0.641,
#   'vwap': 127.25667,
#   'label': 'March 09, 15',
#   'changeOverTime': 0.00641},
#  {'date': '2015-03-10',
#   'open': 126.41,
#   'high': 127.22,
#   'low': 123.8,
#   'close': 124.51,
#   'adjClose': 115.2,
#   'volume': 68856600.0,
#   'unadjustedVolume': 68856600.0,
#   'change': 1.9,
#   'changePercent': 1.503,
#   'vwap': 125.17667,
#   'label': 'March 10, 15',
#   'changeOverTime': 0.01503},
#  {'date': '2015-03-11',
#   'open': 124.75,
#   'high': 124.77,
#   'low': 122.11,
#   'close': 122.24,
#   'adjClose': 113.1,
#   'volume': 68939000.0,
#   'unadjustedVolume': 68939000.0,
#   'change': 2.51,
#   'changePercent': 2.012,
#   'vwap': 123.04,
#   'label': 'March 11, 15',
#   'changeOverTime': 0.02012},
#  {'date': '2015-03-12',
#   'open': 122.31,
#   'high': 124.9,
#   'low': 121.63,
#   'close': 124.45,
#   'adjClose': 115.14,
#   'volume': 48362700.0,
#   'unadjustedVolume': 48362700.0,
#   'change': -2.14,
#   'changePercent': -1.75,
#   'vwap': 123.66,
#   'label': 'March 12, 15',
#   'changeOverTime': -0.0175},
#  {'date': '2015-03-13',
#   'open': 124.4,
#   'high': 125.4,
#   'low': 122.58,
#   'close': 123.59,
#   'adjClose': 114.35,
#   'volume': 51827300.0,
#   'unadjustedVolume': 51827300.0,
#   'change': 0.81,
#   'changePercent': 0.651,
#   'vwap': 123.85667,
#   'label': 'March 13, 15',
#   'changeOverTime': 0.00651},
#  {'date': '2015-03-16',
#   'open': 123.88,
#   'high': 124.95,
#   'low': 122.87,
#   'close': 124.95,
#   'adjClose': 115.61,
#   'volume': 35874300.0,
#   'unadjustedVolume': 35874300.0,
#   'change': -1.07,
#   'changePercent': -0.864,
#   'vwap': 124.25667,
#   'label': 'March 16, 15',
#   'changeOverTime': -0.00864},
#  {'date': '2015-03-17',
#   'open': 125.9,
#   'high': 127.32,
#   'low': 125.65,
#   'close': 127.04,
#   'adjClose': 117.54,
#   'volume': 51023100.0,
#   'unadjustedVolume': 51023100.0,
#   'change': -1.14,
#   'changePercent': -0.905,
#   'vwap': 126.67,
#   'label': 'March 17, 15',
#   'changeOverTime': -0.00905},
#  {'date': '2015-03-18',
#   'open': 127.0,
#   'high': 129.16,
#   'low': 126.37,
#   'close': 128.47,
#   'adjClose': 118.86,
#   'volume': 65270900.0,
#   'unadjustedVolume': 65270900.0,
#   'change': -1.47,
#   'changePercent': -1.157,
#   'vwap': 128.0,
#   'label': 'March 18, 15',
#   'changeOverTime': -0.01157},
#  {'date': '2015-03-19',
#   'open': 128.75,
#   'high': 129.25,
#   'low': 127.4,
#   'close': 127.5,
#   'adjClose': 117.96,
#   'volume': 45809500.0,
#   'unadjustedVolume': 45809500.0,
#   'change': 1.25,
#   'changePercent': 0.971,
#   'vwap': 128.05,
#   'label': 'March 19, 15',
#   'changeOverTime': 0.00971},
#  {'date': '2015-03-20',
#   'open': 128.25,
#   'high': 128.4,
#   'low': 125.16,
#   'close': 125.9,
#   'adjClose': 116.48,
#   'volume': 68695100.0,
#   'unadjustedVolume': 68695100.0,
#   'change': 2.35,
#   'changePercent': 1.832,
#   'vwap': 126.48667,
#   'label': 'March 20, 15',
#   'changeOverTime': 0.01832},
#  {'date': '2015-03-23',
#   'open': 127.12,
#   'high': 127.85,
#   'low': 126.52,
#   'close': 127.21,
#   'adjClose': 117.7,
#   'volume': 37709700.0,
#   'unadjustedVolume': 37709700.0,
#   'change': -0.09,
#   'changePercent': -0.071,
#   'vwap': 127.19333,
#   'label': 'March 23, 15',
#   'changeOverTime': -0.00071},
#  {'date': '2015-03-24',
#   'open': 127.23,
#   'high': 128.04,
#   'low': 126.56,
#   'close': 126.69,
#   'adjClose': 117.22,
#   'volume': 32842300.0,
#   'unadjustedVolume': 32842300.0,
#   'change': 0.54,
#   'changePercent': 0.424,
#   'vwap': 127.09667,
#   'label': 'March 24, 15',
#   'changeOverTime': 0.00424},
#  {'date': '2015-03-25',
#   'open': 126.54,
#   'high': 126.82,
#   'low': 123.38,
#   'close': 123.38,
#   'adjClose': 114.15,
#   'volume': 51655200.0,
#   'unadjustedVolume': 51655200.0,
#   'change': 3.16,
#   'changePercent': 2.497,
#   'vwap': 124.52667,
#   'label': 'March 25, 15',
#   'changeOverTime': 0.02497},
#  {'date': '2015-03-26',
#   'open': 122.76,
#   'high': 124.88,
#   'low': 122.6,
#   'close': 124.24,
#   'adjClose': 114.95,
#   'volume': 47572900.0,
#   'unadjustedVolume': 47572900.0,
#   'change': -1.48,
#   'changePercent': -1.206,
#   'vwap': 123.90667,
#   'label': 'March 26, 15',
#   'changeOverTime': -0.01206},
#  {'date': '2015-03-27',
#   'open': 124.57,
#   'high': 124.7,
#   'low': 122.91,
#   'close': 123.25,
#   'adjClose': 114.03,
#   'volume': 39546200.0,
#   'unadjustedVolume': 39546200.0,
#   'change': 1.32,
#   'changePercent': 1.06,
#   'vwap': 123.62,
#   'label': 'March 27, 15',
#   'changeOverTime': 0.0106},
#  {'date': '2015-03-30',
#   'open': 124.05,
#   'high': 126.4,
#   'low': 124.0,
#   'close': 126.37,
#   'adjClose': 116.92,
#   'volume': 47099700.0,
#   'unadjustedVolume': 47099700.0,
#   'change': -2.32,
#   'changePercent': -1.87,
#   'vwap': 125.59,
#   'label': 'March 30, 15',
#   'changeOverTime': -0.0187},
#  {'date': '2015-03-31',
#   'open': 126.09,
#   'high': 126.49,
#   'low': 124.36,
#   'close': 124.43,
#   'adjClose': 115.12,
#   'volume': 42090600.0,
#   'unadjustedVolume': 42090600.0,
#   'change': 1.66,
#   'changePercent': 1.317,
#   'vwap': 125.09333,
#   'label': 'March 31, 15',
#   'changeOverTime': 0.01317},
#  {'date': '2015-04-01',
#   'open': 124.82,
#   'high': 125.12,
#   'low': 123.1,
#   'close': 124.25,
#   'adjClose': 114.96,
#   'volume': 40621400.0,
#   'unadjustedVolume': 40621400.0,
#   'change': 0.57,
#   'changePercent': 0.457,
#   'vwap': 124.15667,
#   'label': 'April 01, 15',
#   'changeOverTime': 0.00457},
#  {'date': '2015-04-02',
#   'open': 125.03,
#   'high': 125.56,
#   'low': 124.19,
#   'close': 125.32,
#   'adjClose': 115.95,
#   'volume': 32220100.0,
#   'unadjustedVolume': 32220100.0,
#   'change': -0.29,
#   'changePercent': -0.232,
#   'vwap': 125.02333,
#   'label': 'April 02, 15',
#   'changeOverTime': -0.00232},
#  {'date': '2015-04-06',
#   'open': 124.47,
#   'high': 127.51,
#   'low': 124.33,
#   'close': 127.35,
#   'adjClose': 117.83,
#   'volume': 37194000.0,
#   'unadjustedVolume': 37194000.0,
#   'change': -2.88,
#   'changePercent': -2.314,
#   'vwap': 126.39667,
#   'label': 'April 06, 15',
#   'changeOverTime': -0.02314},
#  {'date': '2015-04-07',
#   'open': 127.64,
#   'high': 128.12,
#   'low': 125.98,
#   'close': 126.01,
#   'adjClose': 116.59,
#   'volume': 35012300.0,
#   'unadjustedVolume': 35012300.0,
#   'change': 1.63,
#   'changePercent': 1.277,
#   'vwap': 126.70333,
#   'label': 'April 07, 15',
#   'changeOverTime': 0.01277},
#  {'date': '2015-04-08',
#   'open': 125.85,
#   'high': 126.4,
#   'low': 124.97,
#   'close': 125.6,
#   'adjClose': 116.21,
#   'volume': 37329200.0,
#   'unadjustedVolume': 37329200.0,
#   'change': 0.25,
#   'changePercent': 0.199,
#   'vwap': 125.65667,
#   'label': 'April 08, 15',
#   'changeOverTime': 0.00199},
#  {'date': '2015-04-09',
#   'open': 125.85,
#   'high': 126.58,
#   'low': 124.66,
#   'close': 126.56,
#   'adjClose': 117.09,
#   'volume': 32484000.0,
#   'unadjustedVolume': 32484000.0,
#   'change': -0.71,
#   'changePercent': -0.564,
#   'vwap': 125.93333,
#   'label': 'April 09, 15',
#   'changeOverTime': -0.00564},
#  {'date': '2015-04-10',
#   'open': 125.95,
#   'high': 127.21,
#   'low': 125.26,
#   'close': 127.1,
#   'adjClose': 117.59,
#   'volume': 40188000.0,
#   'unadjustedVolume': 40188000.0,
#   'change': -1.15,
#   'changePercent': -0.913,
#   'vwap': 126.52333,
#   'label': 'April 10, 15',
#   'changeOverTime': -0.00913},
#  {'date': '2015-04-13',
#   'open': 128.37,
#   'high': 128.57,
#   'low': 126.61,
#   'close': 126.85,
#   'adjClose': 117.36,
#   'volume': 36365100.0,
#   'unadjustedVolume': 36365100.0,
#   'change': 1.52,
#   'changePercent': 1.184,
#   'vwap': 127.34333,
#   'label': 'April 13, 15',
#   'changeOverTime': 0.01184},
#  {'date': '2015-04-14',
#   'open': 127.0,
#   'high': 127.29,
#   'low': 125.91,
#   'close': 126.3,
#   'adjClose': 116.85,
#   'volume': 25524600.0,
#   'unadjustedVolume': 25524600.0,
#   'change': 0.7,
#   'changePercent': 0.551,
#   'vwap': 126.5,
#   'label': 'April 14, 15',
#   'changeOverTime': 0.00551},
#  {'date': '2015-04-15',
#   'open': 126.41,
#   'high': 127.13,
#   'low': 126.01,
#   'close': 126.78,
#   'adjClose': 117.3,
#   'volume': 28970400.0,
#   'unadjustedVolume': 28970400.0,
#   'change': -0.37,
#   'changePercent': -0.293,
#   'vwap': 126.64,
#   'label': 'April 15, 15',
#   'changeOverTime': -0.00293},
#  {'date': '2015-04-16',
#   'open': 126.28,
#   'high': 127.1,
#   'low': 126.11,
#   'close': 126.17,
#   'adjClose': 116.73,
#   'volume': 28369000.0,
#   'unadjustedVolume': 28369000.0,
#   'change': 0.11,
#   'changePercent': 0.087,
#   'vwap': 126.46,
#   'label': 'April 16, 15',
#   'changeOverTime': 0.00087},
#  {'date': '2015-04-17',
#   'open': 125.55,
#   'high': 126.14,
#   'low': 124.46,
#   'close': 124.75,
#   'adjClose': 115.42,
#   'volume': 51957000.0,
#   'unadjustedVolume': 51957000.0,
#   'change': 0.8,
#   'changePercent': 0.637,
#   'vwap': 125.11667,
#   'label': 'April 17, 15',
#   'changeOverTime': 0.00637},
#  {'date': '2015-04-20',
#   'open': 125.57,
#   'high': 128.12,
#   'low': 125.17,
#   'close': 127.6,
#   'adjClose': 118.06,
#   'volume': 47054300.0,
#   'unadjustedVolume': 47054300.0,
#   'change': -2.03,
#   'changePercent': -1.617,
#   'vwap': 126.96333,
#   'label': 'April 20, 15',
#   'changeOverTime': -0.01617},
#  {'date': '2015-04-21',
#   'open': 128.1,
#   'high': 128.2,
#   'low': 126.67,
#   'close': 126.91,
#   'adjClose': 117.42,
#   'volume': 32435100.0,
#   'unadjustedVolume': 32435100.0,
#   'change': 1.19,
#   'changePercent': 0.929,
#   'vwap': 127.26,
#   'label': 'April 21, 15',
#   'changeOverTime': 0.00929},
#  {'date': '2015-04-22',
#   'open': 126.99,
#   'high': 128.87,
#   'low': 126.32,
#   'close': 128.62,
#   'adjClose': 119.0,
#   'volume': 37654500.0,
#   'unadjustedVolume': 37654500.0,
#   'change': -1.63,
#   'changePercent': -1.284,
#   'vwap': 127.93667,
#   'label': 'April 22, 15',
#   'changeOverTime': -0.01284},
#  {'date': '2015-04-23',
#   'open': 128.3,
#   'high': 130.42,
#   'low': 128.14,
#   'close': 129.67,
#   'adjClose': 119.97,
#   'volume': 45770900.0,
#   'unadjustedVolume': 45770900.0,
#   'change': -1.37,
#   'changePercent': -1.068,
#   'vwap': 129.41,
#   'label': 'April 23, 15',
#   'changeOverTime': -0.01068},
#  {'date': '2015-04-24',
#   'open': 130.49,
#   'high': 130.63,
#   'low': 129.23,
#   'close': 130.28,
#   'adjClose': 120.54,
#   'volume': 44525900.0,
#   'unadjustedVolume': 44525900.0,
#   'change': 0.21,
#   'changePercent': 0.161,
#   'vwap': 130.04667,
#   'label': 'April 24, 15',
#   'changeOverTime': 0.00161},
#  {'date': '2015-04-27',
#   'open': 132.31,
#   'high': 133.13,
#   'low': 131.15,
#   'close': 132.65,
#   'adjClose': 122.73,
#   'volume': 96954200.0,
#   'unadjustedVolume': 96954200.0,
#   'change': -0.34,
#   'changePercent': -0.257,
#   'vwap': 132.31,
#   'label': 'April 27, 15',
#   'changeOverTime': -0.00257},
#  {'date': '2015-04-28',
#   'open': 134.46,
#   'high': 134.54,
#   'low': 129.57,
#   'close': 130.56,
#   'adjClose': 120.8,
#   'volume': 118924000.0,
#   'unadjustedVolume': 118924000.0,
#   'change': 3.9,
#   'changePercent': 2.9,
#   'vwap': 131.55667,
#   'label': 'April 28, 15',
#   'changeOverTime': 0.029},
#  {'date': '2015-04-29',
#   'open': 130.16,
#   'high': 131.59,
#   'low': 128.3,
#   'close': 128.64,
#   'adjClose': 119.02,
#   'volume': 63386100.0,
#   'unadjustedVolume': 63386100.0,
#   'change': 1.52,
#   'changePercent': 1.168,
#   'vwap': 129.51,
#   'label': 'April 29, 15',
#   'changeOverTime': 0.01168},
#  {'date': '2015-04-30',
#   'open': 128.64,
#   'high': 128.64,
#   'low': 124.58,
#   'close': 125.15,
#   'adjClose': 115.79,
#   'volume': 83195400.0,
#   'unadjustedVolume': 83195400.0,
#   'change': 3.49,
#   'changePercent': 2.713,
#   'vwap': 126.12333,
#   'label': 'April 30, 15',
#   'changeOverTime': 0.02713},
#  {'date': '2015-05-01',
#   'open': 126.1,
#   'high': 130.13,
#   'low': 125.3,
#   'close': 128.95,
#   'adjClose': 119.31,
#   'volume': 58512600.0,
#   'unadjustedVolume': 58512600.0,
#   'change': -2.85,
#   'changePercent': -2.26,
#   'vwap': 128.12667,
#   'label': 'May 01, 15',
#   'changeOverTime': -0.0226},
#  {'date': '2015-05-04',
#   'open': 129.5,
#   'high': 130.57,
#   'low': 128.26,
#   'close': 128.7,
#   'adjClose': 119.07,
#   'volume': 50988300.0,
#   'unadjustedVolume': 50988300.0,
#   'change': 0.8,
#   'changePercent': 0.618,
#   'vwap': 129.17667,
#   'label': 'May 04, 15',
#   'changeOverTime': 0.00618},
#  {'date': '2015-05-05',
#   'open': 128.15,
#   'high': 128.45,
#   'low': 125.78,
#   'close': 125.8,
#   'adjClose': 116.39,
#   'volume': 49271400.0,
#   'unadjustedVolume': 49271400.0,
#   'change': 2.35,
#   'changePercent': 1.834,
#   'vwap': 126.67667,
#   'label': 'May 05, 15',
#   'changeOverTime': 0.01834},
#  {'date': '2015-05-06',
#   'open': 126.56,
#   'high': 126.75,
#   'low': 123.36,
#   'close': 125.01,
#   'adjClose': 115.66,
#   'volume': 72141000.0,
#   'unadjustedVolume': 72141000.0,
#   'change': 1.55,
#   'changePercent': 1.225,
#   'vwap': 125.04,
#   'label': 'May 06, 15',
#   'changeOverTime': 0.01225},
#  {'date': '2015-05-07',
#   'open': 124.77,
#   'high': 126.08,
#   'low': 124.02,
#   'close': 125.26,
#   'adjClose': 116.38,
#   'volume': 43940900.0,
#   'unadjustedVolume': 43940900.0,
#   'change': -0.49,
#   'changePercent': -0.393,
#   'vwap': 125.12,
#   'label': 'May 07, 15',
#   'changeOverTime': -0.00393},
#  {'date': '2015-05-08',
#   'open': 126.68,
#   'high': 127.62,
#   'low': 126.11,
#   'close': 127.62,
#   'adjClose': 118.57,
#   'volume': 55550400.0,
#   'unadjustedVolume': 55550400.0,
#   'change': -0.94,
#   'changePercent': -0.742,
#   'vwap': 127.11667,
#   'label': 'May 08, 15',
#   'changeOverTime': -0.00742},
#  {'date': '2015-05-11',
#   'open': 127.39,
#   'high': 127.56,
#   'low': 125.63,
#   'close': 126.32,
#   'adjClose': 117.36,
#   'volume': 42035800.0,
#   'unadjustedVolume': 42035800.0,
#   'change': 1.07,
#   'changePercent': 0.84,
#   'vwap': 126.50333,
#   'label': 'May 11, 15',
#   'changeOverTime': 0.0084},
#  {'date': '2015-05-12',
#   'open': 125.6,
#   'high': 126.88,
#   'low': 124.82,
#   'close': 125.87,
#   'adjClose': 116.94,
#   'volume': 48160000.0,
#   'unadjustedVolume': 48160000.0,
#   'change': -0.27,
#   'changePercent': -0.215,
#   'vwap': 125.85667,
#   'label': 'May 12, 15',
#   'changeOverTime': -0.00215},
#  {'date': '2015-05-13',
#   'open': 126.15,
#   'high': 127.19,
#   'low': 125.87,
#   'close': 126.01,
#   'adjClose': 117.07,
#   'volume': 34694200.0,
#   'unadjustedVolume': 34694200.0,
#   'change': 0.14,
#   'changePercent': 0.111,
#   'vwap': 126.35667,
#   'label': 'May 13, 15',
#   'changeOverTime': 0.00111},
#  {'date': '2015-05-14',
#   'open': 127.41,
#   'high': 128.95,
#   'low': 127.16,
#   'close': 128.95,
#   'adjClose': 119.8,
#   'volume': 45203500.0,
#   'unadjustedVolume': 45203500.0,
#   'change': -1.54,
#   'changePercent': -1.209,
#   'vwap': 128.35333,
#   'label': 'May 14, 15',
#   'changeOverTime': -0.01209},
#  {'date': '2015-05-15',
#   'open': 129.07,
#   'high': 129.49,
#   'low': 128.21,
#   'close': 128.77,
#   'adjClose': 119.64,
#   'volume': 38208000.0,
#   'unadjustedVolume': 38208000.0,
#   'change': 0.3,
#   'changePercent': 0.232,
#   'vwap': 128.82333,
#   'label': 'May 15, 15',
#   'changeOverTime': 0.00232},
#  {'date': '2015-05-18',
#   'open': 128.38,
#   'high': 130.72,
#   'low': 128.36,
#   'close': 130.19,
#   'adjClose': 120.96,
#   'volume': 50882900.0,
#   'unadjustedVolume': 50882900.0,
#   'change': -1.81,
#   'changePercent': -1.41,
#   'vwap': 129.75667,
#   'label': 'May 18, 15',
#   'changeOverTime': -0.0141},
#  {'date': '2015-05-19',
#   'open': 130.69,
#   'high': 130.88,
#   'low': 129.64,
#   'close': 130.07,
#   'adjClose': 120.85,
#   'volume': 44633200.0,
#   'unadjustedVolume': 44633200.0,
#   'change': 0.62,
#   'changePercent': 0.474,
#   'vwap': 130.19667,
#   'label': 'May 19, 15',
#   'changeOverTime': 0.00474},
#  {'date': '2015-05-20',
#   'open': 130.0,
#   'high': 130.98,
#   'low': 129.34,
#   'close': 130.06,
#   'adjClose': 120.84,
#   'volume': 36454900.0,
#   'unadjustedVolume': 36454900.0,
#   'change': -0.06,
#   'changePercent': -0.046,
#   'vwap': 130.12667,
#   'label': 'May 20, 15',
#   'changeOverTime': -0.00046},
#  {'date': '2015-05-21',
#   'open': 130.07,
#   'high': 131.63,
#   'low': 129.83,
#   'close': 131.39,
#   'adjClose': 122.07,
#   'volume': 39730400.0,
#   'unadjustedVolume': 39730400.0,
#   'change': -1.32,
#   'changePercent': -1.015,
#   'vwap': 130.95,
#   'label': 'May 21, 15',
#   'changeOverTime': -0.01015},
#  {'date': '2015-05-22',
#   'open': 131.6,
#   'high': 132.97,
#   'low': 131.4,
#   'close': 132.54,
#   'adjClose': 123.14,
#   'volume': 45596000.0,
#   'unadjustedVolume': 45596000.0,
#   'change': -0.94,
#   'changePercent': -0.714,
#   'vwap': 132.30333,
#   'label': 'May 22, 15',
#   'changeOverTime': -0.00714},
#  {'date': '2015-05-26',
#   'open': 132.6,
#   'high': 132.91,
#   'low': 129.12,
#   'close': 129.62,
#   'adjClose': 120.43,
#   'volume': 70697600.0,
#   'unadjustedVolume': 70697600.0,
#   'change': 2.98,
#   'changePercent': 2.247,
#   'vwap': 130.55,
#   'label': 'May 26, 15',
#   'changeOverTime': 0.02247},
#  {'date': '2015-05-27',
#   'open': 130.34,
#   'high': 132.26,
#   'low': 130.05,
#   'close': 132.04,
#   'adjClose': 122.68,
#   'volume': 45833200.0,
#   'unadjustedVolume': 45833200.0,
#   'change': -1.7,
#   'changePercent': -1.304,
#   'vwap': 131.45,
#   'label': 'May 27, 15',
#   'changeOverTime': -0.01304},
#  {'date': '2015-05-28',
#   'open': 131.86,
#   'high': 131.95,
#   'low': 131.1,
#   'close': 131.78,
#   'adjClose': 122.43,
#   'volume': 30733300.0,
#   'unadjustedVolume': 30733300.0,
#   'change': 0.08,
#   'changePercent': 0.061,
#   'vwap': 131.61,
#   'label': 'May 28, 15',
#   'changeOverTime': 0.00061},
#  {'date': '2015-05-29',
#   'open': 131.23,
#   'high': 131.45,
#   'low': 129.9,
#   'close': 130.28,
#   'adjClose': 121.04,
#   'volume': 50884500.0,
#   'unadjustedVolume': 50884500.0,
#   'change': 0.95,
#   'changePercent': 0.724,
#   'vwap': 130.54333,
#   'label': 'May 29, 15',
#   'changeOverTime': 0.00724},
#  {'date': '2015-06-01',
#   'open': 130.28,
#   'high': 131.39,
#   'low': 130.05,
#   'close': 130.54,
#   'adjClose': 121.28,
#   'volume': 32112800.0,
#   'unadjustedVolume': 32112800.0,
#   'change': -0.26,
#   'changePercent': -0.2,
#   'vwap': 130.66,
#   'label': 'June 01, 15',
#   'changeOverTime': -0.002},
#  {'date': '2015-06-02',
#   'open': 129.86,
#   'high': 130.66,
#   'low': 129.32,
#   'close': 129.96,
#   'adjClose': 120.74,
#   'volume': 33667600.0,
#   'unadjustedVolume': 33667600.0,
#   'change': -0.1,
#   'changePercent': -0.077,
#   'vwap': 129.98,
#   'label': 'June 02, 15',
#   'changeOverTime': -0.00077},
#  {'date': '2015-06-03',
#   'open': 130.66,
#   'high': 130.94,
#   'low': 129.9,
#   'close': 130.12,
#   'adjClose': 120.89,
#   'volume': 30983500.0,
#   'unadjustedVolume': 30983500.0,
#   'change': 0.54,
#   'changePercent': 0.413,
#   'vwap': 130.32,
#   'label': 'June 03, 15',
#   'changeOverTime': 0.00413},
#  {'date': '2015-06-04',
#   'open': 129.58,
#   'high': 130.58,
#   'low': 128.91,
#   'close': 129.36,
#   'adjClose': 120.19,
#   'volume': 38450100.0,
#   'unadjustedVolume': 38450100.0,
#   'change': 0.22,
#   'changePercent': 0.17,
#   'vwap': 129.61667,
#   'label': 'June 04, 15',
#   'changeOverTime': 0.0017},
#  {'date': '2015-06-05',
#   'open': 129.5,
#   'high': 129.69,
#   'low': 128.36,
#   'close': 128.65,
#   'adjClose': 119.53,
#   'volume': 35626800.0,
#   'unadjustedVolume': 35626800.0,
#   'change': 0.85,
#   'changePercent': 0.656,
#   'vwap': 128.9,
#   'label': 'June 05, 15',
#   'changeOverTime': 0.00656},
#  {'date': '2015-06-08',
#   'open': 128.9,
#   'high': 129.21,
#   'low': 126.83,
#   'close': 127.8,
#   'adjClose': 118.74,
#   'volume': 52674800.0,
#   'unadjustedVolume': 52674800.0,
#   'change': 1.1,
#   'changePercent': 0.853,
#   'vwap': 127.94667,
#   'label': 'June 08, 15',
#   'changeOverTime': 0.00853},
#  {'date': '2015-06-09',
#   'open': 126.7,
#   'high': 128.08,
#   'low': 125.62,
#   'close': 127.42,
#   'adjClose': 118.38,
#   'volume': 56075400.0,
#   'unadjustedVolume': 56075400.0,
#   'change': -0.72,
#   'changePercent': -0.568,
#   'vwap': 127.04,
#   'label': 'June 09, 15',
#   'changeOverTime': -0.00568},
#  {'date': '2015-06-10',
#   'open': 127.92,
#   'high': 129.34,
#   'low': 127.85,
#   'close': 128.88,
#   'adjClose': 119.74,
#   'volume': 39087300.0,
#   'unadjustedVolume': 39087300.0,
#   'change': -0.96,
#   'changePercent': -0.75,
#   'vwap': 128.69,
#   'label': 'June 10, 15',
#   'changeOverTime': -0.0075},
#  {'date': '2015-06-11',
#   'open': 129.18,
#   'high': 130.18,
#   'low': 128.48,
#   'close': 128.59,
#   'adjClose': 119.47,
#   'volume': 35390900.0,
#   'unadjustedVolume': 35390900.0,
#   'change': 0.59,
#   'changePercent': 0.457,
#   'vwap': 129.08333,
#   'label': 'June 11, 15',
#   'changeOverTime': 0.00457},
#  {'date': '2015-06-12',
#   'open': 128.19,
#   'high': 128.33,
#   'low': 127.11,
#   'close': 127.17,
#   'adjClose': 118.15,
#   'volume': 36886200.0,
#   'unadjustedVolume': 36886200.0,
#   'change': 1.02,
#   'changePercent': 0.796,
#   'vwap': 127.53667,
#   'label': 'June 12, 15',
#   'changeOverTime': 0.00796},
#  {'date': '2015-06-15',
#   'open': 126.1,
#   'high': 127.24,
#   'low': 125.71,
#   'close': 126.92,
#   'adjClose': 117.92,
#   'volume': 43988900.0,
#   'unadjustedVolume': 43988900.0,
#   'change': -0.82,
#   'changePercent': -0.65,
#   'vwap': 126.62333,
#   'label': 'June 15, 15',
#   'changeOverTime': -0.0065},
#  {'date': '2015-06-16',
#   'open': 127.03,
#   'high': 127.85,
#   'low': 126.37,
#   'close': 127.6,
#   'adjClose': 118.55,
#   'volume': 31494100.0,
#   'unadjustedVolume': 31494100.0,
#   'change': -0.57,
#   'changePercent': -0.449,
#   'vwap': 127.27333,
#   'label': 'June 16, 15',
#   'changeOverTime': -0.00449},
#  {'date': '2015-06-17',
#   'open': 127.72,
#   'high': 127.88,
#   'low': 126.74,
#   'close': 127.3,
#   'adjClose': 118.27,
#   'volume': 32918100.0,
#   'unadjustedVolume': 32918100.0,
#   'change': 0.42,
#   'changePercent': 0.329,
#   'vwap': 127.30667,
#   'label': 'June 17, 15',
#   'changeOverTime': 0.00329},
#  {'date': '2015-06-18',
#   'open': 127.23,
#   'high': 128.31,
#   'low': 127.22,
#   'close': 127.88,
#   'adjClose': 118.81,
#   'volume': 35407200.0,
#   'unadjustedVolume': 35407200.0,
#   'change': -0.65,
#   'changePercent': -0.511,
#   'vwap': 127.80333,
#   'label': 'June 18, 15',
#   'changeOverTime': -0.00511},
#  {'date': '2015-06-19',
#   'open': 127.71,
#   'high': 127.82,
#   'low': 126.4,
#   'close': 126.6,
#   'adjClose': 117.62,
#   'volume': 54716900.0,
#   'unadjustedVolume': 54716900.0,
#   'change': 1.11,
#   'changePercent': 0.869,
#   'vwap': 126.94,
#   'label': 'June 19, 15',
#   'changeOverTime': 0.00869},
#  {'date': '2015-06-22',
#   'open': 127.49,
#   'high': 128.06,
#   'low': 127.08,
#   'close': 127.61,
#   'adjClose': 118.56,
#   'volume': 34039300.0,
#   'unadjustedVolume': 34039300.0,
#   'change': -0.12,
#   'changePercent': -0.094,
#   'vwap': 127.58333,
#   'label': 'June 22, 15',
#   'changeOverTime': -0.00094},
#  {'date': '2015-06-23',
#   'open': 127.48,
#   'high': 127.61,
#   'low': 126.88,
#   'close': 127.03,
#   'adjClose': 118.02,
#   'volume': 30268900.0,
#   'unadjustedVolume': 30268900.0,
#   'change': 0.45,
#   'changePercent': 0.353,
#   'vwap': 127.17333,
#   'label': 'June 23, 15',
#   'changeOverTime': 0.00353},
#  {'date': '2015-06-24',
#   'open': 127.21,
#   'high': 129.8,
#   'low': 127.12,
#   'close': 128.11,
#   'adjClose': 119.02,
#   'volume': 55280900.0,
#   'unadjustedVolume': 55280900.0,
#   'change': -0.9,
#   'changePercent': -0.707,
#   'vwap': 128.34333,
#   'label': 'June 24, 15',
#   'changeOverTime': -0.00707},
#  {'date': '2015-06-25',
#   'open': 128.86,
#   'high': 129.2,
#   'low': 127.5,
#   'close': 127.5,
#   'adjClose': 118.46,
#   'volume': 31938100.0,
#   'unadjustedVolume': 31938100.0,
#   'change': 1.36,
#   'changePercent': 1.055,
#   'vwap': 128.06667,
#   'label': 'June 25, 15',
#   'changeOverTime': 0.01055},
#  {'date': '2015-06-26',
#   'open': 127.67,
#   'high': 127.99,
#   'low': 126.51,
#   'close': 126.75,
#   'adjClose': 117.76,
#   'volume': 44066800.0,
#   'unadjustedVolume': 44066800.0,
#   'change': 0.92,
#   'changePercent': 0.721,
#   'vwap': 127.08333,
#   'label': 'June 26, 15',
#   'changeOverTime': 0.00721},
#  {'date': '2015-06-29',
#   'open': 125.46,
#   'high': 126.47,
#   'low': 124.48,
#   'close': 124.53,
#   'adjClose': 115.7,
#   'volume': 49161400.0,
#   'unadjustedVolume': 49161400.0,
#   'change': 0.93,
#   'changePercent': 0.741,
#   'vwap': 125.16,
#   'label': 'June 29, 15',
#   'changeOverTime': 0.00741},
#  {'date': '2015-06-30',
#   'open': 125.57,
#   'high': 126.12,
#   'low': 124.86,
#   'close': 125.43,
#   'adjClose': 116.53,
#   'volume': 44370700.0,
#   'unadjustedVolume': 44370700.0,
#   'change': 0.14,
#   'changePercent': 0.111,
#   'vwap': 125.47,
#   'label': 'June 30, 15',
#   'changeOverTime': 0.00111},
#  {'date': '2015-07-01',
#   'open': 126.9,
#   'high': 126.94,
#   'low': 125.99,
#   'close': 126.6,
#   'adjClose': 117.62,
#   'volume': 30238800.0,
#   'unadjustedVolume': 30238800.0,
#   'change': 0.3,
#   'changePercent': 0.236,
#   'vwap': 126.51,
#   'label': 'July 01, 15',
#   'changeOverTime': 0.00236},
#  {'date': '2015-07-02',
#   'open': 126.43,
#   'high': 126.69,
#   'low': 125.77,
#   'close': 126.44,
#   'adjClose': 117.47,
#   'volume': 27211000.0,
#   'unadjustedVolume': 27211000.0,
#   'change': -0.01,
#   'changePercent': -0.008,
#   'vwap': 126.3,
#   'label': 'July 02, 15',
#   'changeOverTime': -8e-05},
#  {'date': '2015-07-06',
#   'open': 124.94,
#   'high': 126.23,
#   'low': 124.85,
#   'close': 126.0,
#   'adjClose': 117.06,
#   'volume': 28060400.0,
#   'unadjustedVolume': 28060400.0,
#   'change': -1.06,
#   'changePercent': -0.848,
#   'vwap': 125.69333,
#   'label': 'July 06, 15',
#   'changeOverTime': -0.00848},
#  {'date': '2015-07-07',
#   'open': 125.89,
#   'high': 126.15,
#   'low': 123.77,
#   'close': 125.69,
#   'adjClose': 116.78,
#   'volume': 46946800.0,
#   'unadjustedVolume': 46946800.0,
#   'change': 0.2,
#   'changePercent': 0.159,
#   'vwap': 125.20333,
#   'label': 'July 07, 15',
#   'changeOverTime': 0.00159},
#  {'date': '2015-07-08',
#   'open': 124.48,
#   'high': 124.64,
#   'low': 122.54,
#   'close': 122.57,
#   'adjClose': 113.88,
#   'volume': 60761600.0,
#   'unadjustedVolume': 60761600.0,
#   'change': 1.91,
#   'changePercent': 1.534,
#   'vwap': 123.25,
#   'label': 'July 08, 15',
#   'changeOverTime': 0.01534},
#  {'date': '2015-07-09',
#   'open': 123.85,
#   'high': 124.06,
#   'low': 119.22,
#   'close': 120.07,
#   'adjClose': 111.55,
#   'volume': 78595000.0,
#   'unadjustedVolume': 78595000.0,
#   'change': 3.78,
#   'changePercent': 3.052,
#   'vwap': 121.11667,
#   'label': 'July 09, 15',
#   'changeOverTime': 0.03052},
#  {'date': '2015-07-10',
#   'open': 121.94,
#   'high': 123.85,
#   'low': 121.21,
#   'close': 123.28,
#   'adjClose': 114.54,
#   'volume': 61354500.0,
#   'unadjustedVolume': 61354500.0,
#   'change': -1.34,
#   'changePercent': -1.099,
#   'vwap': 122.78,
#   'label': 'July 10, 15',
#   'changeOverTime': -0.01099},
#  {'date': '2015-07-13',
#   'open': 125.03,
#   'high': 125.76,
#   'low': 124.32,
#   'close': 125.66,
#   'adjClose': 116.75,
#   'volume': 41440500.0,
#   'unadjustedVolume': 41440500.0,
#   'change': -0.63,
#   'changePercent': -0.504,
#   'vwap': 125.24667,
#   'label': 'July 13, 15',
#   'changeOverTime': -0.00504},
#  {'date': '2015-07-14',
#   'open': 126.04,
#   'high': 126.37,
#   'low': 125.04,
#   'close': 125.61,
#   'adjClose': 116.7,
#   'volume': 31768100.0,
#   'unadjustedVolume': 31768100.0,
#   'change': 0.43,
#   'changePercent': 0.341,
#   'vwap': 125.67333,
#   'label': 'July 14, 15',
#   'changeOverTime': 0.00341},
#  {'date': '2015-07-15',
#   'open': 125.72,
#   'high': 127.15,
#   'low': 125.58,
#   'close': 126.82,
#   'adjClose': 117.83,
#   'volume': 33649200.0,
#   'unadjustedVolume': 33649200.0,
#   'change': -1.1,
#   'changePercent': -0.875,
#   'vwap': 126.51667,
#   'label': 'July 15, 15',
#   'changeOverTime': -0.00875},
#  {'date': '2015-07-16',
#   'open': 127.74,
#   'high': 128.57,
#   'low': 127.35,
#   'close': 128.51,
#   'adjClose': 119.4,
#   'volume': 36222400.0,
#   'unadjustedVolume': 36222400.0,
#   'change': -0.77,
#   'changePercent': -0.603,
#   'vwap': 128.14333,
#   'label': 'July 16, 15',
#   'changeOverTime': -0.00603},
#  {'date': '2015-07-17',
#   'open': 129.08,
#   'high': 129.62,
#   'low': 128.31,
#   'close': 129.62,
#   'adjClose': 120.43,
#   'volume': 46164700.0,
#   'unadjustedVolume': 46164700.0,
#   'change': -0.54,
#   'changePercent': -0.418,
#   'vwap': 129.18333,
#   'label': 'July 17, 15',
#   'changeOverTime': -0.00418},
#  {'date': '2015-07-20',
#   'open': 130.97,
#   'high': 132.97,
#   'low': 130.7,
#   'close': 132.07,
#   'adjClose': 122.7,
#   'volume': 58900200.0,
#   'unadjustedVolume': 58900200.0,
#   'change': -1.1,
#   'changePercent': -0.84,
#   'vwap': 131.91333,
#   'label': 'July 20, 15',
#   'changeOverTime': -0.0084},
#  {'date': '2015-07-21',
#   'open': 132.85,
#   'high': 132.92,
#   'low': 130.32,
#   'close': 130.75,
#   'adjClose': 121.48,
#   'volume': 76756400.0,
#   'unadjustedVolume': 76756400.0,
#   'change': 2.1,
#   'changePercent': 1.581,
#   'vwap': 131.33,
#   'label': 'July 21, 15',
#   'changeOverTime': 0.01581},
#  {'date': '2015-07-22',
#   'open': 121.99,
#   'high': 125.5,
#   'low': 121.99,
#   'close': 125.22,
#   'adjClose': 116.34,
#   'volume': 115450600.0,
#   'unadjustedVolume': 115450600.0,
#   'change': -3.23,
#   'changePercent': -2.648,
#   'vwap': 124.23667,
#   'label': 'July 22, 15',
#   'changeOverTime': -0.02648},
#  {'date': '2015-07-23',
#   'open': 126.2,
#   'high': 127.09,
#   'low': 125.06,
#   'close': 125.16,
#   'adjClose': 116.28,
#   'volume': 50999500.0,
#   'unadjustedVolume': 50999500.0,
#   'change': 1.04,
#   'changePercent': 0.824,
#   'vwap': 125.77,
#   'label': 'July 23, 15',
#   'changeOverTime': 0.00824},
#  {'date': '2015-07-24',
#   'open': 125.32,
#   'high': 125.74,
#   'low': 123.9,
#   'close': 124.5,
#   'adjClose': 115.67,
#   'volume': 42162300.0,
#   'unadjustedVolume': 42162300.0,
#   'change': 0.82,
#   'changePercent': 0.654,
#   'vwap': 124.71333,
#   'label': 'July 24, 15',
#   'changeOverTime': 0.00654},
#  {'date': '2015-07-27',
#   'open': 123.09,
#   'high': 123.61,
#   'low': 122.12,
#   'close': 122.77,
#   'adjClose': 114.06,
#   'volume': 44455500.0,
#   'unadjustedVolume': 44455500.0,
#   'change': 0.32,
#   'changePercent': 0.26,
#   'vwap': 122.83333,
#   'label': 'July 27, 15',
#   'changeOverTime': 0.0026},
#  {'date': '2015-07-28',
#   'open': 123.38,
#   'high': 123.91,
#   'low': 122.55,
#   'close': 123.38,
#   'adjClose': 114.63,
#   'volume': 33618100.0,
#   'unadjustedVolume': 33618100.0,
#   'change': 0.0,
#   'changePercent': 0.0,
#   'vwap': 123.28,
#   'label': 'July 28, 15',
#   'changeOverTime': 0.0},
#  {'date': '2015-07-29',
#   'open': 123.15,
#   'high': 123.5,
#   'low': 122.27,
#   'close': 122.99,
#   'adjClose': 114.27,
#   'volume': 37011700.0,
#   'unadjustedVolume': 37011700.0,
#   'change': 0.16,
#   'changePercent': 0.13,
#   'vwap': 122.92,
#   'label': 'July 29, 15',
#   'changeOverTime': 0.0013},
#  {'date': '2015-07-30',
#   'open': 122.32,
#   'high': 122.57,
#   'low': 121.71,
#   'close': 122.37,
#   'adjClose': 113.69,
#   'volume': 33628300.0,
#   'unadjustedVolume': 33628300.0,
#   'change': -0.05,
#   'changePercent': -0.041,
#   'vwap': 122.21667,
#   'label': 'July 30, 15',
#   'changeOverTime': -0.00041},
#  {'date': '2015-07-31',
#   'open': 122.6,
#   'high': 122.64,
#   'low': 120.91,
#   'close': 121.3,
#   'adjClose': 112.7,
#   'volume': 42885000.0,
#   'unadjustedVolume': 42885000.0,
#   'change': 1.3,
#   'changePercent': 1.06,
#   'vwap': 121.61667,
#   'label': 'July 31, 15',
#   'changeOverTime': 0.0106},
#  {'date': '2015-08-03',
#   'open': 121.5,
#   'high': 122.57,
#   'low': 117.52,
#   'close': 118.44,
#   'adjClose': 110.04,
#   'volume': 69976000.0,
#   'unadjustedVolume': 69976000.0,
#   'change': 3.06,
#   'changePercent': 2.519,
#   'vwap': 119.51,
#   'label': 'August 03, 15',
#   'changeOverTime': 0.02519},
#  {'date': '2015-08-04',
#   'open': 117.42,
#   'high': 117.7,
#   'low': 113.25,
#   'close': 114.64,
#   'adjClose': 106.51,
#   'volume': 124138600.0,
#   'unadjustedVolume': 124138600.0,
#   'change': 2.78,
#   'changePercent': 2.368,
#   'vwap': 115.19667,
#   'label': 'August 04, 15',
#   'changeOverTime': 0.02368},
#  {'date': '2015-08-05',
#   'open': 112.95,
#   'high': 117.44,
#   'low': 112.1,
#   'close': 115.4,
#   'adjClose': 107.22,
#   'volume': 99312600.0,
#   'unadjustedVolume': 99312600.0,
#   'change': -2.45,
#   'changePercent': -2.169,
#   'vwap': 114.98,
#   'label': 'August 05, 15',
#   'changeOverTime': -0.02169},
#  {'date': '2015-08-06',
#   'open': 115.97,
#   'high': 116.5,
#   'low': 114.12,
#   'close': 115.13,
#   'adjClose': 107.45,
#   'volume': 52903000.0,
#   'unadjustedVolume': 52903000.0,
#   'change': 0.84,
#   'changePercent': 0.724,
#   'vwap': 115.25,
#   'label': 'August 06, 15',
#   'changeOverTime': 0.00724},
#  {'date': '2015-08-07',
#   'open': 114.58,
#   'high': 116.25,
#   'low': 114.5,
#   'close': 115.52,
#   'adjClose': 107.81,
#   'volume': 38670400.0,
#   'unadjustedVolume': 38670400.0,
#   'change': -0.94,
#   'changePercent': -0.82,
#   'vwap': 115.42333,
#   'label': 'August 07, 15',
#   'changeOverTime': -0.0082},
#  {'date': '2015-08-10',
#   'open': 116.53,
#   'high': 119.99,
#   'low': 116.53,
#   'close': 119.72,
#   'adjClose': 111.73,
#   'volume': 54951600.0,
#   'unadjustedVolume': 54951600.0,
#   'change': -3.19,
#   'changePercent': -2.737,
#   'vwap': 118.74667,
#   'label': 'August 10, 15',
#   'changeOverTime': -0.02737},
#  {'date': '2015-08-11',
#   'open': 117.81,
#   'high': 118.18,
#   'low': 113.33,
#   'close': 113.49,
#   'adjClose': 105.92,
#   'volume': 97082800.0,
#   'unadjustedVolume': 97082800.0,
#   'change': 4.32,
#   'changePercent': 3.667,
#   'vwap': 115.0,
#   'label': 'August 11, 15',
#   'changeOverTime': 0.03667},
#  {'date': '2015-08-12',
#   'open': 112.53,
#   'high': 115.42,
#   'low': 109.63,
#   'close': 115.24,
#   'adjClose': 107.55,
#   'volume': 101217500.0,
#   'unadjustedVolume': 101217500.0,
#   'change': -2.71,
#   'changePercent': -2.408,
#   'vwap': 113.43,
#   'label': 'August 12, 15',
#   'changeOverTime': -0.02408},
#  {'date': '2015-08-13',
#   'open': 116.04,
#   'high': 116.4,
#   'low': 114.54,
#   'close': 115.15,
#   'adjClose': 107.47,
#   'volume': 48535800.0,
#   'unadjustedVolume': 48535800.0,
#   'change': 0.89,
#   'changePercent': 0.767,
#   'vwap': 115.36333,
#   'label': 'August 13, 15',
#   'changeOverTime': 0.00767},
#  {'date': '2015-08-14',
#   'open': 114.32,
#   'high': 116.31,
#   'low': 114.01,
#   'close': 115.96,
#   'adjClose': 108.22,
#   'volume': 42929500.0,
#   'unadjustedVolume': 42929500.0,
#   'change': -1.64,
#   'changePercent': -1.435,
#   'vwap': 115.42667,
#   'label': 'August 14, 15',
#   'changeOverTime': -0.01435},
#  {'date': '2015-08-17',
#   'open': 116.04,
#   'high': 117.65,
#   'low': 115.5,
#   'close': 117.16,
#   'adjClose': 109.34,
#   'volume': 40884700.0,
#   'unadjustedVolume': 40884700.0,
#   'change': -1.12,
#   'changePercent': -0.965,
#   'vwap': 116.77,
#   'label': 'August 17, 15',
#   'changeOverTime': -0.00965},
#  {'date': '2015-08-18',
#   'open': 116.43,
#   'high': 117.44,
#   'low': 116.01,
#   'close': 116.5,
#   'adjClose': 108.73,
#   'volume': 34560700.0,
#   'unadjustedVolume': 34560700.0,
#   'change': -0.07,
#   'changePercent': -0.06,
#   'vwap': 116.65,
#   'label': 'August 18, 15',
#   'changeOverTime': -0.0006},
#  {'date': '2015-08-19',
#   'open': 116.1,
#   'high': 116.52,
#   'low': 114.68,
#   'close': 115.01,
#   'adjClose': 107.34,
#   'volume': 48286500.0,
#   'unadjustedVolume': 48286500.0,
#   'change': 1.09,
#   'changePercent': 0.939,
#   'vwap': 115.40333,
#   'label': 'August 19, 15',
#   'changeOverTime': 0.00939},
#  {'date': '2015-08-20',
#   'open': 114.08,
#   'high': 114.35,
#   'low': 111.63,
#   'close': 112.65,
#   'adjClose': 105.13,
#   'volume': 68501600.0,
#   'unadjustedVolume': 68501600.0,
#   'change': 1.43,
#   'changePercent': 1.254,
#   'vwap': 112.87667,
#   'label': 'August 20, 15',
#   'changeOverTime': 0.01254},
#  {'date': '2015-08-21',
#   'open': 110.43,
#   'high': 111.9,
#   'low': 105.65,
#   'close': 105.76,
#   'adjClose': 98.7,
#   'volume': 128275500.0,
#   'unadjustedVolume': 128275500.0,
#   'change': 4.67,
#   'changePercent': 4.229,
#   'vwap': 107.77,
#   'label': 'August 21, 15',
#   'changeOverTime': 0.04229},
#  {'date': '2015-08-24',
#   'open': 94.87,
#   'high': 108.8,
#   'low': 92.0,
#   'close': 103.12,
#   'adjClose': 96.24,
#   'volume': 162206300.0,
#   'unadjustedVolume': 162206300.0,
#   'change': -8.25,
#   'changePercent': -8.696,
#   'vwap': 101.30667,
#   'label': 'August 24, 15',
#   'changeOverTime': -0.08696},
#  {'date': '2015-08-25',
#   'open': 111.11,
#   'high': 111.11,
#   'low': 103.5,
#   'close': 103.74,
#   'adjClose': 96.82,
#   'volume': 103601600.0,
#   'unadjustedVolume': 103601600.0,
#   'change': 7.37,
#   'changePercent': 6.633,
#   'vwap': 106.11667,
#   'label': 'August 25, 15',
#   'changeOverTime': 0.06633},
#  {'date': '2015-08-26',
#   'open': 107.09,
#   'high': 109.89,
#   'low': 105.05,
#   'close': 109.69,
#   'adjClose': 102.37,
#   'volume': 96774600.0,
#   'unadjustedVolume': 96774600.0,
#   'change': -2.6,
#   'changePercent': -2.428,
#   'vwap': 108.21,
#   'label': 'August 26, 15',
#   'changeOverTime': -0.02428},
#  {'date': '2015-08-27',
#   'open': 112.23,
#   'high': 113.24,
#   'low': 110.02,
#   'close': 112.92,
#   'adjClose': 105.39,
#   'volume': 84616100.0,
#   'unadjustedVolume': 84616100.0,
#   'change': -0.69,
#   'changePercent': -0.615,
#   'vwap': 112.06,
#   'label': 'August 27, 15',
#   'changeOverTime': -0.00615},
#  {'date': '2015-08-28',
#   'open': 112.17,
#   'high': 113.31,
#   'low': 111.54,
#   'close': 113.29,
#   'adjClose': 105.73,
#   'volume': 53164400.0,
#   'unadjustedVolume': 53164400.0,
#   'change': -1.12,
#   'changePercent': -0.998,
#   'vwap': 112.71333,
#   'label': 'August 28, 15',
#   'changeOverTime': -0.00998},
#  {'date': '2015-08-31',
#   'open': 112.03,
#   'high': 114.53,
#   'low': 112.0,
#   'close': 112.76,
#   'adjClose': 105.24,
#   'volume': 56229300.0,
#   'unadjustedVolume': 56229300.0,
#   'change': -0.73,
#   'changePercent': -0.652,
#   'vwap': 113.09667,
#   'label': 'August 31, 15',
#   'changeOverTime': -0.00652},
#  {'date': '2015-09-01',
#   'open': 110.15,
#   'high': 111.88,
#   'low': 107.36,
#   'close': 107.72,
#   'adjClose': 100.53,
#   'volume': 76845900.0,
#   'unadjustedVolume': 76845900.0,
#   'change': 2.43,
#   'changePercent': 2.206,
#   'vwap': 108.98667,
#   'label': 'September 01, 15',
#   'changeOverTime': 0.02206},
#  {'date': '2015-09-02',
#   'open': 110.23,
#   'high': 112.34,
#   'low': 109.13,
#   'close': 112.34,
#   'adjClose': 104.85,
#   'volume': 61888800.0,
#   'unadjustedVolume': 61888800.0,
#   'change': -2.11,
#   'changePercent': -1.914,
#   'vwap': 111.27,
#   'label': 'September 02, 15',
#   'changeOverTime': -0.01914},
#  {'date': '2015-09-03',
#   'open': 112.49,
#   'high': 112.78,
#   'low': 110.04,
#   'close': 110.37,
#   'adjClose': 103.01,
#   'volume': 53233900.0,
#   'unadjustedVolume': 53233900.0,
#   'change': 2.12,
#   'changePercent': 1.885,
#   'vwap': 111.06333,
#   'label': 'September 03, 15',
#   'changeOverTime': 0.01885},
#  {'date': '2015-09-04',
#   'open': 108.97,
#   'high': 110.45,
#   'low': 108.51,
#   'close': 109.27,
#   'adjClose': 101.98,
#   'volume': 49996300.0,
#   'unadjustedVolume': 49996300.0,
#   'change': -0.3,
#   'changePercent': -0.275,
#   'vwap': 109.41,
#   'label': 'September 04, 15',
#   'changeOverTime': -0.00275},
#  {'date': '2015-09-08',
#   'open': 111.75,
#   'high': 112.56,
#   'low': 110.32,
#   'close': 112.31,
#   'adjClose': 104.82,
#   'volume': 54843600.0,
#   'unadjustedVolume': 54843600.0,
#   'change': -0.56,
#   'changePercent': -0.501,
#   'vwap': 111.73,
#   'label': 'September 08, 15',
#   'changeOverTime': -0.00501},
#  {'date': '2015-09-09',
#   'open': 113.76,
#   'high': 114.02,
#   'low': 109.77,
#   'close': 110.15,
#   'adjClose': 102.8,
#   'volume': 85010800.0,
#   'unadjustedVolume': 85010800.0,
#   'change': 3.61,
#   'changePercent': 3.173,
#   'vwap': 111.31333,
#   'label': 'September 09, 15',
#   'changeOverTime': 0.03173},
#  {'date': '2015-09-10',
#   'open': 110.27,
#   'high': 113.28,
#   'low': 109.9,
#   'close': 112.57,
#   'adjClose': 105.06,
#   'volume': 62892800.0,
#   'unadjustedVolume': 62892800.0,
#   'change': -2.3,
#   'changePercent': -2.086,
#   'vwap': 111.91667,
#   'label': 'September 10, 15',
#   'changeOverTime': -0.02086},
#  {'date': '2015-09-11',
#   'open': 111.79,
#   'high': 114.21,
#   'low': 111.76,
#   'close': 114.21,
#   'adjClose': 106.59,
#   'volume': 49915500.0,
#   'unadjustedVolume': 49915500.0,
#   'change': -2.42,
#   'changePercent': -2.165,
#   'vwap': 113.39333,
#   'label': 'September 11, 15',
#   'changeOverTime': -0.02165},
#  {'date': '2015-09-14',
#   'open': 116.58,
#   'high': 116.89,
#   'low': 114.86,
#   'close': 115.31,
#   'adjClose': 107.62,
#   'volume': 58363400.0,
#   'unadjustedVolume': 58363400.0,
#   'change': 1.27,
#   'changePercent': 1.089,
#   'vwap': 115.68667,
#   'label': 'September 14, 15',
#   'changeOverTime': 0.01089},
#  {'date': '2015-09-15',
#   'open': 115.93,
#   'high': 116.53,
#   'low': 114.42,
#   'close': 116.28,
#   'adjClose': 108.52,
#   'volume': 43341200.0,
#   'unadjustedVolume': 43341200.0,
#   'change': -0.35,
#   'changePercent': -0.302,
#   'vwap': 115.74333,
#   'label': 'September 15, 15',
#   'changeOverTime': -0.00302},
#  {'date': '2015-09-16',
#   'open': 116.25,
#   'high': 116.54,
#   'low': 115.44,
#   'close': 116.41,
#   'adjClose': 108.64,
#   'volume': 37173500.0,
#   'unadjustedVolume': 37173500.0,
#   'change': -0.16,
#   'changePercent': -0.138,
#   'vwap': 116.13,
#   'label': 'September 16, 15',
#   'changeOverTime': -0.00138},
#  {'date': '2015-09-17',
#   'open': 115.66,
#   'high': 116.49,
#   'low': 113.72,
#   'close': 113.92,
#   'adjClose': 106.32,
#   'volume': 64112600.0,
#   'unadjustedVolume': 64112600.0,
#   'change': 1.74,
#   'changePercent': 1.504,
#   'vwap': 114.71,
#   'label': 'September 17, 15',
#   'changeOverTime': 0.01504},
#  {'date': '2015-09-18',
#   'open': 112.21,
#   'high': 114.3,
#   'low': 111.87,
#   'close': 113.45,
#   'adjClose': 105.88,
#   'volume': 74285300.0,
#   'unadjustedVolume': 74285300.0,
#   'change': -1.24,
#   'changePercent': -1.105,
#   'vwap': 113.20667,
#   'label': 'September 18, 15',
#   'changeOverTime': -0.01105},
#  {'date': '2015-09-21',
#   'open': 113.67,
#   'high': 115.37,
#   'low': 113.66,
#   'close': 115.21,
#   'adjClose': 107.52,
#   'volume': 50222000.0,
#   'unadjustedVolume': 50222000.0,
#   'change': -1.54,
#   'changePercent': -1.355,
#   'vwap': 114.74667,
#   'label': 'September 21, 15',
#   'changeOverTime': -0.01355},
#  {'date': '2015-09-22',
#   'open': 113.38,
#   'high': 114.18,
#   'low': 112.52,
#   'close': 113.4,
#   'adjClose': 105.83,
#   'volume': 50346200.0,
#   'unadjustedVolume': 50346200.0,
#   'change': -0.02,
#   'changePercent': -0.018,
#   'vwap': 113.36667,
#   'label': 'September 22, 15',
#   'changeOverTime': -0.00018},
#  {'date': '2015-09-23',
#   'open': 113.63,
#   'high': 114.72,
#   'low': 113.3,
#   'close': 114.32,
#   'adjClose': 106.69,
#   'volume': 35756700.0,
#   'unadjustedVolume': 35756700.0,
#   'change': -0.69,
#   'changePercent': -0.607,
#   'vwap': 114.11333,
#   'label': 'September 23, 15',
#   'changeOverTime': -0.00607},
#  {'date': '2015-09-24',
#   'open': 113.25,
#   'high': 115.5,
#   'low': 112.37,
#   'close': 115.0,
#   'adjClose': 107.33,
#   'volume': 50219500.0,
#   'unadjustedVolume': 50219500.0,
#   'change': -1.75,
#   'changePercent': -1.545,
#   'vwap': 114.29,
#   'label': 'September 24, 15',
#   'changeOverTime': -0.01545},
#  {'date': '2015-09-25',
#   'open': 116.44,
#   'high': 116.69,
#   'low': 114.02,
#   'close': 114.71,
#   'adjClose': 107.06,
#   'volume': 56151900.0,
#   'unadjustedVolume': 56151900.0,
#   'change': 1.73,
#   'changePercent': 1.486,
#   'vwap': 115.14,
#   'label': 'September 25, 15',
#   'changeOverTime': 0.01486},
#  {'date': '2015-09-28',
#   'open': 113.85,
#   'high': 114.57,
#   'low': 112.44,
#   'close': 112.44,
#   'adjClose': 104.94,
#   'volume': 52109000.0,
#   'unadjustedVolume': 52109000.0,
#   'change': 1.41,
#   'changePercent': 1.238,
#   'vwap': 113.15,
#   'label': 'September 28, 15',
#   'changeOverTime': 0.01238},
#  {'date': '2015-09-29',
#   'open': 112.83,
#   'high': 113.51,
#   'low': 107.86,
#   'close': 109.06,
#   'adjClose': 101.78,
#   'volume': 73365400.0,
#   'unadjustedVolume': 73365400.0,
#   'change': 3.77,
#   'changePercent': 3.341,
#   'vwap': 110.14333,
#   'label': 'September 29, 15',
#   'changeOverTime': 0.03341},
#  {'date': '2015-09-30',
#   'open': 110.17,
#   'high': 111.54,
#   'low': 108.73,
#   'close': 110.3,
#   'adjClose': 102.94,
#   'volume': 66473000.0,
#   'unadjustedVolume': 66473000.0,
#   'change': -0.13,
#   'changePercent': -0.118,
#   'vwap': 110.19,
#   'label': 'September 30, 15',
#   'changeOverTime': -0.00118},
#  {'date': '2015-10-01',
#   'open': 109.07,
#   'high': 109.62,
#   'low': 107.31,
#   'close': 109.58,
#   'adjClose': 102.27,
#   'volume': 63929100.0,
#   'unadjustedVolume': 63929100.0,
#   'change': -0.51,
#   'changePercent': -0.468,
#   'vwap': 108.83667,
#   'label': 'October 01, 15',
#   'changeOverTime': -0.00468},
#  {'date': '2015-10-02',
#   'open': 108.01,
#   'high': 111.01,
#   'low': 107.55,
#   'close': 110.38,
#   'adjClose': 103.02,
#   'volume': 58019800.0,
#   'unadjustedVolume': 58019800.0,
#   'change': -2.37,
#   'changePercent': -2.194,
#   'vwap': 109.64667,
#   'label': 'October 02, 15',
#   'changeOverTime': -0.02194},
#  {'date': '2015-10-05',
#   'open': 109.88,
#   'high': 111.37,
#   'low': 109.07,
#   'close': 110.78,
#   'adjClose': 103.39,
#   'volume': 52064700.0,
#   'unadjustedVolume': 52064700.0,
#   'change': -0.9,
#   'changePercent': -0.819,
#   'vwap': 110.40667,
#   'label': 'October 05, 15',
#   'changeOverTime': -0.00819},
#  {'date': '2015-10-06',
#   'open': 110.63,
#   'high': 111.74,
#   'low': 109.77,
#   'close': 111.31,
#   'adjClose': 103.88,
#   'volume': 48196800.0,
#   'unadjustedVolume': 48196800.0,
#   'change': -0.68,
#   'changePercent': -0.615,
#   'vwap': 110.94,
#   'label': 'October 06, 15',
#   'changeOverTime': -0.00615},
#  {'date': '2015-10-07',
#   'open': 111.74,
#   'high': 111.77,
#   'low': 109.41,
#   'close': 110.78,
#   'adjClose': 103.39,
#   'volume': 46765600.0,
#   'unadjustedVolume': 46765600.0,
#   'change': 0.96,
#   'changePercent': 0.859,
#   'vwap': 110.65333,
#   'label': 'October 07, 15',
#   'changeOverTime': 0.00859},
#  {'date': '2015-10-08',
#   'open': 110.19,
#   'high': 110.19,
#   'low': 108.21,
#   'close': 109.5,
#   'adjClose': 102.19,
#   'volume': 61979600.0,
#   'unadjustedVolume': 61979600.0,
#   'change': 0.69,
#   'changePercent': 0.626,
#   'vwap': 109.3,
#   'label': 'October 08, 15',
#   'changeOverTime': 0.00626},
#  {'date': '2015-10-09',
#   'open': 110.0,
#   'high': 112.28,
#   'low': 109.49,
#   'close': 112.12,
#   'adjClose': 104.64,
#   'volume': 52766100.0,
#   'unadjustedVolume': 52766100.0,
#   'change': -2.12,
#   'changePercent': -1.927,
#   'vwap': 111.29667,
#   'label': 'October 09, 15',
#   'changeOverTime': -0.01927},
#  {'date': '2015-10-12',
#   'open': 112.73,
#   'high': 112.75,
#   'low': 111.44,
#   'close': 111.6,
#   'adjClose': 104.15,
#   'volume': 30467200.0,
#   'unadjustedVolume': 30467200.0,
#   'change': 1.13,
#   'changePercent': 1.002,
#   'vwap': 111.93,
#   'label': 'October 12, 15',
#   'changeOverTime': 0.01002},
#  {'date': '2015-10-13',
#   'open': 110.82,
#   'high': 112.45,
#   'low': 110.68,
#   'close': 111.79,
#   'adjClose': 104.33,
#   'volume': 33049300.0,
#   'unadjustedVolume': 33049300.0,
#   'change': -0.97,
#   'changePercent': -0.875,
#   'vwap': 111.64,
#   'label': 'October 13, 15',
#   'changeOverTime': -0.00875},
#  {'date': '2015-10-14',
#   'open': 111.29,
#   'high': 111.52,
#   'low': 109.56,
#   'close': 110.21,
#   'adjClose': 102.86,
#   'volume': 44462400.0,
#   'unadjustedVolume': 44462400.0,
#   'change': 1.08,
#   'changePercent': 0.97,
#   'vwap': 110.43,
#   'label': 'October 14, 15',
#   'changeOverTime': 0.0097},
#  {'date': '2015-10-15',
#   'open': 110.93,
#   'high': 112.1,
#   'low': 110.49,
#   'close': 111.86,
#   'adjClose': 104.4,
#   'volume': 37673500.0,
#   'unadjustedVolume': 37673500.0,
#   'change': -0.93,
#   'changePercent': -0.838,
#   'vwap': 111.48333,
#   'label': 'October 15, 15',
#   'changeOverTime': -0.00838},
#  {'date': '2015-10-16',
#   'open': 111.78,
#   'high': 112.0,
#   'low': 110.53,
#   'close': 111.04,
#   'adjClose': 103.63,
#   'volume': 39232600.0,
#   'unadjustedVolume': 39232600.0,
#   'change': 0.74,
#   'changePercent': 0.662,
#   'vwap': 111.19,
#   'label': 'October 16, 15',
#   'changeOverTime': 0.00662},
#  {'date': '2015-10-19',
#   'open': 110.8,
#   'high': 111.75,
#   'low': 110.11,
#   'close': 111.73,
#   'adjClose': 104.28,
#   'volume': 29759200.0,
#   'unadjustedVolume': 29759200.0,
#   'change': -0.93,
#   'changePercent': -0.839,
#   'vwap': 111.19667,
#   'label': 'October 19, 15',
#   'changeOverTime': -0.00839},
#  {'date': '2015-10-20',
#   'open': 111.34,
#   'high': 114.17,
#   'low': 110.82,
#   'close': 113.77,
#   'adjClose': 106.18,
#   'volume': 48967800.0,
#   'unadjustedVolume': 48967800.0,
#   'change': -2.43,
#   'changePercent': -2.183,
#   'vwap': 112.92,
#   'label': 'October 20, 15',
#   'changeOverTime': -0.02183},
#  {'date': '2015-10-21',
#   'open': 114.0,
#   'high': 115.58,
#   'low': 113.7,
#   'close': 113.76,
#   'adjClose': 106.17,
#   'volume': 41795200.0,
#   'unadjustedVolume': 41795200.0,
#   'change': 0.24,
#   'changePercent': 0.211,
#   'vwap': 114.34667,
#   'label': 'October 21, 15',
#   'changeOverTime': 0.00211},
#  {'date': '2015-10-22',
#   'open': 114.33,
#   'high': 115.5,
#   'low': 114.1,
#   'close': 115.5,
#   'adjClose': 107.79,
#   'volume': 41654100.0,
#   'unadjustedVolume': 41654100.0,
#   'change': -1.17,
#   'changePercent': -1.023,
#   'vwap': 115.03333,
#   'label': 'October 22, 15',
#   'changeOverTime': -0.01023},
#  {'date': '2015-10-23',
#   'open': 116.7,
#   'high': 119.23,
#   'low': 116.33,
#   'close': 119.08,
#   'adjClose': 111.14,
#   'volume': 59366900.0,
#   'unadjustedVolume': 59366900.0,
#   'change': -2.38,
#   'changePercent': -2.039,
#   'vwap': 118.21333,
#   'label': 'October 23, 15',
#   'changeOverTime': -0.02039},
#  {'date': '2015-10-26',
#   'open': 118.08,
#   'high': 118.13,
#   'low': 114.92,
# ...
#   'vwap': 170.42667,
#   'label': 'December 07, 18',
#   'changeOverTime': 0.02882},
#  {'date': '2018-12-10',
#   'open': 165.0,
#   'high': 170.09,
#   'low': 163.33,
#   'close': 169.6,
#   'adjClose': 167.59,
#   'volume': 62026000.0,
#   'unadjustedVolume': 62026000.0,
#   'change': -4.6,
#   'changePercent': -2.788,
#   'vwap': 167.67333,
#   'label': 'December 10, 18',
#   'changeOverTime': -0.02788},
#  {'date': '2018-12-11',
#   'open': 171.66,
#   'high': 171.79,
#   'low': 167.0,
#   'close': 168.63,
#   'adjClose': 166.63,
#   'volume': 47281700.0,
#   'unadjustedVolume': 47281700.0,
#   'change': 3.03,
#   'changePercent': 1.765,
#   'vwap': 169.14,
#   'label': 'December 11, 18',
#   'changeOverTime': 0.01765},
#  {'date': '2018-12-12',
#   'open': 170.4,
#   'high': 171.92,
#   'low': 169.02,
#   'close': 169.1,
#   'adjClose': 167.1,
#   'volume': 35627700.0,
#   'unadjustedVolume': 35627700.0,
#   'change': 1.3,
#   'changePercent': 0.763,
#   'vwap': 170.01333,
#   'label': 'December 12, 18',
#   'changeOverTime': 0.00763},
#  {'date': '2018-12-13',
#   'open': 170.49,
#   'high': 172.57,
#   'low': 169.55,
#   'close': 170.95,
#   'adjClose': 168.93,
#   'volume': 31898600.0,
#   'unadjustedVolume': 31898600.0,
#   'change': -0.46,
#   'changePercent': -0.27,
#   'vwap': 171.02333,
#   'label': 'December 13, 18',
#   'changeOverTime': -0.0027},
#  {'date': '2018-12-14',
#   'open': 169.0,
#   'high': 169.08,
#   'low': 165.28,
#   'close': 165.48,
#   'adjClose': 163.52,
#   'volume': 40703700.0,
#   'unadjustedVolume': 40703700.0,
#   'change': 3.52,
#   'changePercent': 2.083,
#   'vwap': 166.61333,
#   'label': 'December 14, 18',
#   'changeOverTime': 0.02083},
#  {'date': '2018-12-17',
#   'open': 165.45,
#   'high': 168.35,
#   'low': 162.73,
#   'close': 163.94,
#   'adjClose': 162.0,
#   'volume': 44287900.0,
#   'unadjustedVolume': 44287900.0,
#   'change': 1.51,
#   'changePercent': 0.913,
#   'vwap': 165.00667,
#   'label': 'December 17, 18',
#   'changeOverTime': 0.00913},
#  {'date': '2018-12-18',
#   'open': 165.38,
#   'high': 167.53,
#   'low': 164.39,
#   'close': 166.07,
#   'adjClose': 164.1,
#   'volume': 33841500.0,
#   'unadjustedVolume': 33841500.0,
#   'change': -0.69,
#   'changePercent': -0.417,
#   'vwap': 165.99667,
#   'label': 'December 18, 18',
#   'changeOverTime': -0.00417},
#  {'date': '2018-12-19',
#   'open': 166.0,
#   'high': 167.45,
#   'low': 159.09,
#   'close': 160.89,
#   'adjClose': 158.98,
#   'volume': 49047300.0,
#   'unadjustedVolume': 49047300.0,
#   'change': 5.11,
#   'changePercent': 3.078,
#   'vwap': 162.47667,
#   'label': 'December 19, 18',
#   'changeOverTime': 0.03078},
#  {'date': '2018-12-20',
#   'open': 160.4,
#   'high': 162.11,
#   'low': 155.3,
#   'close': 156.83,
#   'adjClose': 154.97,
#   'volume': 64773000.0,
#   'unadjustedVolume': 64773000.0,
#   'change': 3.57,
#   'changePercent': 2.226,
#   'vwap': 158.08,
#   'label': 'December 20, 18',
#   'changeOverTime': 0.02226},
#  {'date': '2018-12-21',
#   'open': 156.86,
#   'high': 158.16,
#   'low': 149.63,
#   'close': 150.73,
#   'adjClose': 148.94,
#   'volume': 95744600.0,
#   'unadjustedVolume': 95744600.0,
#   'change': 6.13,
#   'changePercent': 3.908,
#   'vwap': 152.84,
#   'label': 'December 21, 18',
#   'changeOverTime': 0.03908},
#  {'date': '2018-12-24',
#   'open': 148.15,
#   'high': 151.55,
#   'low': 146.59,
#   'close': 146.83,
#   'adjClose': 145.09,
#   'volume': 37169200.0,
#   'unadjustedVolume': 37169200.0,
#   'change': 1.32,
#   'changePercent': 0.891,
#   'vwap': 148.32333,
#   'label': 'December 24, 18',
#   'changeOverTime': 0.00891},
#  {'date': '2018-12-26',
#   'open': 148.3,
#   'high': 157.23,
#   'low': 146.72,
#   'close': 157.17,
#   'adjClose': 155.31,
#   'volume': 58582500.0,
#   'unadjustedVolume': 58582500.0,
#   'change': -8.87,
#   'changePercent': -5.981,
#   'vwap': 153.70667,
#   'label': 'December 26, 18',
#   'changeOverTime': -0.05981},
#  {'date': '2018-12-27',
#   'open': 155.84,
#   'high': 156.77,
#   'low': 150.07,
#   'close': 156.15,
#   'adjClose': 154.3,
#   'volume': 53117100.0,
#   'unadjustedVolume': 53117100.0,
#   'change': -0.31,
#   'changePercent': -0.199,
#   'vwap': 154.33,
#   'label': 'December 27, 18',
#   'changeOverTime': -0.00199},
#  {'date': '2018-12-28',
#   'open': 157.5,
#   'high': 158.52,
#   'low': 154.55,
#   'close': 156.23,
#   'adjClose': 154.38,
#   'volume': 42291400.0,
#   'unadjustedVolume': 42291400.0,
#   'change': 1.27,
#   'changePercent': 0.806,
#   'vwap': 156.43333,
#   'label': 'December 28, 18',
#   'changeOverTime': 0.00806},
#  {'date': '2018-12-31',
#   'open': 158.53,
#   'high': 159.36,
#   'low': 156.48,
#   'close': 157.74,
#   'adjClose': 155.87,
#   'volume': 35003500.0,
#   'unadjustedVolume': 35003500.0,
#   'change': 0.79,
#   'changePercent': 0.498,
#   'vwap': 157.86,
#   'label': 'December 31, 18',
#   'changeOverTime': 0.00498},
#  {'date': '2019-01-02',
#   'open': 154.89,
#   'high': 158.85,
#   'low': 154.23,
#   'close': 157.92,
#   'adjClose': 156.05,
#   'volume': 37039700.0,
#   'unadjustedVolume': 37039700.0,
#   'change': -3.03,
#   'changePercent': -1.956,
#   'vwap': 157.0,
#   'label': 'January 02, 19',
#   'changeOverTime': -0.01956},
#  {'date': '2019-01-03',
#   'open': 143.98,
#   'high': 145.72,
#   'low': 142.0,
#   'close': 142.19,
#   'adjClose': 140.51,
#   'volume': 91312200.0,
#   'unadjustedVolume': 91312200.0,
#   'change': 1.79,
#   'changePercent': 1.243,
#   'vwap': 143.30333,
#   'label': 'January 03, 19',
#   'changeOverTime': 0.01243},
#  {'date': '2019-01-04',
#   'open': 144.53,
#   'high': 148.55,
#   'low': 143.8,
#   'close': 148.26,
#   'adjClose': 146.5,
#   'volume': 58607100.0,
#   'unadjustedVolume': 58607100.0,
#   'change': -3.73,
#   'changePercent': -2.581,
#   'vwap': 146.87,
#   'label': 'January 04, 19',
#   'changeOverTime': -0.02581},
#  {'date': '2019-01-07',
#   'open': 148.7,
#   'high': 148.83,
#   'low': 145.9,
#   'close': 147.93,
#   'adjClose': 146.18,
#   'volume': 54777800.0,
#   'unadjustedVolume': 54777800.0,
#   'change': 0.77,
#   'changePercent': 0.518,
#   'vwap': 147.55333,
#   'label': 'January 07, 19',
#   'changeOverTime': 0.00518},
#  {'date': '2019-01-08',
#   'open': 149.56,
#   'high': 151.82,
#   'low': 148.52,
#   'close': 150.75,
#   'adjClose': 148.96,
#   'volume': 41025300.0,
#   'unadjustedVolume': 41025300.0,
#   'change': -1.19,
#   'changePercent': -0.796,
#   'vwap': 150.36333,
#   'label': 'January 08, 19',
#   'changeOverTime': -0.00796},
#  {'date': '2019-01-09',
#   'open': 151.29,
#   'high': 154.53,
#   'low': 149.63,
#   'close': 153.31,
#   'adjClose': 151.49,
#   'volume': 45099100.0,
#   'unadjustedVolume': 45099100.0,
#   'change': -2.02,
#   'changePercent': -1.335,
#   'vwap': 152.49,
#   'label': 'January 09, 19',
#   'changeOverTime': -0.01335},
#  {'date': '2019-01-10',
#   'open': 152.5,
#   'high': 153.97,
#   'low': 150.86,
#   'close': 153.8,
#   'adjClose': 151.98,
#   'volume': 35780700.0,
#   'unadjustedVolume': 35780700.0,
#   'change': -1.3,
#   'changePercent': -0.852,
#   'vwap': 152.87667,
#   'label': 'January 10, 19',
#   'changeOverTime': -0.00852},
#  {'date': '2019-01-11',
#   'open': 152.88,
#   'high': 153.7,
#   'low': 151.51,
#   'close': 152.29,
#   'adjClose': 150.49,
#   'volume': 27023200.0,
#   'unadjustedVolume': 27023200.0,
#   'change': 0.59,
#   'changePercent': 0.386,
#   'vwap': 152.5,
#   'label': 'January 11, 19',
#   'changeOverTime': 0.00386},
#  {'date': '2019-01-14',
#   'open': 150.85,
#   'high': 151.27,
#   'low': 149.22,
#   'close': 150.0,
#   'adjClose': 148.22,
#   'volume': 32439200.0,
#   'unadjustedVolume': 32439200.0,
#   'change': 0.85,
#   'changePercent': 0.563,
#   'vwap': 150.16333,
#   'label': 'January 14, 19',
#   'changeOverTime': 0.00563},
#  {'date': '2019-01-15',
#   'open': 150.27,
#   'high': 153.39,
#   'low': 150.05,
#   'close': 153.07,
#   'adjClose': 151.26,
#   'volume': 28710900.0,
#   'unadjustedVolume': 28710900.0,
#   'change': -2.8,
#   'changePercent': -1.863,
#   'vwap': 152.17,
#   'label': 'January 15, 19',
#   'changeOverTime': -0.01863},
#  {'date': '2019-01-16',
#   'open': 153.08,
#   'high': 155.88,
#   'low': 153.0,
#   'close': 154.94,
#   'adjClose': 153.1,
#   'volume': 30569700.0,
#   'unadjustedVolume': 30569700.0,
#   'change': -1.86,
#   'changePercent': -1.215,
#   'vwap': 154.60667,
#   'label': 'January 16, 19',
#   'changeOverTime': -0.01215},
#  {'date': '2019-01-17',
#   'open': 154.2,
#   'high': 157.66,
#   'low': 153.26,
#   'close': 155.86,
#   'adjClose': 154.01,
#   'volume': 29821200.0,
#   'unadjustedVolume': 29821200.0,
#   'change': -1.66,
#   'changePercent': -1.077,
#   'vwap': 155.59333,
#   'label': 'January 17, 19',
#   'changeOverTime': -0.01077},
#  {'date': '2019-01-18',
#   'open': 157.5,
#   'high': 157.88,
#   'low': 155.98,
#   'close': 156.82,
#   'adjClose': 154.96,
#   'volume': 33751000.0,
#   'unadjustedVolume': 33751000.0,
#   'change': 0.68,
#   'changePercent': 0.432,
#   'vwap': 156.89333,
#   'label': 'January 18, 19',
#   'changeOverTime': 0.00432},
#  {'date': '2019-01-22',
#   'open': 156.41,
#   'high': 156.73,
#   'low': 152.62,
#   'close': 153.3,
#   'adjClose': 151.48,
#   'volume': 30394000.0,
#   'unadjustedVolume': 30394000.0,
#   'change': 3.11,
#   'changePercent': 1.988,
#   'vwap': 154.21667,
#   'label': 'January 22, 19',
#   'changeOverTime': 0.01988},
#  {'date': '2019-01-23',
#   'open': 154.15,
#   'high': 155.14,
#   'low': 151.7,
#   'close': 153.92,
#   'adjClose': 152.1,
#   'volume': 23130600.0,
#   'unadjustedVolume': 23130600.0,
#   'change': 0.23,
#   'changePercent': 0.149,
#   'vwap': 153.58667,
#   'label': 'January 23, 19',
#   'changeOverTime': 0.00149},
#  {'date': '2019-01-24',
#   'open': 154.11,
#   'high': 154.48,
#   'low': 151.74,
#   'close': 152.7,
#   'adjClose': 150.89,
#   'volume': 25441500.0,
#   'unadjustedVolume': 25441500.0,
#   'change': 1.41,
#   'changePercent': 0.915,
#   'vwap': 152.97333,
#   'label': 'January 24, 19',
#   'changeOverTime': 0.00915},
#  {'date': '2019-01-25',
#   'open': 155.48,
#   'high': 158.13,
#   'low': 154.32,
#   'close': 157.76,
#   'adjClose': 155.89,
#   'volume': 33535500.0,
#   'unadjustedVolume': 33535500.0,
#   'change': -2.28,
#   'changePercent': -1.466,
#   'vwap': 156.73667,
#   'label': 'January 25, 19',
#   'changeOverTime': -0.01466},
#  {'date': '2019-01-28',
#   'open': 155.79,
#   'high': 156.33,
#   'low': 153.66,
#   'close': 156.3,
#   'adjClose': 154.45,
#   'volume': 26192100.0,
#   'unadjustedVolume': 26192100.0,
#   'change': -0.51,
#   'changePercent': -0.327,
#   'vwap': 155.43,
#   'label': 'January 28, 19',
#   'changeOverTime': -0.00327},
#  {'date': '2019-01-29',
#   'open': 156.25,
#   'high': 158.13,
#   'low': 154.11,
#   'close': 154.68,
#   'adjClose': 152.85,
#   'volume': 41587200.0,
#   'unadjustedVolume': 41587200.0,
#   'change': 1.57,
#   'changePercent': 1.005,
#   'vwap': 155.64,
#   'label': 'January 29, 19',
#   'changeOverTime': 0.01005},
#  {'date': '2019-01-30',
#   'open': 163.25,
#   'high': 166.15,
#   'low': 160.23,
#   'close': 165.25,
#   'adjClose': 163.29,
#   'volume': 61109800.0,
#   'unadjustedVolume': 61109800.0,
#   'change': -2.0,
#   'changePercent': -1.225,
#   'vwap': 163.87667,
#   'label': 'January 30, 19',
#   'changeOverTime': -0.01225},
#  {'date': '2019-01-31',
#   'open': 166.11,
#   'high': 169.0,
#   'low': 164.56,
#   'close': 166.44,
#   'adjClose': 164.47,
#   'volume': 40739600.0,
#   'unadjustedVolume': 40739600.0,
#   'change': -0.33,
#   'changePercent': -0.199,
#   'vwap': 166.66667,
#   'label': 'January 31, 19',
#   'changeOverTime': -0.00199},
#  {'date': '2019-02-01',
#   'open': 166.96,
#   'high': 168.98,
#   'low': 165.93,
#   'close': 166.52,
#   'adjClose': 164.55,
#   'volume': 32668100.0,
#   'unadjustedVolume': 32668100.0,
#   'change': 0.44,
#   'changePercent': 0.264,
#   'vwap': 167.14333,
#   'label': 'February 01, 19',
#   'changeOverTime': 0.00264},
#  {'date': '2019-02-04',
#   'open': 167.41,
#   'high': 171.66,
#   'low': 167.28,
#   'close': 171.25,
#   'adjClose': 169.22,
#   'volume': 31495500.0,
#   'unadjustedVolume': 31495500.0,
#   'change': -3.84,
#   'changePercent': -2.294,
#   'vwap': 170.06333,
#   'label': 'February 04, 19',
#   'changeOverTime': -0.02294},
#  {'date': '2019-02-05',
#   'open': 172.86,
#   'high': 175.08,
#   'low': 172.35,
#   'close': 174.18,
#   'adjClose': 172.12,
#   'volume': 36101600.0,
#   'unadjustedVolume': 36101600.0,
#   'change': -1.32,
#   'changePercent': -0.764,
#   'vwap': 173.87,
#   'label': 'February 05, 19',
#   'changeOverTime': -0.00764},
#  {'date': '2019-02-06',
#   'open': 174.65,
#   'high': 175.57,
#   'low': 172.85,
#   'close': 174.24,
#   'adjClose': 172.18,
#   'volume': 28239600.0,
#   'unadjustedVolume': 28239600.0,
#   'change': 0.41,
#   'changePercent': 0.235,
#   'vwap': 174.22,
#   'label': 'February 06, 19',
#   'changeOverTime': 0.00235},
#  {'date': '2019-02-07',
#   'open': 172.4,
#   'high': 173.94,
#   'low': 170.34,
#   'close': 170.94,
#   'adjClose': 168.92,
#   'volume': 31741700.0,
#   'unadjustedVolume': 31741700.0,
#   'change': 1.46,
#   'changePercent': 0.847,
#   'vwap': 171.74,
#   'label': 'February 07, 19',
#   'changeOverTime': 0.00847},
#  {'date': '2019-02-08',
#   'open': 168.99,
#   'high': 170.66,
#   'low': 168.42,
#   'close': 170.41,
#   'adjClose': 169.11,
#   'volume': 23820000.0,
#   'unadjustedVolume': 23820000.0,
#   'change': -1.42,
#   'changePercent': -0.84,
#   'vwap': 169.83,
#   'label': 'February 08, 19',
#   'changeOverTime': -0.0084},
#  {'date': '2019-02-11',
#   'open': 171.05,
#   'high': 171.21,
#   'low': 169.25,
#   'close': 169.43,
#   'adjClose': 168.14,
#   'volume': 20993400.0,
#   'unadjustedVolume': 20993400.0,
#   'change': 1.62,
#   'changePercent': 0.947,
#   'vwap': 169.96333,
#   'label': 'February 11, 19',
#   'changeOverTime': 0.00947},
#  {'date': '2019-02-12',
#   'open': 170.1,
#   'high': 171.0,
#   'low': 169.7,
#   'close': 170.89,
#   'adjClose': 169.59,
#   'volume': 22283500.0,
#   'unadjustedVolume': 22283500.0,
#   'change': -0.79,
#   'changePercent': -0.464,
#   'vwap': 170.53,
#   'label': 'February 12, 19',
#   'changeOverTime': -0.00464},
#  {'date': '2019-02-13',
#   'open': 171.39,
#   'high': 172.48,
#   'low': 169.92,
#   'close': 170.18,
#   'adjClose': 168.89,
#   'volume': 22490200.0,
#   'unadjustedVolume': 22490200.0,
#   'change': 1.21,
#   'changePercent': 0.706,
#   'vwap': 170.86,
#   'label': 'February 13, 19',
#   'changeOverTime': 0.00706},
#  {'date': '2019-02-14',
#   'open': 169.71,
#   'high': 171.26,
#   'low': 169.38,
#   'close': 170.8,
#   'adjClose': 169.5,
#   'volume': 21835700.0,
#   'unadjustedVolume': 21835700.0,
#   'change': -1.09,
#   'changePercent': -0.642,
#   'vwap': 170.48,
#   'label': 'February 14, 19',
#   'changeOverTime': -0.00642},
#  {'date': '2019-02-15',
#   'open': 171.25,
#   'high': 171.7,
#   'low': 169.75,
#   'close': 170.42,
#   'adjClose': 169.12,
#   'volume': 24626800.0,
#   'unadjustedVolume': 24626800.0,
#   'change': 0.83,
#   'changePercent': 0.485,
#   'vwap': 170.62333,
#   'label': 'February 15, 19',
#   'changeOverTime': 0.00485},
#  {'date': '2019-02-19',
#   'open': 169.71,
#   'high': 171.44,
#   'low': 169.49,
#   'close': 170.93,
#   'adjClose': 169.63,
#   'volume': 18972800.0,
#   'unadjustedVolume': 18972800.0,
#   'change': -1.22,
#   'changePercent': -0.719,
#   'vwap': 170.62,
#   'label': 'February 19, 19',
#   'changeOverTime': -0.00719},
#  {'date': '2019-02-20',
#   'open': 171.19,
#   'high': 173.32,
#   'low': 170.99,
#   'close': 172.03,
#   'adjClose': 170.72,
#   'volume': 26114400.0,
#   'unadjustedVolume': 26114400.0,
#   'change': -0.84,
#   'changePercent': -0.491,
#   'vwap': 172.11333,
#   'label': 'February 20, 19',
#   'changeOverTime': -0.00491},
#  {'date': '2019-02-21',
#   'open': 171.8,
#   'high': 172.37,
#   'low': 170.3,
#   'close': 171.06,
#   'adjClose': 169.76,
#   'volume': 17249700.0,
#   'unadjustedVolume': 17249700.0,
#   'change': 0.74,
#   'changePercent': 0.431,
#   'vwap': 171.24333,
#   'label': 'February 21, 19',
#   'changeOverTime': 0.00431},
#  {'date': '2019-02-22',
#   'open': 171.58,
#   'high': 173.0,
#   'low': 171.38,
#   'close': 172.97,
#   'adjClose': 171.65,
#   'volume': 18913200.0,
#   'unadjustedVolume': 18913200.0,
#   'change': -1.39,
#   'changePercent': -0.81,
#   'vwap': 172.45,
#   'label': 'February 22, 19',
#   'changeOverTime': -0.0081},
#  {'date': '2019-02-25',
#   'open': 174.16,
#   'high': 175.87,
#   'low': 173.95,
#   'close': 174.23,
#   'adjClose': 172.9,
#   'volume': 21873400.0,
#   'unadjustedVolume': 21873400.0,
#   'change': -0.07,
#   'changePercent': -0.04,
#   'vwap': 174.68333,
#   'label': 'February 25, 19',
#   'changeOverTime': -0.0004},
#  {'date': '2019-02-26',
#   'open': 173.71,
#   'high': 175.3,
#   'low': 173.17,
#   'close': 174.33,
#   'adjClose': 173.0,
#   'volume': 17070200.0,
#   'unadjustedVolume': 17070200.0,
#   'change': -0.62,
#   'changePercent': -0.357,
#   'vwap': 174.26667,
#   'label': 'February 26, 19',
#   'changeOverTime': -0.00357},
#  ...]

# %%
# (iDF[['close']].rename(columns={'close':'GS'}) for iDF in companies)
pd.concat(companies, axis=1, join='outer').head(1)
# Out:
#              open  high    low  close  adjClose      volume  unadjustedVolume  \
# date
# 2015-03-09  15.98  16.1  15.93  16.03     12.48  17132400.0        17132400.0
#
#             change  changePercent   vwap  ...     low   close  adjClose  \
# date                                      ...
# 2015-03-09   -0.05         -0.313  16.02  ...  186.57  187.93    175.86
#
#                volume  unadjustedVolume  change  changePercent       vwap  \
# date
# 2015-03-09  2233700.0         2233700.0   -0.63         -0.336  187.76333
#
#                    label  changeOverTime
# date
# 2015-03-09  March 09, 15        -0.00336
#
# [1 rows x 24 columns]

# %%
df1 =pd.DataFrame.from_dict(F,orient='index',columns=['close']).rename(columns={'close':'F'})

# %%
pd.DataFrame(get_data('GS')['historical']).set_index('date')
# Out:
#               open    high     low   close  adjClose      volume  \
# date
# 2015-03-09  127.96  129.57  125.06  127.14    117.63  88528500.0
# 2015-03-10  126.41  127.22  123.80  124.51    115.20  68856600.0
# 2015-03-11  124.75  124.77  122.11  122.24    113.10  68939000.0
# 2015-03-12  122.31  124.90  121.63  124.45    115.14  48362700.0
# 2015-03-13  124.40  125.40  122.58  123.59    114.35  51827300.0
# ...            ...     ...     ...     ...       ...         ...
# 2020-03-02  282.28  301.44  277.72  298.81    298.81  85349300.0
# 2020-03-03  303.67  304.00  285.80  289.32    289.32  79868900.0
# 2020-03-04  296.44  303.40  293.13  302.74    302.74  54794600.0
# 2020-03-05  295.52  299.55  291.41  292.92    292.92  46893200.0
# 2020-03-06  282.00  290.82  281.23  289.03    289.03  56491800.0
#
#             unadjustedVolume  change  changePercent       vwap         label  \
# date
# 2015-03-09        88528500.0    0.82          0.641  127.25667  March 09, 15
# 2015-03-10        68856600.0    1.90          1.503  125.17667  March 10, 15
# 2015-03-11        68939000.0    2.51          2.012  123.04000  March 11, 15
# 2015-03-12        48362700.0   -2.14         -1.750  123.66000  March 12, 15
# 2015-03-13        51827300.0    0.81          0.651  123.85667  March 13, 15
# ...                      ...     ...            ...        ...           ...
# 2020-03-02        85349300.0  -16.53         -5.856  292.65667  March 02, 20
# 2020-03-03        79868900.0   14.35          4.726  293.04000  March 03, 20
# 2020-03-04        54794600.0   -6.30         -2.125  299.75667  March 04, 20
# 2020-03-05        46893200.0    2.60          0.880  294.62667  March 05, 20
# 2020-03-06        56491800.0   -7.03         -2.493  287.02667  March 06, 20
#
#             changeOverTime
# date
# 2015-03-09         0.00641
# 2015-03-10         0.01503
# 2015-03-11         0.02012
# 2015-03-12        -0.01750
# 2015-03-13         0.00651
# ...                    ...
# 2020-03-02        -0.05856
# 2020-03-03         0.04726
# 2020-03-04        -0.02125
# 2020-03-05         0.00880
# 2020-03-06        -0.02493
#
# [1259 rows x 12 columns]

# %%
df2 =pd.DataFrame.from_dict(GS,orient='index',columns=['close']).rename(columns={'close':'GS'})

# %%
df1
# Out:
#                F
# 1972-06-01  2.25
# 1972-06-02  2.24
# 1972-06-05  2.24
# 1972-06-06  2.22
# 1972-06-07  2.21
# ...          ...
# 2020-02-27  6.97
# 2020-02-28  6.96
# 2020-03-02  7.20
# 2020-03-03  6.97
# 2020-03-04  7.08
#
# [12052 rows x 1 columns]

# %%
pd.DataFrame().join([df1,df2],how='outer').dropna( how='any')
# Out:
#                 F      GS
# 1999-05-04  36.68   70.38
# 1999-05-05  36.83   69.13
# 1999-05-06  35.76   67.94
# 1999-05-07  37.11   74.69
# 1999-05-10  36.65   70.50
# ...           ...     ...
# 2020-02-27   6.97  205.69
# 2020-02-28   6.96  200.77
# 2020-03-02   7.20  209.47
# 2020-03-03   6.97  203.43
# 2020-03-04   7.08  208.74
#
# [5244 rows x 2 columns]

# %%
requests.get(f'https://api.worldtradingdata.com/api/v1/ticker_list?type=stocks&api_token=aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy').json()
# Out:
# ['000001.SZ',
#  '000002.SZ',
#  '000004.SZ',
#  '000005.SZ',
#  '000006.SZ',
#  '000007.SZ',
#  '000008.SZ',
#  '000009.SZ',
#  '000010.SZ',
#  '000011.SZ',
#  '000012.SZ',
#  '000014.SZ',
#  '000016.SZ',
#  '000017.SZ',
#  '000018.SZ',
#  '000019.SZ',
#  '000020.SZ',
#  '000021.SZ',
#  '000022.SZ',
#  '000023.SZ',
#  '000025.SZ',
#  '000026.SZ',
#  '000027.SZ',
#  '000028.SZ',
#  '000029.SZ',
#  '000030.KS',
#  '000030.SZ',
#  '000031.SZ',
#  '000032.SZ',
#  '000034.SZ',
#  '000035.SZ',
#  '000036.SZ',
#  '000037.SZ',
#  '000038.SZ',
#  '000039.SZ',
#  '000040.KS',
#  '000040.SZ',
#  '000042.SZ',
#  '000043.SZ',
#  '000045.SZ',
#  '000046.SZ',
#  '000048.SZ',
#  '000049.SZ',
#  '000050.SZ',
#  '000055.SZ',
#  '000056.SZ',
#  '000058.SZ',
#  '000059.SZ',
#  '000060.KS',
#  '000060.SZ',
#  '000061.SZ',
#  '000062.SZ',
#  '000063.SZ',
#  '000065.SZ',
#  '000066.SZ',
#  '000068.SZ',
#  '000069.SZ',
#  '000070.KS',
#  '000070.SZ',
#  '000075.KS',
#  '000078.SZ',
#  '000080.KS',
#  '000087.KS',
#  '000088.SZ',
#  '000089.SZ',
#  '000090.SZ',
#  '000096.SZ',
#  '000099.SZ',
#  '0001.HK',
#  '0001.KL',
#  '000100.SZ',
#  '000105.KS',
#  '000120.KS',
#  '000140.KS',
#  '000150.SZ',
#  '000151.SZ',
#  '000153.SZ',
#  '000155.SZ',
#  '000156.SZ',
#  '000157.KS',
#  '000157.SZ',
#  '000158.SZ',
#  '000159.SZ',
#  '000166.SZ',
#  '0002.HK',
#  '0002.KL',
#  '000210.KS',
#  '000215.KS',
#  '000225.KS',
#  '000270.KS',
#  '0003.HK',
#  '000300.KS',
#  '000301.SZ',
#  '000325.KS',
#  '000333.SZ',
#  '000338.SZ',
#  '000370.KS',
#  '000390.KS',
#  '0004.HK',
#  '000400.KS',
#  '000400.SZ',
#  '000401.SZ',
#  '000402.SZ',
#  '000403.SZ',
#  '000404.SZ',
#  '000407.SZ',
#  '000408.SZ',
#  '000409.SZ',
#  '000410.SZ',
#  '000411.SZ',
#  '000413.SZ',
#  '000415.SZ',
#  '000416.SZ',
#  '000417.SZ',
#  '000418.SZ',
#  '000419.SZ',
#  '000420.SZ',
#  '000421.SZ',
#  '000422.SZ',
#  '000423.SZ',
#  '000425.SZ',
#  '000426.SZ',
#  '000428.SZ',
#  '000429.SZ',
#  '000430.KS',
#  '000430.SZ',
#  '000480.KS',
#  '000488.SZ',
#  '000498.SZ',
#  '0005.HK',
#  '0005.KL',
#  '000501.SZ',
#  '000502.SZ',
#  '000503.SZ',
#  '000504.SZ',
#  '000505.SZ',
#  '000506.SZ',
#  '000507.SZ',
#  '000509.SZ',
#  '000510.SZ',
#  '000513.SZ',
#  '000514.SZ',
#  '000516.SZ',
#  '000517.SZ',
#  '000518.SZ',
#  '000519.SZ',
#  '000520.KS',
#  '000520.SZ',
#  '000521.SZ',
#  '000523.SZ',
#  '000524.SZ',
#  '000525.SZ',
#  '000526.SZ',
#  '000528.SZ',
#  '000529.SZ',
#  '000530.SZ',
#  '000531.SZ',
#  '000532.SZ',
#  '000533.SZ',
#  '000534.SZ',
#  '000536.SZ',
#  '000537.SZ',
#  '000538.SZ',
#  '000539.SZ',
#  '000540.KS',
#  '000540.SZ',
#  '000541.SZ',
#  '000543.SZ',
#  '000544.SZ',
#  '000545.KS',
#  '000545.SZ',
#  '000546.SZ',
#  '000547.KS',
#  '000547.SZ',
#  '000548.SZ',
#  '000550.SZ',
#  '000551.SZ',
#  '000552.SZ',
#  '000553.SZ',
#  '000554.SZ',
#  '000555.SZ',
#  '000557.SZ',
#  '000558.SZ',
#  '000559.SZ',
#  '000560.SZ',
#  '000561.SZ',
#  '000563.SZ',
#  '000564.SZ',
#  '000565.SZ',
#  '000566.SZ',
#  '000567.SZ',
#  '000568.SZ',
#  '000570.SZ',
#  '000571.SZ',
#  '000572.SZ',
#  '000573.SZ',
#  '000576.SZ',
#  '000581.SZ',
#  '000582.SZ',
#  '000584.SZ',
#  '000585.SZ',
#  '000586.SZ',
#  '000587.SZ',
#  '000589.SZ',
#  '000590.KS',
#  '000590.SZ',
#  '000591.SZ',
#  '000592.SZ',
#  '000593.SZ',
#  '000595.SZ',
#  '000596.SZ',
#  '000597.SZ',
#  '000598.SZ',
#  '000599.SZ',
#  '0006.HK',
#  '0006.KL',
#  '000600.SZ',
#  '000601.SZ',
#  '000603.SZ',
#  '000605.SZ',
#  '000606.SZ',
#  '000607.SZ',
#  '000608.SZ',
#  '000609.SZ',
#  '000610.SZ',
#  '000611.SZ',
#  '000612.SZ',
#  '000613.SZ',
#  '000615.SZ',
#  '000616.SZ',
#  '000617.SZ',
#  '000619.SZ',
#  '000620.SZ',
#  '000622.SZ',
#  '000623.SZ',
#  '000625.SZ',
#  '000626.SZ',
#  '000627.SZ',
#  '000628.SZ',
#  '000629.SZ',
#  '000630.SZ',
#  '000631.SZ',
#  '000632.SZ',
#  '000633.SZ',
#  '000635.SZ',
#  '000636.SZ',
#  '000637.SZ',
#  '000638.SZ',
#  '000639.SZ',
#  '000640.KS',
#  '000650.KS',
#  '000650.SZ',
#  '000651.SZ',
#  '000652.SZ',
#  '000655.SZ',
#  '000656.SZ',
#  '000657.SZ',
#  '000659.SZ',
#  '000660.KS',
#  '000661.SZ',
#  '000662.SZ',
#  '000663.SZ',
#  '000665.SZ',
#  '000666.SZ',
#  '000667.SZ',
#  '000668.SZ',
#  '000669.SZ',
#  '000670.KS',
#  '000670.SZ',
#  '000671.SZ',
#  '000672.SZ',
#  '000673.SZ',
#  '000676.SZ',
#  '000677.SZ',
#  '000678.SZ',
#  '000679.SZ',
#  '000680.KS',
#  '000680.SZ',
#  '000681.SZ',
#  '000682.SZ',
#  '000683.SZ',
#  '000685.SZ',
#  '000686.SZ',
#  '000687.SZ',
#  '000688.SZ',
#  '000690.SZ',
#  '000691.SZ',
#  '000692.SZ',
#  '000693.SZ',
#  '000695.SZ',
#  '000697.SZ',
#  '000698.SZ',
#  '0007.HK',
#  '0007.KL',
#  '000700.KS',
#  '000700.SZ',
#  '000701.SZ',
#  '000702.SZ',
#  '000703.SZ',
#  '000705.SZ',
#  '000707.SZ',
#  '000708.SZ',
#  '000709.SZ',
#  '000710.SZ',
#  '000711.SZ',
#  '000712.SZ',
#  '000713.SZ',
#  '000715.SZ',
#  '000716.SZ',
#  '000717.SZ',
#  '000718.SZ',
#  '000719.SZ',
#  '000720.KS',
#  '000720.SZ',
#  '000721.SZ',
#  '000722.SZ',
#  '000723.SZ',
#  '000725.KS',
#  '000725.SZ',
#  '000726.SZ',
#  '000727.SZ',
#  '000728.SZ',
#  '000729.SZ',
#  '000731.SZ',
#  '000732.SZ',
#  '000733.SZ',
#  '000735.SZ',
#  '000736.SZ',
#  '000737.SZ',
#  '000738.SZ',
#  '000739.SZ',
#  '000750.SZ',
#  '000751.SZ',
#  '000752.SZ',
#  '000753.SZ',
#  '000755.SZ',
#  '000756.SZ',
#  '000757.SZ',
#  '000758.SZ',
#  '000759.SZ',
#  '000760.KS',
#  '000760.SZ',
#  '000761.SZ',
#  '000762.SZ',
#  '000766.SZ',
#  '000767.SZ',
#  '000768.SZ',
#  '000776.SZ',
#  '000777.SZ',
#  '000778.SZ',
#  '000779.SZ',
#  '000780.SZ',
#  '000782.SZ',
#  '000783.SZ',
#  '000785.SZ',
#  '000786.SZ',
#  '000788.SZ',
#  '000789.SZ',
#  '000790.SZ',
#  '000791.SZ',
#  '000792.SZ',
#  '000793.SZ',
#  '000795.SZ',
#  '000796.SZ',
#  '000797.SZ',
#  '000798.SZ',
#  '000799.SZ',
#  '0008.HK',
#  '0008.KL',
#  '000800.SZ',
#  '000801.SZ',
#  '000802.SZ',
#  '000803.SZ',
#  '000806.SZ',
#  '000807.SZ',
#  '000809.SZ',
#  '000810.KS',
#  '000810.SZ',
#  '000811.SZ',
#  '000812.SZ',
#  '000813.SZ',
#  '000815.KS',
#  '000815.SZ',
#  '000816.SZ',
#  '000818.SZ',
#  '000819.SZ',
#  '000820.SZ',
#  '000821.SZ',
#  '000822.SZ',
#  '000823.SZ',
#  '000825.SZ',
#  '000826.SZ',
#  '000828.SZ',
#  '000829.SZ',
#  '000830.KS',
#  '000830.SZ',
#  '000831.SZ',
#  '000833.SZ',
#  '000835.KS',
#  '000835.SZ',
#  '000836.SZ',
#  '000837.SZ',
#  '000838.SZ',
#  '000839.SZ',
#  '000848.SZ',
#  '000850.SZ',
#  '000851.SZ',
#  '000852.SZ',
#  '000856.SZ',
#  '000858.SZ',
#  '000859.SZ',
#  '000860.SZ',
#  '000861.SZ',
#  '000862.SZ',
#  '000863.SZ',
#  '000868.SZ',
#  '000869.SZ',
#  '000875.SZ',
#  '000876.SZ',
#  '000877.SZ',
#  '000878.SZ',
#  '000880.KS',
#  '000880.SZ',
#  '000881.SZ',
#  '000882.SZ',
#  '000883.SZ',
#  '000885.SZ',
#  '000886.SZ',
#  '000887.SZ',
#  '000888.SZ',
#  '000889.SZ',
#  '000890.KS',
#  '000890.SZ',
#  '000892.SZ',
#  '000893.SZ',
#  '000895.SZ',
#  '000897.SZ',
#  '000898.SZ',
#  '000899.SZ',
#  '0009.HK',
#  '000900.SZ',
#  '000901.SZ',
#  '000902.SZ',
#  '000903.SZ',
#  '000905.SZ',
#  '000906.SZ',
#  '000908.SZ',
#  '000909.SZ',
#  '000910.SZ',
#  '000911.SZ',
#  '000912.SZ',
#  '000913.SZ',
#  '000915.SZ',
#  '000917.SZ',
#  '000918.SZ',
#  '000919.SZ',
#  '000920.SZ',
#  '000921.SZ',
#  '000922.SZ',
#  '000923.SZ',
#  '000925.SZ',
#  '000926.SZ',
#  '000927.SZ',
#  '000928.SZ',
#  '000929.SZ',
#  '000930.SZ',
#  '000931.SZ',
#  '000932.SZ',
#  '000933.SZ',
#  '000935.SZ',
#  '000936.SZ',
#  '000937.SZ',
#  '000938.SZ',
#  '000939.SZ',
#  '000948.SZ',
#  '000949.SZ',
#  '000950.KS',
#  '000950.SZ',
#  '000951.SZ',
#  '000952.SZ',
#  '000953.SZ',
#  '000955.SZ',
#  '000957.SZ',
#  '000958.SZ',
#  '000959.SZ',
#  '000960.SZ',
#  '000961.SZ',
#  '000962.SZ',
#  '000963.SZ',
#  '000965.SZ',
#  '000966.SZ',
#  '000967.SZ',
#  '000968.SZ',
#  '000969.SZ',
#  '000970.KS',
#  '000970.SZ',
#  '000971.SZ',
#  '000972.SZ',
#  '000973.SZ',
#  '000975.SZ',
#  '000976.SZ',
#  '000977.SZ',
#  '000978.SZ',
#  '000979.SZ',
#  '000980.SZ',
#  '000981.SZ',
#  '000982.SZ',
#  '000983.SZ',
#  '000985.SZ',
#  '000987.SZ',
#  '000988.SZ',
#  '000989.SZ',
#  '000990.KS',
#  '000990.SZ',
#  '000993.SZ',
#  '000995.SZ',
#  '000996.SZ',
#  '000997.SZ',
#  '000998.SZ',
#  '000999.SZ',
#  '0010.HK',
#  '0010.KL',
#  '001020.KS',
#  '001040.KS',
#  '001045.KS',
#  '001060.KS',
#  '001065.KS',
#  '001067.KS',
#  '001070.KS',
#  '001080.KS',
#  '0011.HK',
#  '0011.KL',
#  '001130.KS',
#  '001140.KS',
#  '0012.HK',
#  '0012.KL',
#  '001210.KS',
#  '001230.KS',
#  '001250.KS',
#  '001275.KS',
#  '001290.KS',
#  '001340.KS',
#  '001390.KS',
#  '0014.HK',
#  '001420.KS',
#  '001440.KS',
#  '001460.KS',
#  '001465.KS',
#  '001470.KS',
#  '0015.HK',
#  '001500.KS',
#  '001510.KS',
#  '001515.KS',
#  '001520.KS',
#  '001525.KS',
#  '001527.KS',
#  '001530.KS',
#  '001550.KS',
#  '001560.KS',
#  '001570.KS',
#  '0016.HK',
#  '001620.KS',
#  '001630.KS',
#  '001680.KS',
#  '001685.KS',
#  '001696.SZ',
#  '0017.HK',
#  '0017.KL',
#  '001720.KS',
#  '001725.KS',
#  '001740.KS',
#  '001745.KS',
#  '001750.KS',
#  '001770.KS',
#  '001780.KS',
#  '001790.KS',
#  '0018.HK',
#  '0018.KL',
#  '001800.KS',
#  '001820.KS',
#  '001872.SZ',
#  '001880.KS',
#  '001896.SZ',
#  '0019.HK',
#  '001914.SZ',
#  '001940.KS',
#  '001965.SZ',
#  '001979.SZ',
#  '0020.HK',
#  '0020.KL',
#  '002000.KS',
#  '002001.SZ',
#  '002002.SZ',
#  '002003.SZ',
#  '002004.SZ',
#  '002005.KS',
#  '002005.SZ',
#  '002006.SZ',
#  '002007.SZ',
#  '002008.SZ',
#  '002009.SZ',
#  '002010.SZ',
#  '002011.SZ',
#  '002012.SZ',
#  '002013.SZ',
#  '002014.SZ',
#  '002015.SZ',
#  '002016.SZ',
#  '002017.SZ',
#  '002018.SZ',
#  '002019.SZ',
#  '002020.SZ',
#  '002021.SZ',
#  '002022.SZ',
#  '002023.SZ',
#  '002024.SZ',
#  '002025.KS',
#  '002025.SZ',
#  '002026.SZ',
#  '002027.SZ',
#  '002028.SZ',
#  '002029.SZ',
#  '002030.KS',
#  '002030.SZ',
#  '002031.SZ',
#  '002032.SZ',
#  '002033.SZ',
#  '002034.SZ',
#  '002035.SZ',
#  '002036.SZ',
#  '002037.SZ',
#  '002038.SZ',
#  '002039.SZ',
#  '002040.SZ',
#  '002041.SZ',
#  '002042.SZ',
#  '002043.SZ',
#  '002044.SZ',
#  '002045.SZ',
#  '002046.SZ',
#  '002047.SZ',
#  '002048.SZ',
#  '002049.SZ',
#  '002050.SZ',
#  '002051.SZ',
#  '002052.SZ',
#  '002053.SZ',
#  '002054.SZ',
#  '002055.SZ',
#  '002056.SZ',
#  '002057.SZ',
#  '002058.SZ',
#  '002059.SZ',
#  '002060.SZ',
#  '002061.SZ',
#  '002062.SZ',
#  '002063.SZ',
#  '002064.SZ',
#  '002065.SZ',
#  '002066.SZ',
#  '002067.SZ',
#  '002068.SZ',
#  '002069.SZ',
#  '002070.KS',
#  '002070.SZ',
#  '002071.SZ',
#  '002072.SZ',
#  '002073.SZ',
#  '002074.SZ',
#  '002075.SZ',
#  '002076.SZ',
#  '002077.SZ',
#  '002078.SZ',
#  '002079.SZ',
#  '002080.SZ',
#  '002081.SZ',
#  '002082.SZ',
#  '002083.SZ',
#  '002084.SZ',
#  '002085.SZ',
#  '002086.SZ',
#  '002087.SZ',
#  '002088.SZ',
#  '002089.SZ',
#  '002090.SZ',
#  '002091.SZ',
#  '002092.SZ',
#  '002093.SZ',
#  '002094.SZ',
#  '002095.SZ',
#  '002096.SZ',
#  '002097.SZ',
#  '002098.SZ',
#  '002099.SZ',
#  '0021.HK',
#  '0021.KL',
#  '002100.KS',
#  '002100.SZ',
#  '002101.SZ',
#  '002102.SZ',
#  '002103.SZ',
#  '002104.SZ',
#  '002105.SZ',
#  '002106.SZ',
#  '002107.SZ',
#  '002108.SZ',
#  '002109.SZ',
#  '002110.SZ',
#  '002111.SZ',
#  '002112.SZ',
#  '002113.SZ',
#  '002114.SZ',
#  '002115.SZ',
#  '002116.SZ',
#  '002117.SZ',
#  '002118.SZ',
#  '002119.SZ',
#  '002120.SZ',
#  '002121.SZ',
#  '002122.SZ',
#  '002123.SZ',
#  '002124.SZ',
#  '002125.SZ',
#  '002126.SZ',
#  '002127.SZ',
#  '002128.SZ',
#  '002129.SZ',
#  '002130.SZ',
#  '002131.SZ',
#  '002132.SZ',
#  '002133.SZ',
#  '002134.SZ',
#  '002135.SZ',
#  '002136.SZ',
#  '002137.SZ',
#  '002138.SZ',
#  '002139.SZ',
#  '002140.KS',
#  '002140.SZ',
#  '002141.SZ',
#  '002142.SZ',
#  '002143.SZ',
#  '002144.SZ',
#  '002145.SZ',
#  '002146.SZ',
#  '002147.SZ',
#  '002148.SZ',
#  '002149.SZ',
#  '002150.KS',
#  '002150.SZ',
#  '002151.SZ',
#  '002152.SZ',
#  '002153.SZ',
#  '002154.SZ',
#  '002155.SZ',
#  '002156.SZ',
#  '002157.SZ',
#  '002158.SZ',
#  '002159.SZ',
#  '002160.SZ',
#  '002161.SZ',
#  '002162.SZ',
#  '002163.SZ',
#  '002164.SZ',
#  '002165.SZ',
#  '002166.SZ',
#  '002167.SZ',
#  '002168.SZ',
#  '002169.SZ',
#  '002170.KS',
#  '002170.SZ',
#  '002171.SZ',
#  '002172.SZ',
#  '002173.SZ',
#  '002174.SZ',
#  '002175.SZ',
#  '002176.SZ',
#  '002177.SZ',
#  '002178.SZ',
#  '002179.SZ',
#  '002180.SZ',
#  '002181.SZ',
#  '002182.SZ',
#  '002183.SZ',
#  '002184.SZ',
#  '002185.SZ',
#  '002186.SZ',
#  '002187.SZ',
#  '002188.SZ',
#  '002189.SZ',
#  '002190.SZ',
#  '002191.SZ',
#  '002192.SZ',
#  '002193.SZ',
#  '002194.SZ',
#  '002195.SZ',
#  '002196.SZ',
#  '002197.SZ',
#  '002198.SZ',
#  '002199.SZ',
#  '0022.HK',
#  '0022.KL',
#  '002200.SZ',
#  '002201.SZ',
#  '002202.SZ',
#  '002203.SZ',
#  '002204.SZ',
#  '002205.SZ',
#  '002206.SZ',
#  '002207.SZ',
#  '002208.SZ',
#  '002209.SZ',
#  '002210.KS',
#  '002210.SZ',
#  '002211.SZ',
#  '002212.SZ',
#  '002213.SZ',
#  '002214.SZ',
#  '002215.SZ',
#  '002216.SZ',
#  '002217.SZ',
#  '002218.SZ',
#  '002219.SZ',
#  '002220.KS',
#  '002220.SZ',
#  '002221.SZ',
#  '002222.SZ',
#  '002223.SZ',
#  '002224.SZ',
#  '002225.SZ',
#  '002226.SZ',
#  '002227.SZ',
#  '002228.SZ',
#  '002229.SZ',
#  '002230.SZ',
#  '002231.SZ',
#  '002232.SZ',
#  '002233.SZ',
#  '002234.SZ',
#  '002235.SZ',
#  '002236.SZ',
#  '002237.SZ',
#  '002238.SZ',
#  '002239.SZ',
#  '002240.KS',
#  '002240.SZ',
#  '002241.SZ',
#  '002242.SZ',
#  '002243.SZ',
#  '002244.SZ',
#  '002245.SZ',
#  '002246.SZ',
#  '002247.SZ',
#  '002248.SZ',
#  '002249.SZ',
#  '002250.KS',
#  '002250.SZ',
#  '002251.SZ',
#  '002252.SZ',
#  '002253.SZ',
#  '002254.SZ',
#  '002255.SZ',
#  '002256.SZ',
#  '002258.SZ',
#  '002259.SZ',
#  '002260.SZ',
#  '002261.SZ',
#  '002262.SZ',
#  '002263.SZ',
#  '002264.SZ',
#  '002265.SZ',
#  '002266.SZ',
#  '002267.SZ',
#  '002268.SZ',
#  '002269.SZ',
#  '002270.KS',
#  '002270.SZ',
#  '002271.SZ',
#  '002272.SZ',
#  '002273.SZ',
#  '002274.SZ',
#  '002275.SZ',
#  '002276.SZ',
#  '002277.SZ',
#  '002278.SZ',
#  '002279.SZ',
#  '002280.SZ',
#  '002281.SZ',
#  '002282.SZ',
#  '002283.SZ',
#  '002284.SZ',
#  '002285.SZ',
#  '002286.SZ',
#  '002287.SZ',
#  '002288.SZ',
#  '002289.SZ',
#  '002290.SZ',
#  '002291.SZ',
#  '002292.SZ',
#  '002293.SZ',
#  '002294.SZ',
#  '002295.SZ',
#  '002296.SZ',
#  '002297.SZ',
#  '002298.SZ',
#  '002299.SZ',
#  '0023.HK',
#  '0023.KL',
#  '002300.KS',
#  '002300.SZ',
#  '002301.SZ',
#  '002302.SZ',
#  '002303.SZ',
#  '002304.SZ',
#  '002305.SZ',
#  '002306.SZ',
#  '002307.SZ',
#  '002308.SZ',
#  '002309.SZ',
#  '002310.KS',
#  '002310.SZ',
#  '002311.SZ',
#  '002312.SZ',
#  '002313.SZ',
#  '002314.SZ',
#  '002315.SZ',
#  '002316.SZ',
#  '002317.SZ',
#  '002318.SZ',
#  '002319.SZ',
#  '002320.SZ',
#  '002321.SZ',
#  '002322.SZ',
#  '002323.SZ',
#  '002324.SZ',
#  '002325.SZ',
#  '002326.SZ',
#  '002327.SZ',
#  '002328.SZ',
#  '002329.SZ',
#  '002330.SZ',
#  '002331.SZ',
#  '002332.SZ',
#  '002333.SZ',
#  '002334.SZ',
#  '002335.SZ',
#  '002336.SZ',
#  '002337.SZ',
#  '002338.SZ',
#  '002339.SZ',
#  '002340.SZ',
#  '002341.SZ',
#  '002342.SZ',
#  '002343.SZ',
#  '002344.SZ',
#  '002345.SZ',
#  '002346.SZ',
#  '002347.SZ',
#  '002348.SZ',
#  '002349.SZ',
#  '002350.KS',
#  '002350.SZ',
#  '002351.SZ',
#  '002352.SZ',
#  '002353.SZ',
#  '002354.SZ',
#  '002355.SZ',
#  '002356.SZ',
#  '002357.SZ',
#  '002358.SZ',
#  '002359.SZ',
#  '002360.KS',
#  '002360.SZ',
#  '002361.SZ',
#  '002362.SZ',
#  '002363.SZ',
#  '002364.SZ',
#  '002365.SZ',
#  '002366.SZ',
#  '002367.SZ',
#  '002368.SZ',
#  '002369.SZ',
#  '002370.SZ',
#  '002371.SZ',
#  '002372.SZ',
#  '002373.SZ',
#  '002374.SZ',
#  '002375.SZ',
#  '002376.SZ',
#  '002377.SZ',
#  '002378.SZ',
#  '002379.SZ',
#  '002380.SZ',
#  '002381.SZ',
#  '002382.SZ',
#  '002383.SZ',
#  '002384.SZ',
#  '002385.SZ',
#  '002386.SZ',
#  '002387.SZ',
#  ...]

# %%
get_symbol = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={symbol}&apikey={api_key}'

# %%
res = requests.get(get_stock).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2520693ddfe2> in <module>
# ----> 1 res = requests.get(get_stock).json()
#
# NameError: name 'get_stock' is not defined

# %%
requests.get(f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={api_key}').json();

# %%
requests.get(get_symbol).json();

# %%
from datetime import date, datetime
import time
from enum import Enum

class Urls(Enum):
    STOCK_PRICE = 'https://financialmodelingprep.com/api/v3/historical-price-full'
    VOLUME_PRICE = 'https://financialmodelingprep.com/api/v3/volume-price-full'
    API_KEY = 'aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'
    
def url(ticker):
    from_date = time.mktime(datetime(2005, 1, 1).timetuple())
    to_date = time.mktime(datetime.now().timetuple())
    print(from_date)
    print(to_date)
    return f'https://api.worldtradingdata.com/api/v1/history?symbol={ticker}&api_token={Urls.API_KEY.value}'
#     return f'https://finnhub.io/api/v1/stock/candle?symbol={ticker}&resolution=1&from={from_date}&to={to_date}&token={Urls.API_KEY.value}'
#'https://finnhub.io/api/v1/stock/candle?symbol=AAPL&resolution=1&from=04537600.0&to=1572910590&token=bpi2rsvrh5rbgl0l7vv0').json()

# %%
x = url('GS')
# Out:
# 1104537600.0
# 1583625841.0

# %%
x
# Out:
# 'https://api.worldtradingdata.com/api/v1/history?symbol=GS&api_token=aQpKQhT0CzMSf1ReEySVQCxvCY9XbMEOxjEQjHVoi11KJnN2bEwFAyfeivHy'

# %%
import requests

z = requests.get(x).json()

# %%
import pandas as pd
df= pd.DataFrame.from_dict(z['history'], orient='index')

# %%
# Out:
# {'2020-03-06': {'open': '190.68',
#   'close': '192.85',
#   'high': '196.30',
#   'low': '189.28',
#   'volume': '5071909'},
#  '2020-03-05': {'open': '201.33',
#   'close': '198.79',
#   'high': '203.47',
#   'low': '196.95',
#   'volume': '4151707'},
#  '2020-03-04': {'open': '205.84',
#   'close': '208.74',
#   'high': '208.92',
#   'low': '202.70',
#   'volume': '3520352'},
#  '2020-03-03': {'open': '209.00',
#   'close': '203.43',
#   'high': '211.79',
#   'low': '202.12',
#   'volume': '5677200'},
#  '2020-03-02': {'open': '201.41',
#   'close': '209.47',
#   'high': '209.62',
#   'low': '197.63',
#   'volume': '5285526'},
#  '2020-02-28': {'open': '199.09',
#   'close': '200.77',
#   'high': '202.25',
#   'low': '194.85',
#   'volume': '6740665'},
#  '2020-02-27': {'open': '210.49',
#   'close': '205.69',
#   'high': '213.48',
#   'low': '205.37',
#   'volume': '5848188'},
#  '2020-02-26': {'open': '218.70',
#   'close': '215.78',
#   'high': '220.00',
#   'low': '214.76',
#   'volume': '4172156'},
#  '2020-02-25': {'open': '224.78',
#   'close': '217.61',
#   'high': '225.87',
#   'low': '215.89',
#   'volume': '5343512'},
#  '2020-02-24': {'open': '223.23',
#   'close': '224.54',
#   'high': '226.69',
#   'low': '222.54',
#   'volume': '4139814'},
#  '2020-02-21': {'open': '230.91',
#   'close': '230.62',
#   'high': '231.80',
#   'low': '228.37',
#   'volume': '3082273'},
#  '2020-02-20': {'open': '236.41',
#   'close': '232.73',
#   'high': '236.90',
#   'low': '231.25',
#   'volume': '3183748'},
#  '2020-02-19': {'open': '235.00',
#   'close': '237.33',
#   'high': '237.80',
#   'low': '233.28',
#   'volume': '2207061'},
#  '2020-02-18': {'open': '236.55',
#   'close': '233.21',
#   'high': '237.07',
#   'low': '231.20',
#   'volume': '2737383'},
#  '2020-02-14': {'open': '237.94',
#   'close': '237.08',
#   'high': '239.01',
#   'low': '236.23',
#   'volume': '1718742'},
#  '2020-02-13': {'open': '237.85',
#   'close': '238.35',
#   'high': '238.97',
#   'low': '236.57',
#   'volume': '1461372'},
#  '2020-02-12': {'open': '238.01',
#   'close': '238.65',
#   'high': '241.18',
#   'low': '237.72',
#   'volume': '2119549'},
#  '2020-02-11': {'open': '239.00',
#   'close': '236.46',
#   'high': '239.55',
#   'low': '236.22',
#   'volume': '2238902'},
#  '2020-02-10': {'open': '237.40',
#   'close': '237.36',
#   'high': '237.87',
#   'low': '235.46',
#   'volume': '2591280'},
#  '2020-02-07': {'open': '239.75',
#   'close': '238.00',
#   'high': '240.52',
#   'low': '236.55',
#   'volume': '3006894'},
#  '2020-02-06': {'open': '245.35',
#   'close': '241.82',
#   'high': '245.77',
#   'low': '241.18',
#   'volume': '2225886'},
#  '2020-02-05': {'open': '244.99',
#   'close': '244.30',
#   'high': '245.13',
#   'low': '243.00',
#   'volume': '3126622'},
#  '2020-02-04': {'open': '242.88',
#   'close': '241.94',
#   'high': '243.74',
#   'low': '241.55',
#   'volume': '3052654'},
#  '2020-02-03': {'open': '238.36',
#   'close': '239.01',
#   'high': '242.39',
#   'low': '238.05',
#   'volume': '2733171'},
#  '2020-01-31': {'open': '241.99',
#   'close': '237.75',
#   'high': '242.89',
#   'low': '236.88',
#   'volume': '3482838'},
#  '2020-01-30': {'open': '237.69',
#   'close': '244.13',
#   'high': '244.34',
#   'low': '236.73',
#   'volume': '3261733'},
#  '2020-01-29': {'open': '244.52',
#   'close': '240.12',
#   'high': '246.50',
#   'low': '239.57',
#   'volume': '3713664'},
#  '2020-01-28': {'open': '239.49',
#   'close': '242.58',
#   'high': '243.58',
#   'low': '238.05',
#   'volume': '3123389'},
#  '2020-01-27': {'open': '236.37',
#   'close': '238.14',
#   'high': '238.99',
#   'low': '235.01',
#   'volume': '2506445'},
#  '2020-01-24': {'open': '245.07',
#   'close': '241.92',
#   'high': '245.71',
#   'low': '240.60',
#   'volume': '2877351'},
#  '2020-01-23': {'open': '244.50',
#   'close': '245.58',
#   'high': '247.00',
#   'low': '242.88',
#   'volume': '2806820'},
#  '2020-01-22': {'open': '246.61',
#   'close': '247.05',
#   'high': '248.52',
#   'low': '246.34',
#   'volume': '2031016'},
#  '2020-01-21': {'open': '247.21',
#   'close': '245.70',
#   'high': '248.85',
#   'low': '245.60',
#   'volume': '2492363'},
#  '2020-01-17': {'open': '250.23',
#   'close': '249.46',
#   'high': '250.46',
#   'low': '248.00',
#   'volume': '3108371'},
#  '2020-01-16': {'open': '247.01',
#   'close': '249.72',
#   'high': '249.82',
#   'low': '246.23',
#   'volume': '3968405'},
#  '2020-01-15': {'open': '242.00',
#   'close': '245.21',
#   'high': '249.50',
#   'low': '239.16',
#   'volume': '5411198'},
#  '2020-01-14': {'open': '245.32',
#   'close': '245.66',
#   'high': '248.52',
#   'low': '244.60',
#   'volume': '4309141'},
#  '2020-01-13': {'open': '244.44',
#   'close': '245.21',
#   'high': '246.11',
#   'low': '243.00',
#   'volume': '3321364'},
#  '2020-01-10': {'open': '242.75',
#   'close': '242.11',
#   'high': '243.39',
#   'low': '241.39',
#   'volume': '2249212'},
#  '2020-01-09': {'open': '241.34',
#   'close': '242.60',
#   'high': '243.40',
#   'low': '239.82',
#   'volume': '3982130'},
#  '2020-01-08': {'open': '235.68',
#   'close': '237.76',
#   'high': '239.75',
#   'low': '235.48',
#   'volume': '3564884'},
#  '2020-01-07': {'open': '235.00',
#   'close': '235.49',
#   'high': '237.77',
#   'low': '234.76',
#   'volume': '5393171'},
#  '2020-01-06': {'open': '229.93',
#   'close': '233.95',
#   'high': '234.02',
#   'low': '229.49',
#   'volume': '3329354'},
#  '2020-01-03': {'open': '231.60',
#   'close': '231.58',
#   'high': '232.61',
#   'low': '230.30',
#   'volume': '2276089'},
#  '2020-01-02': {'open': '231.00',
#   'close': '234.32',
#   'high': '234.64',
#   'low': '230.16',
#   'volume': '3737791'},
#  '2019-12-31': {'open': '229.71',
#   'close': '229.93',
#   'high': '229.97',
#   'low': '228.67',
#   'volume': '1447336'},
#  '2019-12-30': {'open': '231.68',
#   'close': '229.80',
#   'high': '231.68',
#   'low': '229.50',
#   'volume': '1494667'},
#  '2019-12-27': {'open': '231.81',
#   'close': '230.66',
#   'high': '232.21',
#   'low': '230.47',
#   'volume': '1343887'},
#  '2019-12-26': {'open': '230.26',
#   'close': '231.21',
#   'high': '232.20',
#   'low': '229.99',
#   'volume': '1704161'},
#  '2019-12-24': {'open': '228.98',
#   'close': '229.91',
#   'high': '229.95',
#   'low': '228.37',
#   'volume': '467722'},
#  '2019-12-23': {'open': '229.66',
#   'close': '229.09',
#   'high': '230.48',
#   'low': '228.41',
#   'volume': '1671705'},
#  '2019-12-20': {'open': '230.96',
#   'close': '228.93',
#   'high': '231.29',
#   'low': '228.62',
#   'volume': '3716158'},
#  '2019-12-19': {'open': '230.95',
#   'close': '229.94',
#   'high': '231.39',
#   'low': '228.96',
#   'volume': '2420063'},
#  '2019-12-18': {'open': '231.97',
#   'close': '230.45',
#   'high': '232.20',
#   'low': '229.94',
#   'volume': '2280912'},
#  '2019-12-17': {'open': '230.00',
#   'close': '231.15',
#   'high': '232.07',
#   'low': '228.80',
#   'volume': '3590439'},
#  '2019-12-16': {'open': '228.50',
#   'close': '228.04',
#   'high': '230.70',
#   'low': '227.87',
#   'volume': '3219426'},
#  '2019-12-13': {'open': '226.72',
#   'close': '225.00',
#   'high': '227.99',
#   'low': '223.70',
#   'volume': '1908510'},
#  '2019-12-12': {'open': '221.91',
#   'close': '226.05',
#   'high': '226.78',
#   'low': '220.60',
#   'volume': '2975577'},
#  '2019-12-11': {'open': '222.25',
#   'close': '221.19',
#   'high': '222.85',
#   'low': '220.84',
#   'volume': '1778596'},
#  '2019-12-10': {'open': '221.67',
#   'close': '221.88',
#   'high': '222.88',
#   'low': '220.55',
#   'volume': '1854483'},
#  '2019-12-09': {'open': '224.61',
#   'close': '221.81',
#   'high': '224.65',
#   'low': '221.77',
#   'volume': '2149451'},
#  '2019-12-06': {'open': '219.95',
#   'close': '224.61',
#   'high': '225.40',
#   'low': '218.82',
#   'volume': '4229733'},
#  '2019-12-05': {'open': '217.15',
#   'close': '217.14',
#   'high': '217.63',
#   'low': '215.42',
#   'volume': '1329572'},
#  '2019-12-04': {'open': '213.54',
#   'close': '215.94',
#   'high': '216.99',
#   'low': '212.38',
#   'volume': '1583647'},
#  '2019-12-03': {'open': '215.43',
#   'close': '212.24',
#   'high': '215.43',
#   'low': '210.00',
#   'volume': '3279762'},
#  '2019-12-02': {'open': '220.97',
#   'close': '217.64',
#   'high': '221.80',
#   'low': '217.08',
#   'volume': '2119133'},
#  '2019-11-29': {'open': '220.88',
#   'close': '221.35',
#   'high': '222.00',
#   'low': '220.41',
#   'volume': '770438'},
#  '2019-11-27': {'open': '223.45',
#   'close': '222.95',
#   'high': '224.28',
#   'low': '221.86',
#   'volume': '1615085'},
#  '2019-11-26': {'open': '222.68',
#   'close': '222.45',
#   'high': '222.76',
#   'low': '221.11',
#   'volume': '1926961'},
#  '2019-11-25': {'open': '220.89',
#   'close': '222.75',
#   'high': '223.95',
#   'low': '220.89',
#   'volume': '2181836'},
#  '2019-11-22': {'open': '218.00',
#   'close': '220.28',
#   'high': '220.71',
#   'low': '218.00',
#   'volume': '1529121'},
#  '2019-11-21': {'open': '218.60',
#   'close': '218.23',
#   'high': '219.32',
#   'low': '216.82',
#   'volume': '1677745'},
#  '2019-11-20': {'open': '218.36',
#   'close': '217.91',
#   'high': '219.47',
#   'low': '216.40',
#   'volume': '2177738'},
#  '2019-11-19': {'open': '220.56',
#   'close': '220.04',
#   'high': '220.68',
#   'low': '218.31',
#   'volume': '1817120'},
#  '2019-11-18': {'open': '219.73',
#   'close': '219.73',
#   'high': '219.95',
#   'low': '218.04',
#   'volume': '1603539'},
#  '2019-11-15': {'open': '220.00',
#   'close': '220.25',
#   'high': '221.09',
#   'low': '219.04',
#   'volume': '1693160'},
#  '2019-11-14': {'open': '218.79',
#   'close': '219.43',
#   'high': '220.47',
#   'low': '218.03',
#   'volume': '1483216'},
#  '2019-11-13': {'open': '218.39',
#   'close': '219.32',
#   'high': '219.84',
#   'low': '217.01',
#   'volume': '1769133'},
#  '2019-11-12': {'open': '218.56',
#   'close': '220.41',
#   'high': '221.11',
#   'low': '217.93',
#   'volume': '1891598'},
#  '2019-11-11': {'open': '220.90',
#   'close': '219.03',
#   'high': '221.41',
#   'low': '218.52',
#   'volume': '2755038'},
#  '2019-11-08': {'open': '223.00',
#   'close': '222.91',
#   'high': '223.23',
#   'low': '221.10',
#   'volume': '1610873'},
#  '2019-11-07': {'open': '220.77',
#   'close': '223.29',
#   'high': '224.77',
#   'low': '220.41',
#   'volume': '3748660'},
#  '2019-11-06': {'open': '218.01',
#   'close': '218.42',
#   'high': '219.07',
#   'low': '216.55',
#   'volume': '1863038'},
#  '2019-11-05': {'open': '220.80',
#   'close': '218.64',
#   'high': '221.78',
#   'low': '218.47',
#   'volume': '2525109'},
#  '2019-11-04': {'open': '219.70',
#   'close': '219.87',
#   'high': '220.69',
#   'low': '218.57',
#   'volume': '2538122'},
#  '2019-11-01': {'open': '215.26',
#   'close': '217.39',
#   'high': '217.89',
#   'low': '214.75',
#   'volume': '2112310'},
#  '2019-10-31': {'open': '215.15',
#   'close': '213.38',
#   'high': '215.36',
#   'low': '211.32',
#   'volume': '1876214'},
#  '2019-10-30': {'open': '217.02',
#   'close': '215.81',
#   'high': '217.05',
#   'low': '213.81',
#   'volume': '1584888'},
#  '2019-10-29': {'open': '217.22',
#   'close': '217.64',
#   'high': '219.28',
#   'low': '216.45',
#   'volume': '2030786'},
#  '2019-10-28': {'open': '216.32',
#   'close': '217.75',
#   'high': '218.92',
#   'low': '215.69',
#   'volume': '2707775'},
#  '2019-10-25': {'open': '210.18',
#   'close': '214.23',
#   'high': '215.42',
#   'low': '210.18',
#   'volume': '2602050'},
#  '2019-10-24': {'open': '211.61',
#   'close': '211.05',
#   'high': '213.15',
#   'low': '209.78',
#   'volume': '1273179'},
#  '2019-10-23': {'open': '209.22',
#   'close': '211.32',
#   'high': '212.02',
#   'low': '209.00',
#   'volume': '1583225'},
#  '2019-10-22': {'open': '209.59',
#   'close': '209.60',
#   'high': '211.65',
#   'low': '208.31',
#   'volume': '1885431'},
#  '2019-10-21': {'open': '208.67',
#   'close': '209.25',
#   'high': '210.86',
#   'low': '207.68',
#   'volume': '1958379'},
#  '2019-10-18': {'open': '204.99',
#   'close': '206.52',
#   'high': '208.06',
#   'low': '204.99',
#   'volume': '2207607'},
#  '2019-10-17': {'open': '208.29',
#   'close': '206.46',
#   'high': '208.93',
#   'low': '204.39',
#   'volume': '2893459'},
#  '2019-10-16': {'open': '206.17',
#   'close': '207.42',
#   'high': '208.62',
#   'low': '206.10',
#   'volume': '3447187'},
#  '2019-10-15': {'open': '202.00',
#   'close': '206.46',
#   'high': '208.24',
#   'low': '198.61',
#   'volume': '8303263'},
#  '2019-10-14': {'open': '203.83',
#   'close': '205.82',
#   'high': '206.17',
#   'low': '202.92',
#   'volume': '2303649'},
#  '2019-10-11': {'open': '203.72',
#   'close': '204.68',
#   'high': '207.29',
#   'low': '203.72',
#   'volume': '3342623'},
#  '2019-10-10': {'open': '197.59',
#   'close': '199.87',
#   'high': '201.32',
#   'low': '197.54',
#   'volume': '2114131'},
#  '2019-10-09': {'open': '198.19',
#   'close': '196.85',
#   'high': '198.98',
#   'low': '196.68',
#   'volume': '2457007'},
#  '2019-10-08': {'open': '197.60',
#   'close': '197.37',
#   'high': '198.95',
#   'low': '195.92',
#   'volume': '2674425'},
#  '2019-10-07': {'open': '200.79',
#   'close': '200.40',
#   'high': '202.53',
#   'low': '199.47',
#   'volume': '2210318'},
#  '2019-10-04': {'open': '196.99',
#   'close': '200.80',
#   'high': '201.23',
#   'low': '196.04',
#   'volume': '3028781'},
#  '2019-10-03': {'open': '197.61',
#   'close': '197.24',
#   'high': '198.37',
#   'low': '193.99',
#   'volume': '2923698'},
#  '2019-10-02': {'open': '201.69',
#   'close': '198.25',
#   'high': '201.88',
#   'low': '197.60',
#   'volume': '3395299'},
#  '2019-10-01': {'open': '207.01',
#   'close': '202.69',
#   'high': '209.38',
#   'low': '202.61',
#   'volume': '3171507'},
#  '2019-09-30': {'open': '209.71',
#   'close': '207.23',
#   'high': '209.71',
#   'low': '206.83',
#   'volume': '1798010'},
#  '2019-09-27': {'open': '209.85',
#   'close': '208.97',
#   'high': '210.55',
#   'low': '208.09',
#   'volume': '1531374'},
#  '2019-09-26': {'open': '209.05',
#   'close': '208.22',
#   'high': '209.97',
#   'low': '208.11',
#   'volume': '1692716'},
#  '2019-09-25': {'open': '207.96',
#   'close': '210.03',
#   'high': '211.09',
#   'low': '207.45',
#   'volume': '1609841'},
#  '2019-09-24': {'open': '214.04',
#   'close': '207.75',
#   'high': '214.20',
#   'low': '206.80',
#   'volume': '2885686'},
#  '2019-09-23': {'open': '212.85',
#   'close': '213.46',
#   'high': '214.11',
#   'low': '211.56',
#   'volume': '1565762'},
#  '2019-09-20': {'open': '214.66',
#   'close': '213.74',
#   'high': '216.68',
#   'low': '213.63',
#   'volume': '5490118'},
#  '2019-09-19': {'open': '217.58',
#   'close': '215.23',
#   'high': '217.93',
#   'low': '215.06',
#   'volume': '1611076'},
#  '2019-09-18': {'open': '214.83',
#   'close': '217.08',
#   'high': '217.89',
#   'low': '213.30',
#   'volume': '2492485'},
#  '2019-09-17': {'open': '215.80',
#   'close': '215.91',
#   'high': '216.14',
#   'low': '212.54',
#   'volume': '2467394'},
#  '2019-09-16': {'open': '217.82',
#   'close': '217.22',
#   'high': '219.33',
#   'low': '216.32',
#   'volume': '2205543'},
#  '2019-09-13': {'open': '220.35',
#   'close': '219.90',
#   'high': '221.50',
#   'low': '219.20',
#   'volume': '2722411'},
#  '2019-09-12': {'open': '216.38',
#   'close': '218.74',
#   'high': '220.76',
#   'low': '215.15',
#   'volume': '2913786'},
#  '2019-09-11': {'open': '215.21',
#   'close': '216.80',
#   'high': '216.85',
#   'low': '213.36',
#   'volume': '1886291'},
#  '2019-09-10': {'open': '213.50',
#   'close': '215.63',
#   'high': '217.09',
#   'low': '213.22',
#   'volume': '2616235'},
#  '2019-09-09': {'open': '209.22',
#   'close': '211.98',
#   'high': '213.88',
#   'low': '208.44',
#   'volume': '2734609'},
#  '2019-09-06': {'open': '207.06',
#   'close': '207.21',
#   'high': '208.25',
#   'low': '205.57',
#   'volume': '1439087'},
#  '2019-09-05': {'open': '205.27',
#   'close': '207.05',
#   'high': '208.93',
#   'low': '205.04',
#   'volume': '2237906'},
#  '2019-09-04': {'open': '201.49',
#   'close': '201.73',
#   'high': '202.10',
#   'low': '200.05',
#   'volume': '1736967'},
#  '2019-09-03': {'open': '201.10',
#   'close': '198.97',
#   'high': '201.61',
#   'low': '196.58',
#   'volume': '2633970'},
#  '2019-08-30': {'open': '204.85',
#   'close': '203.91',
#   'high': '205.21',
#   'low': '203.01',
#   'volume': '1529629'},
#  '2019-08-29': {'open': '201.36',
#   'close': '203.44',
#   'high': '204.37',
#   'low': '201.36',
#   'volume': '1817824'},
#  '2019-08-28': {'open': '196.57',
#   'close': '200.42',
#   'high': '201.47',
#   'low': '196.25',
#   'volume': '1444021'},
#  '2019-08-27': {'open': '200.33',
#   'close': '198.07',
#   'high': '200.86',
#   'low': '196.50',
#   'volume': '1513448'},
#  '2019-08-26': {'open': '198.27',
#   'close': '199.65',
#   'high': '199.71',
#   'low': '198.00',
#   'volume': '1442394'},
#  '2019-08-23': {'open': '200.81',
#   'close': '196.20',
#   'high': '201.88',
#   'low': '195.19',
#   'volume': '2201526'},
#  '2019-08-22': {'open': '202.28',
#   'close': '202.42',
#   'high': '203.45',
#   'low': '200.91',
#   'volume': '1276379'},
#  '2019-08-21': {'open': '202.74',
#   'close': '200.68',
#   'high': '203.02',
#   'low': '200.17',
#   'volume': '1161185'},
#  '2019-08-20': {'open': '200.21',
#   'close': '199.98',
#   'high': '201.99',
#   'low': '199.70',
#   'volume': '1545894'},
#  '2019-08-19': {'open': '203.81',
#   'close': '202.20',
#   'high': '204.45',
#   'low': '201.82',
#   'volume': '1646082'},
#  '2019-08-16': {'open': '197.03',
#   'close': '199.42',
#   'high': '200.67',
#   'low': '197.00',
#   'volume': '1878739'},
#  '2019-08-15': {'open': '195.91',
#   'close': '196.18',
#   'high': '196.97',
#   'low': '193.71',
#   'volume': '1981913'},
#  '2019-08-14': {'open': '199.80',
#   'close': '195.56',
#   'high': '199.91',
#   'low': '195.06',
#   'volume': '3025103'},
#  '2019-08-13': {'open': '201.51',
#   'close': '204.11',
#   'high': '206.60',
#   'low': '200.23',
#   'volume': '2157671'},
#  '2019-08-12': {'open': '203.28',
#   'close': '201.52',
#   'high': '204.15',
#   'low': '200.48',
#   'volume': '1479335'},
#  '2019-08-09': {'open': '205.62',
#   'close': '206.90',
#   'high': '208.30',
#   'low': '203.86',
#   'volume': '1790148'},
#  '2019-08-08': {'open': '207.17',
#   'close': '207.00',
#   'high': '207.80',
#   'low': '203.54',
#   'volume': '2342226'},
#  '2019-08-07': {'open': '201.11',
#   'close': '205.74',
#   'high': '205.96',
#   'low': '199.05',
#   'volume': '2454249'},
#  '2019-08-06': {'open': '203.56',
#   'close': '206.01',
#   'high': '206.07',
#   'low': '200.89',
#   'volume': '2349383'},
#  '2019-08-05': {'open': '205.82',
#   'close': '201.68',
#   'high': '205.82',
#   'low': '199.58',
#   'volume': '2794194'},
#  '2019-08-02': {'open': '211.58',
#   'close': '209.37',
#   'high': '211.58',
#   'low': '205.31',
#   'volume': '2502996'},
#  '2019-08-01': {'open': '219.35',
#   'close': '211.60',
#   'high': '219.95',
#   'low': '210.76',
#   'volume': '3070149'},
#  '2019-07-31': {'open': '221.24',
#   'close': '220.13',
#   'high': '221.98',
#   'low': '219.01',
#   'volume': '1991056'},
#  '2019-07-30': {'open': '218.49',
#   'close': '221.40',
#   'high': '221.99',
#   'low': '217.33',
#   'volume': '1644552'},
#  '2019-07-29': {'open': '221.00',
#   'close': '220.32',
#   'high': '222.13',
#   'low': '220.20',
#   'volume': '1372767'},
#  '2019-07-26': {'open': '220.45',
#   'close': '222.14',
#   'high': '222.24',
#   'low': '220.37',
#   'volume': '2304848'},
#  '2019-07-25': {'open': '221.77',
#   'close': '219.98',
#   'high': '221.77',
#   'low': '218.23',
#   'volume': '2777134'},
#  '2019-07-24': {'open': '219.25',
#   'close': '222.03',
#   'high': '222.09',
#   'low': '218.63',
#   'volume': '3180106'},
#  '2019-07-23': {'open': '214.95',
#   'close': '219.43',
#   'high': '220.00',
#   'low': '214.95',
#   'volume': '3330637'},
#  '2019-07-22': {'open': '213.40',
#   'close': '214.00',
#   'high': '214.86',
#   'low': '212.31',
#   'volume': '1907237'},
#  '2019-07-19': {'open': '214.02',
#   'close': '213.52',
#   'high': '215.77',
#   'low': '213.35',
#   'volume': '1822284'},
#  '2019-07-18': {'open': '212.71',
#   'close': '214.52',
#   'high': '215.83',
#   'low': '211.75',
#   'volume': '2858986'},
#  '2019-07-17': {'open': '213.83',
#   'close': '213.30',
#   'high': '215.78',
#   'low': '213.16',
#   'volume': '2583462'},
#  '2019-07-16': {'open': '214.80',
#   'close': '215.52',
#   'high': '217.33',
#   'low': '212.55',
#   'volume': '5283690'},
#  '2019-07-15': {'open': '214.11',
#   'close': '211.58',
#   'high': '214.60',
#   'low': '209.79',
#   'volume': '2600222'},
#  '2019-07-12': {'open': '212.00',
#   'close': '213.94',
#   'high': '214.19',
#   'low': '210.79',
#   'volume': '2626026'},
#  '2019-07-11': {'open': '206.20',
#   'close': '211.35',
#   'high': '212.59',
#   'low': '206.00',
#   'volume': '3691619'},
#  '2019-07-10': {'open': '207.18',
#   'close': '205.97',
#   'high': '208.99',
#   'low': '205.65',
#   'volume': '1779844'},
#  '2019-07-09': {'open': '203.75',
#   'close': '207.77',
#   'high': '207.94',
#   'low': '203.54',
#   'volume': '1812186'},
#  '2019-07-08': {'open': '206.36',
#   'close': '205.75',
#   'high': '207.25',
#   'low': '204.71',
#   'volume': '1853938'},
#  '2019-07-05': {'open': '206.86',
#   'close': '207.90',
#   'high': '208.76',
#   'low': '206.20',
#   'volume': '1511445'},
#  '2019-07-03': {'open': '207.30',
#   'close': '206.04',
#   'high': '207.40',
#   'low': '205.23',
#   'volume': '978795'},
#  '2019-07-02': {'open': '205.40',
#   'close': '205.98',
#   'high': '206.31',
#   'low': '204.16',
#   'volume': '1626880'},
#  '2019-07-01': {'open': '208.00',
#   'close': '206.86',
#   'high': '209.85',
#   'low': '205.74',
#   'volume': '2468489'},
#  '2019-06-28': {'open': '203.50',
#   'close': '204.60',
#   'high': '205.84',
#   'low': '202.94',
#   'volume': '4854919'},
#  '2019-06-27': {'open': '197.57',
#   'close': '199.32',
#   'high': '199.61',
#   'low': '196.76',
#   'volume': '2239186'},
#  '2019-06-26': {'open': '196.50',
#   'close': '197.01',
#   'high': '197.87',
#   'low': '196.12',
#   'volume': '1649866'},
#  '2019-06-25': {'open': '197.50',
#   'close': '196.06',
#   'high': '197.52',
#   'low': '194.01',
#   'volume': '1828309'},
#  '2019-06-24': {'open': '196.53',
#   'close': '197.49',
#   'high': '199.35',
#   'low': '196.03',
#   'volume': '2069816'},
#  '2019-06-21': {'open': '195.34',
#   'close': '195.94',
#   'high': '198.34',
#   'low': '193.97',
#   'volume': '3365504'},
#  '2019-06-20': {'open': '197.50',
#   'close': '195.70',
#   'high': '198.19',
#   'low': '193.61',
#   'volume': '2749296'},
#  '2019-06-19': {'open': '195.35',
#   'close': '195.64',
#   'high': '197.61',
#   'low': '194.79',
#   'volume': '2196816'},
#  '2019-06-18': {'open': '190.67',
#   'close': '194.98',
#   'high': '197.13',
#   'low': '190.67',
#   'volume': '2362978'},
#  '2019-06-17': {'open': '192.02',
#   'close': '190.83',
#   'high': '193.23',
#   'low': '190.74',
#   'volume': '1155579'},
#  '2019-06-14': {'open': '191.29',
#   'close': '191.66',
#   'high': '192.17',
#   'low': '189.31',
#   'volume': '1403930'},
#  '2019-06-13': {'open': '190.41',
#   'close': '191.45',
#   'high': '192.25',
#   'low': '190.07',
#   'volume': '1411616'},
#  '2019-06-12': {'open': '193.61',
#   'close': '190.22',
#   'high': '194.05',
#   'low': '189.83',
#   'volume': '2059406'},
#  '2019-06-11': {'open': '195.30',
#   'close': '194.73',
#   'high': '196.12',
#   'low': '193.51',
#   'volume': '1632227'},
#  '2019-06-10': {'open': '191.40',
#   'close': '194.12',
#   'high': '197.00',
#   'low': '191.40',
#   'volume': '2372134'},
#  '2019-06-07': {'open': '189.88',
#   'close': '189.81',
#   'high': '190.61',
#   'low': '188.52',
#   'volume': '1838954'},
#  '2019-06-06': {'open': '188.06',
#   'close': '189.81',
#   'high': '190.74',
#   'low': '187.31',
#   'volume': '1653532'},
#  '2019-06-05': {'open': '190.10',
#   'close': '188.44',
#   'high': '190.16',
#   'low': '187.01',
#   'volume': '1968185'},
#  '2019-06-04': {'open': '186.18',
#   'close': '189.88',
#   'high': '189.99',
#   'low': '185.71',
#   'volume': '2421063'},
#  '2019-06-03': {'open': '181.70',
#   'close': '183.19',
#   'high': '183.49',
#   'low': '180.73',
#   'volume': '2857821'},
#  '2019-05-31': {'open': '184.77',
#   'close': '182.49',
#   'high': '184.89',
#   'low': '182.31',
#   'volume': '2640393'},
#  '2019-05-30': {'open': '188.09',
#   'close': '187.37',
#   'high': '189.37',
#   'low': '186.01',
#   'volume': '1919327'},
#  '2019-05-29': {'open': '187.74',
#   'close': '188.05',
#   'high': '188.65',
#   'low': '184.92',
#   'volume': '2815797'},
#  '2019-05-28': {'open': '192.00',
#   'close': '189.44',
#   'high': '193.31',
#   'low': '189.39',
#   'volume': '3039950'},
#  '2019-05-24': {'open': '192.89',
#   'close': '193.00',
#   'high': '194.07',
#   'low': '191.68',
#   'volume': '1637338'},
#  '2019-05-23': {'open': '193.00',
#   'close': '191.97',
#   'high': '193.00',
#   'low': '189.56',
#   'volume': '3184179'},
#  '2019-05-22': {'open': '197.44',
#   'close': '195.52',
#   'high': '198.48',
#   'low': '195.46',
#   'volume': '2427247'},
#  '2019-05-21': {'open': '198.66',
#   'close': '199.11',
#   'high': '199.32',
#   'low': '198.00',
#   'volume': '2327767'},
#  '2019-05-20': {'open': '197.09',
#   'close': '197.24',
#   'high': '197.78',
#   'low': '195.57',
#   'volume': '2483484'},
#  '2019-05-17': {'open': '196.30',
#   'close': '197.43',
#   'high': '199.09',
#   'low': '196.30',
#   'volume': '1928394'},
#  '2019-05-16': {'open': '196.63',
#   'close': '199.14',
#   'high': '200.00',
#   'low': '196.62',
#   'volume': '2008310'},
#  '2019-05-15': {'open': '194.64',
#   'close': '196.40',
#   'high': '197.59',
#   'low': '193.42',
#   'volume': '2271501'},
#  '2019-05-14': {'open': '194.99',
#   'close': '196.28',
#   'high': '198.13',
#   'low': '194.90',
#   'volume': '2463391'},
#  '2019-05-13': {'open': '197.90',
#   'close': '194.97',
#   'high': '197.90',
#   'low': '194.00',
#   'volume': '3605565'},
#  '2019-05-10': {'open': '200.98',
#   'close': '202.05',
#   'high': '202.10',
#   'low': '198.99',
#   'volume': '2089764'},
#  '2019-05-09': {'open': '199.51',
#   'close': '201.63',
#   'high': '202.22',
#   'low': '197.91',
#   'volume': '2333539'},
#  '2019-05-08': {'open': '201.40',
#   'close': '200.95',
#   'high': '203.20',
#   'low': '200.80',
#   'volume': '1817714'},
#  '2019-05-07': {'open': '203.34',
#   'close': '202.63',
#   'high': '204.00',
#   'low': '201.01',
#   'volume': '2839464'},
#  '2019-05-06': {'open': '202.80',
#   'close': '206.43',
#   'high': '206.98',
#   'low': '201.71',
#   'volume': '1927994'},
#  '2019-05-03': {'open': '206.01',
#   'close': '207.52',
#   'high': '208.75',
#   'low': '205.67',
#   'volume': '1897692'},
#  '2019-05-02': {'open': '204.43',
#   'close': '204.99',
#   'high': '206.22',
#   'low': '203.12',
#   'volume': '1514660'},
#  '2019-05-01': {'open': '206.40',
#   'close': '204.73',
#   'high': '208.41',
#   'low': '204.03',
#   'volume': '1981789'},
#  '2019-04-30': {'open': '206.94',
#   'close': '205.92',
#   'high': '207.99',
#   'low': '204.15',
#   'volume': '1833416'},
#  '2019-04-29': {'open': '203.50',
#   'close': '206.92',
#   'high': '208.00',
#   'low': '203.27',
#   'volume': '2997024'},
#  '2019-04-26': {'open': '201.73',
#   'close': '203.08',
#   'high': '203.12',
#   'low': '200.32',
#   'volume': '1543137'},
#  '2019-04-25': {'open': '199.70',
#   'close': '201.40',
#   'high': '202.56',
#   'low': '199.10',
#   'volume': '2075273'},
#  '2019-04-24': {'open': '203.00',
#   'close': '200.54',
#   'high': '203.52',
#   'low': '199.73',
#   'volume': '4606367'},
#  '2019-04-23': {'open': '204.25',
#   'close': '204.14',
#   'high': '205.19',
#   'low': '202.74',
#   'volume': '2121243'},
#  '2019-04-22': {'open': '205.12',
#   'close': '204.60',
#   'high': '205.59',
#   'low': '204.14',
#   'volume': '1591430'},
#  '2019-04-18': {'open': '207.09',
#   'close': '205.91',
#   'high': '207.86',
#   'low': '205.15',
#   'volume': '2874292'},
#  '2019-04-17': {'open': '201.96',
#   'close': '207.90',
#   'high': '208.50',
#   'low': '201.78',
#   'volume': '4195336'},
#  '2019-04-16': {'open': '199.62',
#   'close': '201.84',
#   'high': '202.94',
#   'low': '199.24',
#   'volume': '4852969'},
#  '2019-04-15': {'open': '204.11',
#   'close': '199.91',
#   'high': '205.74',
#   'low': '199.70',
#   'volume': '6617232'},
#  '2019-04-12': {'open': '207.00',
#   'close': '207.84',
#   'high': '209.97',
#   'low': '206.37',
#   'volume': '5096630'},
#  '2019-04-11': {'open': '204.23',
#   'close': '202.83',
#   'high': '205.45',
#   'low': '201.57',
#   'volume': '2802400'},
#  '2019-04-10': {'open': '201.80',
#   'close': '202.98',
#   'high': '203.17',
#   'low': '200.27',
#   'volume': '1907115'},
#  '2019-04-09': {'open': '201.23',
#   'close': '200.62',
#   'high': '201.59',
#   'low': '198.86',
#   'volume': '2400893'},
#  '2019-04-08': {'open': '202.79',
#   'close': '202.54',
#   'high': '203.63',
#   'low': '201.18',
#   'volume': '1891580'},
#  '2019-04-05': {'open': '203.38',
#   'close': '202.38',
#   'high': '205.50',
#   'low': '202.06',
#   'volume': '2447288'},
#  '2019-04-04': {'open': '200.80',
#   'close': '202.23',
#   'high': '204.29',
#   'low': '200.50',
#   'volume': '2582379'},
#  '2019-04-03': {'open': '199.25',
#   'close': '200.86',
#   'high': '201.09',
#   'low': '198.54',
#   'volume': '3227885'},
#  '2019-04-02': {'open': '196.24',
#   'close': '197.50',
#   'high': '197.76',
#   'low': '195.40',
#   'volume': '2246979'},
#  '2019-04-01': {'open': '194.00',
#   'close': '196.74',
#   'high': '198.09',
#   'low': '193.61',
#   'volume': '3562556'},
#  '2019-03-29': {'open': '192.68',
#   'close': '191.99',
#   'high': '193.11',
#   'low': '191.14',
#   'volume': '2632797'},
#  '2019-03-28': {'open': '190.74',
#   'close': '191.18',
#   'high': '191.91',
#   'low': '189.29',
#   'volume': '2343428'},
#  '2019-03-27': {'open': '190.60',
#   'close': '190.03',
#   'high': '191.61',
#   'low': '188.74',
#   'volume': '2343810'},
#  '2019-03-26': {'open': '190.03',
#   'close': '190.69',
#   'high': '192.41',
#   'low': '188.69',
#   'volume': '2910110'},
#  '2019-03-25': {'open': '189.33',
#   'close': '188.51',
#   'high': '191.45',
#   'low': '186.50',
#   'volume': '3751226'},
#  '2019-03-22': {'open': '192.67',
#   'close': '188.96',
#   'high': '193.71',
#   'low': '187.78',
#   'volume': '5703063'},
#  '2019-03-21': {'open': '192.90',
#   'close': '194.58',
#   'high': '195.55',
#   'low': '191.75',
#   'volume': '4031526'},
#  '2019-03-20': {'open': '200.33',
#   'close': '194.32',
#   'high': '200.33',
#   'low': '193.97',
#   'volume': '5033491'},
#  '2019-03-19': {'open': '204.88',
#   'close': '201.12',
#   'high': '206.45',
#   'low': '200.78',
#   'volume': '3284871'},
#  '2019-03-18': {'open': '199.18',
#   'close': '202.47',
#   'high': '203.85',
#   'low': '198.92',
#   'volume': '3355202'},
#  '2019-03-15': {'open': '197.16',
#   'close': '198.26',
#   'high': '198.85',
#   'low': '196.85',
#   'volume': '2985264'},
#  '2019-03-14': {'open': '197.32',
#   'close': '197.47',
#   'high': '198.50',
#   'low': '196.70',
#   'volume': '1482382'},
#  '2019-03-13': {'open': '197.75',
#   'close': '197.25',
#   'high': '198.93',
#   'low': '196.52',
#   'volume': '1904531'},
#  '2019-03-12': {'open': '196.00',
#   'close': '196.63',
#   'high': '197.40',
#   'low': '195.69',
#   'volume': '1977361'},
#  '2019-03-11': {'open': '197.23',
#   'close': '195.97',
#   'high': '198.97',
#   'low': '195.73',
#   'volume': '2669014'},
#  '2019-03-08': {'open': '190.40',
#   'close': '195.24',
#   'high': '195.77',
#   'low': '189.71',
#   'volume': '3162760'},
#  '2019-03-07': {'open': '193.13',
#   'close': '192.77',
#   'high': '193.45',
#   'low': '190.08',
#   'volume': '3567935'},
#  '2019-03-06': {'open': '195.90',
#   'close': '194.74',
#   'high': '197.56',
#   'low': '194.53',
#   'volume': '2247480'},
#  '2019-03-05': {'open': '195.85',
#   'close': '196.00',
#   'high': '196.18',
#   'low': '193.00',
#   'volume': '2338725'},
#  '2019-03-04': {'open': '198.81',
#   'close': '195.98',
#   'high': '200.83',
#   'low': '194.15',
#   'volume': '2683593'},
#  '2019-03-01': {'open': '198.75',
#   'close': '198.20',
#   'high': '201.44',
#   'low': '197.43',
#   'volume': '2580797'},
#  '2019-02-28': {'open': '198.04',
#   'close': '196.70',
#   'high': '198.40',
#   'low': '196.01',
#   'volume': '2964439'},
#  '2019-02-27': {'open': '198.50',
#   'close': '198.10',
#   'high': '199.89',
#   'low': '197.12',
#   'volume': '1804501'},
#  '2019-02-26': {'open': '198.47',
#   'close': '198.90',
#   'high': '200.56',
#   'low': '196.55',
#   'volume': '2499795'},
#  '2019-02-25': {'open': '198.00',
#   'close': '198.65',
#   'high': '201.50',
#   'low': '197.71',
#   'volume': '3032171'},
#  '2019-02-22': {'open': '196.60',
#   'close': '196.00',
#   'high': '197.75',
#   'low': '195.20',
#   'volume': '2626634'},
#  '2019-02-21': {'open': '198.97',
#   'close': '196.36',
#   'high': '199.45',
#   'low': '195.05',
#   'volume': '2786021'},
#  '2019-02-20': {'open': '198.73',
#   'close': '198.60',
#   'high': '199.30',
#   'low': '197.51',
#   'volume': '2265991'},
#  '2019-02-19': {'open': '196.66',
#   'close': '198.67',
#   'high': '199.06',
#   'low': '195.61',
#   'volume': '2558186'},
#  '2019-02-15': {'open': '193.21',
#   'close': '198.50',
#   'high': '198.89',
#   'low': '193.10',
#   'volume': '3065444'},
#  '2019-02-14': {'open': '192.21',
#   'close': '192.53',
#   'high': '194.13',
#   'low': '189.44',
#   'volume': '2864952'},
#  '2019-02-13': {'open': '195.92',
#   'close': '194.69',
#   'high': '198.78',
#   'low': '194.60',
#   'volume': '2757343'},
#  '2019-02-12': {'open': '193.05',
#   'close': '194.49',
#   'high': '195.65',
#   'low': '193.00',
#   'volume': '2392931'},
#  '2019-02-11': {'open': '192.88',
#   'close': '191.33',
#   'high': '193.32',
#   'low': '191.07',
#   'volume': '2056684'},
#  '2019-02-08': {'open': '191.72',
#   'close': '191.67',
#   'high': '192.62',
#   'low': '188.22',
#   'volume': '2757596'},
#  '2019-02-07': {'open': '195.28',
#   'close': '193.07',
#   'high': '195.88',
#   'low': '191.05',
#   'volume': '2948750'},
#  '2019-02-06': {'open': '197.18',
#   'close': '196.62',
#   'high': '199.06',
#   'low': '195.83',
#   'volume': '2063097'},
#  '2019-02-05': {'open': '198.12',
#   'close': '198.01',
#   'high': '199.33',
#   'low': '196.86',
#   'volume': '2601036'},
#  '2019-02-04': {'open': '195.80',
#   'close': '197.72',
#   'high': '197.76',
#   'low': '194.79',
#   'volume': '2400169'},
#  '2019-02-01': {'open': '198.00',
#   'close': '196.54',
#   'high': '199.64',
#   'low': '196.54',
#   'volume': '3174301'},
#  '2019-01-31': {'open': '200.10',
#   'close': '198.01',
#   'high': '202.35',
#   'low': '196.95',
#   'volume': '5604546'},
#  '2019-01-30': {'open': '200.90',
#   'close': '202.48',
#   'high': '203.29',
#   'low': '199.65',
#   'volume': '2773366'},
#  '2019-01-29': {'open': '199.00',
#   'close': '200.50',
#   'high': '201.97',
#   'low': '197.87',
#   'volume': '2694125'},
#  '2019-01-28': {'open': '197.99',
#   'close': '199.72',
#   'high': '200.07',
#   'low': '197.10',
#   'volume': '2369554'},
#  '2019-01-25': {'open': '199.83',
#   'close': '200.74',
#   'high': '201.19',
#   'low': '199.42',
#   'volume': '3275461'},
#  '2019-01-24': {'open': '196.22',
#   'close': '197.80',
#   'high': '199.68',
#   'low': '195.76',
#   'volume': '2632011'},
#  '2019-01-23': {'open': '197.55',
#   'close': '196.90',
#   'high': '198.09',
#   'low': '194.53',
#   'volume': '3410681'},
#  '2019-01-22': {'open': '200.50',
#   'close': '197.68',
#   'high': '201.47',
#   'low': '195.92',
#   'volume': '4648472'},
#  '2019-01-18': {'open': '200.38',
#   'close': '202.54',
#   'high': '203.00',
#   'low': '196.91',
#   'volume': '5650934'},
#  '2019-01-17': {'open': '195.95',
#   'close': '199.09',
#   'high': '199.80',
#   'low': '192.83',
#   'volume': '8176998'},
#  '2019-01-16': {'open': '187.00',
#   'close': '197.08',
#   'high': '198.15',
#   'low': '185.60',
#   'volume': '15194227'},
#  '2019-01-15': {'open': '178.32',
#   'close': '179.91',
#   'high': '179.99',
#   'low': '176.40',
#   'volume': '2911802'},
#  '2019-01-14': {'open': '174.52',
#   'close': '178.72',
#   'high': '179.54',
#   'low': '174.10',
#   'volume': '3361688'},
#  '2019-01-11': {'open': '175.10',
#   'close': '176.93',
#   'high': '177.04',
#   'low': '172.42',
#   'volume': '3183036'},
#  '2019-01-10': {'open': '175.66',
#   'close': '176.00',
#   'high': '178.07',
#   'low': '175.50',
#   'volume': '2808732'},
#  '2019-01-09': {'open': '176.10',
#   'close': '176.47',
#   'high': '177.69',
#   'low': '174.91',
#   'volume': '3321697'},
#  '2019-01-08': {'open': '177.78',
#   'close': '175.37',
#   'high': '178.10',
#   'low': '172.90',
#   'volume': '2692684'},
#  '2019-01-07': {'open': '175.23',
#   'close': '176.02',
#   'high': '177.83',
#   'low': '172.27',
#   'volume': '3152092'},
#  '2019-01-04': {'open': '172.99',
#   'close': '175.05',
#   'high': '176.00',
#   'low': '171.10',
#   'volume': '3788312'},
#  '2019-01-03': {'open': '170.66',
#   'close': '169.51',
#   'high': '171.77',
#   'low': '168.29',
#   'volume': '4060393'},
#  '2019-01-02': {'open': '164.33',
#   'close': '172.03',
#   'high': '172.25',
#   'low': '163.35',
#   'volume': '3999444'},
#  '2018-12-31': {'open': '163.78',
#   'close': '167.05',
#   'high': '167.12',
#   'low': '163.78',
#   'volume': '4550009'},
#  '2018-12-28': {'open': '165.64',
#   'close': '163.03',
#   'high': '165.95',
#   'low': '162.02',
#   'volume': '4110520'},
#  '2018-12-27': {'open': '160.12',
#   'close': '165.41',
#   'high': '165.41',
#   'low': '159.02',
#   'volume': '4972964'},
#  '2018-12-26': {'open': '157.00',
#   'close': '162.93',
#   'high': '163.11',
#   'low': '151.70',
#   'volume': '7054656'},
#  '2018-12-24': {'open': '159.00',
#   'close': '156.35',
#   'high': '160.00',
#   'low': '154.31',
#   'volume': '3783497'},
#  '2018-12-21': {'open': '168.25',
#   'close': '160.05',
#   'high': '169.63',
#   'low': '159.42',
#   'volume': '8960030'},
#  '2018-12-20': {'open': '168.39',
#   'close': '168.41',
#   'high': '171.65',
#   'low': '167.16',
#   'volume': '6488177'},
#  '2018-12-19': {'open': '171.59',
#   'close': '169.25',
#   'high': '174.85',
#   'low': '167.60',
#   'volume': '5316095'},
#  '2018-12-18': {'open': '169.78',
#   'close': '171.50',
#   'high': '173.02',
#   'low': '169.32',
#   'volume': '5150789'},
#  '2018-12-17': {'open': '169.40',
#   'close': '168.01',
#   'high': '171.43',
#   'low': '166.53',
#   'volume': '8395805'},
#  '2018-12-14': {'open': '174.34',
#   'close': '172.77',
#   'high': '176.26',
#   'low': '172.37',
#   'volume': '5078341'},
#  '2018-12-13': {'open': '177.83',
#   'close': '175.92',
#   'high': '178.69',
#   'low': '175.12',
#   'volume': '4008550'},
#  '2018-12-12': {'open': '178.50',
#   'close': '176.70',
#   'high': '180.00',
#   'low': '176.48',
#   'volume': '3677292'},
#  '2018-12-11': {'open': '182.15',
#   'close': '176.80',
#   'high': '184.43',
#   'low': '175.45',
#   'volume': '4713871'},
#  '2018-12-10': {'open': '178.60',
#   'close': '178.83',
#   'high': '179.84',
#   'low': '174.68',
#   'volume': '4528341'},
#  '2018-12-07': {'open': '183.85',
#   'close': '179.67',
#   'high': '186.25',
#   'low': '179.00',
#   'volume': '3921232'},
#  '2018-12-06': {'open': '181.33',
#   'close': '184.09',
#   'high': '184.88',
#   'low': '180.15',
#   'volume': '5275511'},
#  '2018-12-04': {'open': '190.69',
#   'close': '184.31',
#   'high': '191.11',
#   'low': '183.63',
#   'volume': '5797535'},
#  '2018-12-03': {'open': '194.00',
#   'close': '191.63',
#   'high': '195.66',
#   'low': '191.62',
#   'volume': '4015619'},
#  '2018-11-30': {'open': '190.57',
#   'close': '190.69',
#   'high': '191.45',
#   'low': '188.12',
#   'volume': '6219958'},
#  '2018-11-29': {'open': '196.02',
#   'close': '194.85',
#   'high': '197.45',
#   'low': '193.16',
#   'volume': '2666117'},
#  '2018-11-28': {'open': '194.84',
#   'close': '198.35',
#   'high': '198.45',
#   'low': '192.23',
#   'volume': '3762873'},
#  '2018-11-27': {'open': '193.40',
#   'close': '193.65',
#   'high': '194.62',
#   'low': '191.56',
#   'volume': '2345380'},
#  '2018-11-26': {'open': '191.17',
#   'close': '194.34',
#   'high': '195.23',
#   'low': '190.69',
#   'volume': '3143267'},
#  '2018-11-23': {'open': '191.61',
#   'close': '189.10',
#   'high': '191.87',
#   'low': '188.94',
#   'volume': '1862633'},
#  '2018-11-21': {'open': '192.09',
#   'close': '192.60',
#   'high': '195.24',
#   'low': '191.19',
#   'volume': '4111653'},
#  '2018-11-20': {'open': '195.10',
#   'close': '191.34',
#   'high': '195.89',
#   'low': '190.35',
#   'volume': '5513841'},
#  '2018-11-19': {'open': '201.83',
#   'close': '198.22',
#   'high': '202.30',
#   'low': '197.35',
#   'volume': '3419116'},
#  '2018-11-16': {'open': '202.93',
#   'close': '202.12',
#   'high': '204.74',
#   'low': '200.35',
#   'volume': '2829572'},
#  '2018-11-15': {'open': '201.80',
#   'close': '203.74',
#   'high': '204.50',
#   'low': '199.32',
#   'volume': '4260001'},
#  '2018-11-14': {'open': '206.24',
#   'close': '202.49',
#   'high': '207.34',
#   'low': '198.44',
#   'volume': '5742451'},
#  '2018-11-13': {'open': '204.40',
#   'close': '205.05',
#   'high': '209.59',
#   'low': '202.33',
#   'volume': '6984798'},
#  '2018-11-12': {'open': '222.00',
#   'close': '206.05',
#   'high': '222.31',
#   'low': '205.13',
#   'volume': '11019357'},
#  '2018-11-09': {'open': '231.69',
#   'close': '222.65',
#   'high': '231.69',
#   'low': '222.30',
#   'volume': '3721716'},
#  '2018-11-08': {'open': '231.00',
#   'close': '231.65',
#   'high': '234.06',
#   'low': '230.60',
#   'volume': '2404854'},
#  '2018-11-07': {'open': '230.05',
#   'close': '231.28',
#   'high': '232.80',
#   'low': '226.90',
#   'volume': '3514619'},
#  '2018-11-06': {'open': '228.19',
#   'close': '228.20',
#   'high': '229.52',
#   'low': '227.05',
#   'volume': '2275807'},
#  '2018-11-05': {'open': '228.32',
#   'close': '228.72',
#   'high': '231.10',
#   'low': '226.95',
#   'volume': '2565374'},
#  '2018-11-02': {'open': '230.00',
#   'close': '229.69',
#   'high': '231.69',
#   'low': '226.29',
#   'volume': '3698981'},
#  '2018-11-01': {'open': '225.76',
#   'close': '226.97',
#   'high': '228.88',
#   'low': '225.47',
#   'volume': '2557550'},
#  '2018-10-31': {'open': '221.89',
#   'close': '225.37',
#   'high': '229.00',
#   'low': '221.40',
#   'volume': '4369633'},
#  '2018-10-30': {'open': '215.99',
#   'close': '219.28',
#   'high': '220.35',
#   'low': '215.04',
#   'volume': '3897378'},
#  '2018-10-29': {'open': '214.15',
#   'close': '214.49',
#   'high': '218.21',
#   'low': '212.05',
#   'volume': '3278258'},
#  '2018-10-26': {'open': '210.73',
#   'close': '212.36',
#   'high': '214.80',
#   'low': '209.53',
#   'volume': '3558077'},
#  '2018-10-25': {'open': '211.27',
#   'close': '214.01',
#   'high': '215.69',
#   'low': '210.34',
#   'volume': '3179707'},
#  '2018-10-24': {'open': '218.14',
#   'close': '209.18',
#   'high': '218.93',
#   'low': '208.40',
#   'volume': '4152713'},
#  '2018-10-23': {'open': '216.59',
#   'close': '218.56',
#   'high': '219.52',
#   'low': '214.32',
#   'volume': '3318168'},
#  '2018-10-22': {'open': '226.93',
#   'close': '221.60',
#   'high': '228.87',
#   'low': '221.52',
#   'volume': '2736770'},
#  '2018-10-19': {'open': '225.26',
#   'close': '226.96',
#   'high': '228.30',
#   'low': '224.19',
#   'volume': '2759105'},
#  '2018-10-18': {'open': '227.50',
#   'close': '224.95',
#   'high': '228.73',
#   'low': '223.86',
#   'volume': '2995425'},
#  '2018-10-17': {'open': '220.53',
#   'close': '228.28',
#   'high': '228.90',
#   'low': '220.05',
#   'volume': '4953723'},
#  '2018-10-16': {'open': '219.35',
#   'close': '221.70',
#   'high': '222.00',
#   'low': '216.30',
#   'volume': '5924183'},
#  '2018-10-15': {'open': '214.45',
#   'close': '215.22',
#   'high': '217.14',
#   'low': '213.05',
#   'volume': '3333750'},
#  '2018-10-12': {'open': '217.00',
#   'close': '213.87',
#   'high': '217.98',
#   'low': '211.46',
#   'volume': '4161711'},
#  '2018-10-11': {'open': '214.20',
#   'close': '212.97',
#   'high': '216.03',
#   'low': '210.95',
#   'volume': '6217366'},
#  '2018-10-10': {'open': '223.24',
#   'close': '214.89',
#   'high': '223.64',
#   'low': '214.56',
#   'volume': '3955472'},
#  '2018-10-09': {'open': '224.99',
#   'close': '222.91',
#   'high': '225.12',
#   'low': '222.53',
#   'volume': '1863236'},
#  '2018-10-08': {'open': '224.26',
#   'close': '225.35',
#   'high': '226.92',
#   'low': '222.50',
#   'volume': '2523200'},
#  '2018-10-05': {'open': '228.00',
#   'close': '225.71',
#   'high': '228.41',
#   'low': '224.21',
#   'volume': '1722697'},
#  '2018-10-04': {'open': '229.26',
#   'close': '227.48',
#   'high': '231.40',
#   'low': '225.39',
#   'volume': '2903786'},
#  '2018-10-03': {'open': '227.75',
#   'close': '227.78',
#   'high': '229.77',
#   'low': '226.58',
#   'volume': '2574210'},
#  '2018-10-02': {'open': '225.28',
#   'close': '226.07',
#   'high': '226.33',
#   'low': '223.97',
#   'volume': '2272681'},
#  '2018-10-01': {'open': '226.22',
#   'close': '225.33',
#   'high': '227.59',
#   'low': '225.00',
#   'volume': '2451341'},
#  '2018-09-28': {'open': '225.75',
#   'close': '224.24',
#   'high': '227.40',
#   'low': '223.80',
#   'volume': '3097847'},
#  '2018-09-27': {'open': '228.77',
#   'close': '227.74',
#   'high': '229.85',
#   'low': '227.52',
#   'volume': '2451510'},
#  '2018-09-26': {'open': '232.96',
#   'close': '228.88',
#   'high': '233.00',
#   'low': '228.24',
#   'volume': '2372746'},
#  '2018-09-25': {'open': '234.64',
#   'close': '232.50',
#   'high': '234.64',
#   'low': '232.23',
#   'volume': '2003418'},
#  '2018-09-24': {'open': '234.74',
#   'close': '232.90',
#   'high': '235.74',
#   'low': '232.24',
#   'volume': '2056982'},
#  '2018-09-21': {'open': '238.06',
#   'close': '235.34',
#   'high': '238.52',
#   'low': '234.83',
#   'volume': '3760267'},
#  '2018-09-20': {'open': '237.00',
#   'close': '237.40',
#   'high': '238.51',
#   'low': '236.03',
#   'volume': '2502995'},
#  '2018-09-19': {'open': '229.90',
#   'close': '235.58',
#   'high': '236.28',
#   'low': '229.52',
#   'volume': '3716487'},
#  '2018-09-18': {'open': '228.35',
#   'close': '228.89',
#   'high': '229.40',
#   'low': '226.57',
#   'volume': '2498063'},
#  '2018-09-17': {'open': '229.40',
#   'close': '227.89',
#   'high': '230.16',
#   'low': '227.30',
#   'volume': '1918787'},
#  '2018-09-14': {'open': '229.08',
#   'close': '229.24',
#   'high': '230.55',
#   'low': '228.76',
#   'volume': '2228307'},
#  '2018-09-13': {'open': '229.50',
#   'close': '228.33',
#   'high': '229.85',
#   'low': '227.57',
#   'volume': '3003569'},
#  '2018-09-12': {'open': '230.91',
#   'close': '228.15',
#   'high': '231.99',
#   'low': '227.30',
#   'volume': '3577707'},
#  '2018-09-11': {'open': '230.67',
#   'close': '230.21',
#   'high': '231.65',
#   'low': '228.66',
#   'volume': '2719540'},
#  '2018-09-10': {'open': '235.01',
#   'close': '231.91',
#   'high': '235.50',
#   'low': '231.74',
#   'volume': '1948493'},
#  '2018-09-07': {'open': '235.05',
#   'close': '233.91',
#   'high': '235.64',
#   'low': '232.68',
#   'volume': '1952884'},
#  '2018-09-06': {'open': '237.00',
#   'close': '234.52',
#   'high': '238.63',
#   'low': '233.88',
#   'volume': '2651790'},
#  '2018-09-05': {'open': '237.01',
#   'close': '237.56',
#   'high': '239.45',
#   'low': '236.17',
#   'volume': '2092231'},
#  '2018-09-04': {'open': '237.76',
#   'close': '237.66',
#   'high': '238.12',
#   'low': '234.59',
#   'volume': '2083698'},
#  '2018-08-31': {'open': '238.94',
#   'close': '237.81',
#   'high': '239.35',
#   'low': '237.12',
#   'volume': '1965472'},
#  '2018-08-30': {'open': '240.80',
#   'close': '239.40',
#   'high': '241.12',
#   'low': '238.68',
#   'volume': '1963935'},
#  '2018-08-29': {'open': '242.05',
#   'close': '241.40',
#   'high': '242.79',
#   'low': '240.31',
#   'volume': '1911957'},
#  '2018-08-28': {'open': '243.06',
#   'close': '242.37',
#   'high': '245.08',
#   'low': '241.59',
#   'volume': '2951180'},
#  '2018-08-27': {'open': '236.99',
#   'close': '242.60',
#   'high': '243.65',
#   'low': '236.56',
#   'volume': '4106946'},
#  '2018-08-24': {'open': '237.36',
#   'close': '235.11',
#   'high': '237.80',
#   'low': '234.70',
#   'volume': '1948234'},
#  '2018-08-23': {'open': '239.05',
#   'close': '236.34',
#   'high': '239.28',
#   'low': '235.84',
#   'volume': '2065059'},
#  '2018-08-22': {'open': '237.89',
#   'close': '239.34',
#   'high': '239.67',
#   'low': '237.58',
#   'volume': '1870940'},
#  '2018-08-21': {'open': '235.29',
#   'close': '238.65',
#   'high': '239.53',
#   'low': '235.29',
#   'volume': '2437333'},
#  '2018-08-20': {'open': '234.13',
#   'close': '235.78',
#   'high': '235.98',
#   'low': '234.08',
#   'volume': '2604975'},
#  '2018-08-17': {'open': '232.51',
#   'close': '233.38',
#   'high': '233.72',
#   'low': '231.64',
#   'volume': '2107243'},
#  '2018-08-16': {'open': '230.67',
#   'close': '233.00',
#   'high': '233.29',
#   'low': '230.45',
#   'volume': '2438306'},
#  '2018-08-15': {'open': '229.35',
#   'close': '229.25',
#   'high': '231.54',
#   'low': '228.31',
#   'volume': '3218939'},
#  '2018-08-14': {'open': '227.35',
#   'close': '229.56',
#   'high': '230.37',
#   'low': '227.30',
#   'volume': '2359006'},
#  '2018-08-13': {'open': '229.49',
#   'close': '226.86',
#   'high': '229.89',
#   'low': '226.57',
#   'volume': '2663244'},
#  '2018-08-10': {'open': '230.97',
#   'close': '229.61',
#   'high': '231.46',
#   'low': '228.11',
#   'volume': '3863732'},
#  '2018-08-09': {'open': '236.35',
#   'close': '233.78',
#   'high': '236.85',
#   'low': '233.39',
#   'volume': '2952021'},
#  '2018-08-08': {'open': '238.12',
#   'close': '236.37',
#   'high': '239.16',
#   'low': '236.23',
#   'volume': '2522656'},
#  '2018-08-07': {'open': '237.25',
#   'close': '237.83',
#   'high': '239.46',
#   'low': '236.49',
#   'volume': '2399530'},
#  '2018-08-06': {'open': '234.14',
#   'close': '235.93',
#   'high': '236.98',
#   'low': '234.03',
#   'volume': '2259700'},
#  '2018-08-03': {'open': '234.44',
#   'close': '234.09',
#   'high': '235.52',
#   'low': '233.49',
#   'volume': '3053130'},
#  '2018-08-02': {'open': '233.93',
#   'close': '233.99',
#   'high': '235.21',
#   'low': '232.77',
#   'volume': '2580124'},
#  '2018-08-01': {'open': '238.50',
#   'close': '236.04',
#   'high': '239.40',
#   'low': '235.78',
#   'volume': '2510727'},
#  '2018-07-31': {'open': '239.50',
#   'close': '237.43',
#   'high': '239.50',
#   'low': '236.55',
#   'volume': '2504133'},
#  '2018-07-30': {'open': '238.00',
#   'close': '238.95',
#   'high': '239.73',
#   'low': '236.89',
#   'volume': '2454219'},
#  '2018-07-27': {'open': '237.96',
#   'close': '237.64',
#   'high': '238.80',
#   'low': '235.99',
#   'volume': '1999682'},
#  '2018-07-26': {'open': '237.00',
#   'close': '237.11',
#   'high': '238.34',
#   'low': '236.43',
#   'volume': '1885496'},
#  '2018-07-25': {'open': '235.01',
#   'close': '236.69',
#   'high': '236.85',
# ...
#   'high': '163.79',
#   'low': '161.68',
#   'volume': '1677707'},
#  '2016-09-27': {'open': '160.72',
#   'close': '162.89',
#   'high': '163.45',
#   'low': '159.82',
#   'volume': '2602486'},
#  '2016-09-26': {'open': '163.83',
#   'close': '161.48',
#   'high': '163.97',
#   'low': '161.00',
#   'volume': '2772196'},
#  '2016-09-23': {'open': '167.75',
#   'close': '165.13',
#   'high': '168.10',
#   'low': '165.05',
#   'volume': '3420548'},
#  '2016-09-22': {'open': '168.45',
#   'close': '168.02',
#   'high': '169.33',
#   'low': '167.70',
#   'volume': '2467664'},
#  '2016-09-21': {'open': '167.42',
#   'close': '167.03',
#   'high': '168.28',
#   'low': '165.93',
#   'volume': '2333587'},
#  '2016-09-20': {'open': '167.68',
#   'close': '166.47',
#   'high': '168.28',
#   'low': '166.39',
#   'volume': '1533159'},
#  '2016-09-19': {'open': '167.34',
#   'close': '166.21',
#   'high': '168.31',
#   'low': '165.68',
#   'volume': '2030742'},
#  '2016-09-16': {'open': '167.85',
#   'close': '166.00',
#   'high': '168.05',
#   'low': '165.61',
#   'volume': '4534927'},
#  '2016-09-15': {'open': '165.78',
#   'close': '168.08',
#   'high': '168.76',
#   'low': '165.76',
#   'volume': '1666130'},
#  '2016-09-14': {'open': '167.00',
#   'close': '166.16',
#   'high': '167.86',
#   'low': '165.59',
#   'volume': '1995701'},
#  '2016-09-13': {'open': '168.54',
#   'close': '167.00',
#   'high': '169.97',
#   'low': '166.38',
#   'volume': '2788205'},
#  '2016-09-12': {'open': '167.01',
#   'close': '171.06',
#   'high': '171.67',
#   'low': '166.23',
#   'volume': '2647877'},
#  '2016-09-09': {'open': '170.83',
#   'close': '168.57',
#   'high': '172.42',
#   'low': '168.51',
#   'volume': '3411550'},
#  '2016-09-08': {'open': '169.35',
#   'close': '171.66',
#   'high': '171.88',
#   'low': '168.71',
#   'volume': '3031625'},
#  '2016-09-07': {'open': '168.70',
#   'close': '169.67',
#   'high': '170.21',
#   'low': '168.65',
#   'volume': '1584347'},
#  '2016-09-06': {'open': '168.72',
#   'close': '169.33',
#   'high': '169.79',
#   'low': '167.47',
#   'volume': '2034847'},
#  '2016-09-02': {'open': '168.52',
#   'close': '169.18',
#   'high': '169.74',
#   'low': '167.90',
#   'volume': '1747492'},
#  '2016-09-01': {'open': '170.00',
#   'close': '168.51',
#   'high': '170.07',
#   'low': '166.66',
#   'volume': '2843174'},
#  '2016-08-31': {'open': '169.25',
#   'close': '169.46',
#   'high': '170.24',
#   'low': '167.47',
#   'volume': '3688089'},
#  '2016-08-30': {'open': '166.69',
#   'close': '169.37',
#   'high': '169.51',
#   'low': '166.44',
#   'volume': '2931934'},
#  '2016-08-29': {'open': '166.60',
#   'close': '166.87',
#   'high': '167.86',
#   'low': '166.15',
#   'volume': '2620945'},
#  '2016-08-26': {'open': '166.76',
#   'close': '165.97',
#   'high': '168.07',
#   'low': '165.36',
#   'volume': '2402214'},
#  '2016-08-25': {'open': '165.08',
#   'close': '165.90',
#   'high': '166.04',
#   'low': '164.61',
#   'volume': '1441352'},
#  '2016-08-24': {'open': '165.78',
#   'close': '165.30',
#   'high': '166.70',
#   'low': '164.85',
#   'volume': '2035311'},
#  '2016-08-23': {'open': '167.00',
#   'close': '166.08',
#   'high': '167.85',
#   'low': '165.98',
#   'volume': '1965148'},
#  '2016-08-22': {'open': '166.00',
#   'close': '166.26',
#   'high': '166.91',
#   'low': '164.89',
#   'volume': '1448111'},
#  '2016-08-19': {'open': '165.36',
#   'close': '166.23',
#   'high': '166.90',
#   'low': '164.50',
#   'volume': '1840848'},
#  '2016-08-18': {'open': '165.34',
#   'close': '166.06',
#   'high': '166.56',
#   'low': '164.63',
#   'volume': '1750624'},
#  '2016-08-17': {'open': '165.94',
#   'close': '165.67',
#   'high': '166.32',
#   'low': '164.74',
#   'volume': '2061908'},
#  '2016-08-16': {'open': '164.99',
#   'close': '165.65',
#   'high': '166.76',
#   'low': '164.72',
#   'volume': '2523774'},
#  '2016-08-15': {'open': '163.87',
#   'close': '165.55',
#   'high': '165.84',
#   'low': '163.80',
#   'volume': '2221188'},
#  '2016-08-12': {'open': '162.67',
#   'close': '163.25',
#   'high': '163.37',
#   'low': '162.07',
#   'volume': '1440839'},
#  '2016-08-11': {'open': '162.20',
#   'close': '163.86',
#   'high': '164.25',
#   'low': '161.93',
#   'volume': '1827689'},
#  '2016-08-10': {'open': '163.45',
#   'close': '162.19',
#   'high': '163.60',
#   'low': '162.01',
#   'volume': '1656141'},
#  '2016-08-09': {'open': '162.50',
#   'close': '163.44',
#   'high': '164.58',
#   'low': '162.50',
#   'volume': '1956938'},
#  '2016-08-08': {'open': '162.10',
#   'close': '162.83',
#   'high': '163.98',
#   'low': '162.01',
#   'volume': '2266612'},
#  '2016-08-05': {'open': '159.75',
#   'close': '162.09',
#   'high': '162.13',
#   'low': '159.20',
#   'volume': '2676064'},
#  '2016-08-04': {'open': '158.22',
#   'close': '158.05',
#   'high': '158.90',
#   'low': '157.41',
#   'volume': '2005699'},
#  '2016-08-03': {'open': '156.45',
#   'close': '158.34',
#   'high': '158.95',
#   'low': '156.18',
#   'volume': '2284670'},
#  '2016-08-02': {'open': '157.65',
#   'close': '156.06',
#   'high': '158.46',
#   'low': '155.37',
#   'volume': '3182583'},
#  '2016-08-01': {'open': '158.81',
#   'close': '158.18',
#   'high': '159.92',
#   'low': '157.93',
#   'volume': '2315900'},
#  '2016-07-29': {'open': '159.51',
#   'close': '158.81',
#   'high': '160.19',
#   'low': '158.65',
#   'volume': '2388134'},
#  '2016-07-28': {'open': '160.18',
#   'close': '160.53',
#   'high': '160.96',
#   'low': '158.84',
#   'volume': '2047424'},
#  '2016-07-27': {'open': '161.20',
#   'close': '160.99',
#   'high': '162.17',
#   'low': '160.41',
#   'volume': '2317561'},
#  '2016-07-26': {'open': '160.68',
#   'close': '161.16',
#   'high': '161.50',
#   'low': '159.42',
#   'volume': '2147846'},
#  '2016-07-25': {'open': '159.64',
#   'close': '160.51',
#   'high': '161.33',
#   'low': '159.61',
#   'volume': '1956099'},
#  '2016-07-22': {'open': '160.29',
#   'close': '160.41',
#   'high': '160.73',
#   'low': '159.86',
#   'volume': '1811695'},
#  '2016-07-21': {'open': '161.71',
#   'close': '160.05',
#   'high': '161.90',
#   'low': '159.77',
#   'volume': '2997187'},
#  '2016-07-20': {'open': '162.55',
#   'close': '161.77',
#   'high': '162.89',
#   'low': '159.22',
#   'volume': '3547824'},
#  '2016-07-19': {'open': '162.02',
#   'close': '161.41',
#   'high': '164.08',
#   'low': '160.73',
#   'volume': '5399685'},
#  '2016-07-18': {'open': '162.36',
#   'close': '163.33',
#   'high': '164.09',
#   'low': '162.01',
#   'volume': '4731357'},
#  '2016-07-15': {'open': '162.86',
#   'close': '161.64',
#   'high': '163.14',
#   'low': '160.70',
#   'volume': '3076630'},
#  '2016-07-14': {'open': '160.29',
#   'close': '162.54',
#   'high': '163.24',
#   'low': '160.01',
#   'volume': '5087024'},
#  '2016-07-13': {'open': '157.00',
#   'close': '157.92',
#   'high': '158.27',
#   'low': '156.15',
#   'volume': '4275685'},
#  '2016-07-12': {'open': '154.00',
#   'close': '156.92',
#   'high': '157.25',
#   'low': '153.92',
#   'volume': '5119314'},
#  '2016-07-11': {'open': '151.49',
#   'close': '152.19',
#   'high': '152.98',
#   'low': '151.38',
#   'volume': '3042033'},
#  '2016-07-08': {'open': '149.36',
#   'close': '150.38',
#   'high': '150.92',
#   'low': '148.31',
#   'volume': '3281205'},
#  '2016-07-07': {'open': '146.00',
#   'close': '147.00',
#   'high': '148.09',
#   'low': '145.36',
#   'volume': '2578042'},
#  '2016-07-06': {'open': '142.94',
#   'close': '145.58',
#   'high': '145.94',
#   'low': '142.62',
#   'volume': '2941459'},
#  '2016-07-05': {'open': '146.72',
#   'close': '144.45',
#   'high': '146.94',
#   'low': '143.33',
#   'volume': '3942834'},
#  '2016-07-01': {'open': '148.49',
#   'close': '148.25',
#   'high': '150.70',
#   'low': '148.07',
#   'volume': '3096778'},
#  '2016-06-30': {'open': '146.67',
#   'close': '148.58',
#   'high': '148.88',
#   'low': '145.37',
#   'volume': '4528474'},
#  '2016-06-29': {'open': '143.60',
#   'close': '145.50',
#   'high': '145.55',
#   'low': '142.93',
#   'volume': '3803312'},
#  '2016-06-28': {'open': '142.21',
#   'close': '142.41',
#   'high': '142.62',
#   'low': '139.82',
#   'volume': '5040725'},
#  '2016-06-27': {'open': '140.07',
#   'close': '139.51',
#   'high': '141.23',
#   'low': '138.20',
#   'volume': '7395704'},
#  '2016-06-24': {'open': '143.03',
#   'close': '141.86',
#   'high': '146.42',
#   'low': '140.92',
#   'volume': '9441520'},
#  '2016-06-23': {'open': '150.56',
#   'close': '152.66',
#   'high': '152.80',
#   'low': '150.14',
#   'volume': '2938037'},
#  '2016-06-22': {'open': '148.01',
#   'close': '148.14',
#   'high': '150.12',
#   'low': '147.99',
#   'volume': '2485406'},
#  '2016-06-21': {'open': '148.50',
#   'close': '148.35',
#   'high': '148.83',
#   'low': '147.12',
#   'volume': '2424723'},
#  '2016-06-20': {'open': '148.50',
#   'close': '147.75',
#   'high': '150.50',
#   'low': '147.58',
#   'volume': '3337283'},
#  '2016-06-17': {'open': '146.63',
#   'close': '145.64',
#   'high': '148.23',
#   'low': '145.46',
#   'volume': '4296342'},
#  '2016-06-16': {'open': '145.00',
#   'close': '146.63',
#   'high': '146.99',
#   'low': '143.53',
#   'volume': '3495834'},
#  '2016-06-15': {'open': '147.16',
#   'close': '146.16',
#   'high': '148.70',
#   'low': '145.90',
#   'volume': '2980272'},
#  '2016-06-14': {'open': '148.22',
#   'close': '146.19',
#   'high': '149.05',
#   'low': '145.45',
#   'volume': '5069610'},
#  '2016-06-13': {'open': '149.00',
#   'close': '148.63',
#   'high': '151.32',
#   'low': '148.59',
#   'volume': '3385673'},
#  '2016-06-10': {'open': '151.35',
#   'close': '149.89',
#   'high': '151.66',
#   'low': '149.57',
#   'volume': '4335725'},
#  '2016-06-09': {'open': '153.79',
#   'close': '153.17',
#   'high': '154.29',
#   'low': '152.46',
#   'volume': '2712012'},
#  '2016-06-08': {'open': '155.20',
#   'close': '154.64',
#   'high': '156.58',
#   'low': '153.91',
#   'volume': '2426771'},
#  '2016-06-07': {'open': '157.20',
#   'close': '155.17',
#   'high': '157.47',
#   'low': '155.17',
#   'volume': '2488541'},
#  '2016-06-06': {'open': '156.25',
#   'close': '157.06',
#   'high': '157.91',
#   'low': '155.77',
#   'volume': '2540081'},
#  '2016-06-03': {'open': '155.86',
#   'close': '155.67',
#   'high': '156.54',
#   'low': '153.86',
#   'volume': '4328603'},
#  '2016-06-02': {'open': '160.14',
#   'close': '159.28',
#   'high': '160.33',
#   'low': '158.46',
#   'volume': '2257027'},
#  '2016-06-01': {'open': '157.90',
#   'close': '159.97',
#   'high': '160.55',
#   'low': '156.00',
#   'volume': '2581557'},
#  '2016-05-31': {'open': '160.40',
#   'close': '159.48',
#   'high': '161.65',
#   'low': '158.55',
#   'volume': '2915646'},
#  '2016-05-27': {'open': '158.70',
#   'close': '159.53',
#   'high': '160.40',
#   'low': '158.32',
#   'volume': '2157794'},
#  '2016-05-26': {'open': '161.16',
#   'close': '159.22',
#   'high': '161.33',
#   'low': '159.17',
#   'volume': '2576024'},
#  '2016-05-25': {'open': '158.06',
#   'close': '161.25',
#   'high': '162.29',
#   'low': '158.03',
#   'volume': '3259910'},
#  '2016-05-24': {'open': '156.67',
#   'close': '157.59',
#   'high': '158.55',
#   'low': '156.44',
#   'volume': '3039343'},
#  '2016-05-23': {'open': '154.44',
#   'close': '155.45',
#   'high': '156.09',
#   'low': '153.74',
#   'volume': '2767609'},
#  '2016-05-20': {'open': '155.76',
#   'close': '154.51',
#   'high': '156.41',
#   'low': '153.92',
#   'volume': '3247841'},
#  '2016-05-19': {'open': '158.68',
#   'close': '154.70',
#   'high': '159.95',
#   'low': '154.52',
#   'volume': '4711549'},
#  '2016-05-18': {'open': '154.81',
#   'close': '159.94',
#   'high': '160.00',
#   'low': '154.65',
#   'volume': '3652990'},
#  '2016-05-17': {'open': '154.74',
#   'close': '154.65',
#   'high': '157.11',
#   'low': '153.77',
#   'volume': '2701449'},
#  '2016-05-16': {'open': '155.34',
#   'close': '155.38',
#   'high': '156.90',
#   'low': '154.60',
#   'volume': '3177707'},
#  '2016-05-13': {'open': '157.88',
#   'close': '155.34',
#   'high': '159.72',
#   'low': '155.26',
#   'volume': '2549908'},
#  '2016-05-12': {'open': '160.32',
#   'close': '158.07',
#   'high': '161.47',
#   'low': '157.31',
#   'volume': '2447686'},
#  '2016-05-11': {'open': '161.36',
#   'close': '159.42',
#   'high': '162.53',
#   'low': '159.28',
#   'volume': '2095968'},
#  '2016-05-10': {'open': '158.67',
#   'close': '161.42',
#   'high': '161.50',
#   'low': '158.39',
#   'volume': '2379590'},
#  '2016-05-09': {'open': '158.20',
#   'close': '157.51',
#   'high': '159.85',
#   'low': '156.79',
#   'volume': '2097854'},
#  '2016-05-06': {'open': '158.19',
#   'close': '158.85',
#   'high': '160.17',
#   'low': '157.01',
#   'volume': '2306376'},
#  '2016-05-05': {'open': '160.78',
#   'close': '159.53',
#   'high': '160.82',
#   'low': '158.50',
#   'volume': '2366823'},
#  '2016-05-04': {'open': '161.20',
#   'close': '160.07',
#   'high': '162.60',
#   'low': '159.09',
#   'volume': '3203833'},
#  '2016-05-03': {'open': '163.66',
#   'close': '163.14',
#   'high': '164.11',
#   'low': '161.37',
#   'volume': '2776969'},
#  '2016-05-02': {'open': '165.08',
#   'close': '166.18',
#   'high': '167.19',
#   'low': '163.99',
#   'volume': '1998361'},
#  '2016-04-29': {'open': '163.80',
#   'close': '164.11',
#   'high': '164.68',
#   'low': '162.56',
#   'volume': '2890849'},
#  '2016-04-28': {'open': '165.35',
#   'close': '164.29',
#   'high': '167.32',
#   'low': '164.01',
#   'volume': '2527327'},
#  '2016-04-27': {'open': '165.83',
#   'close': '166.92',
#   'high': '168.66',
#   'low': '164.93',
#   'volume': '3323584'},
#  '2016-04-26': {'open': '165.38',
#   'close': '165.84',
#   'high': '166.00',
#   'low': '164.22',
#   'volume': '2250895'},
#  '2016-04-25': {'open': '166.00',
#   'close': '165.09',
#   'high': '167.39',
#   'low': '164.06',
#   'volume': '2472984'},
#  '2016-04-22': {'open': '165.79',
#   'close': '166.75',
#   'high': '167.49',
#   'low': '165.66',
#   'volume': '2680171'},
#  '2016-04-21': {'open': '166.55',
#   'close': '165.32',
#   'high': '168.90',
#   'low': '165.01',
#   'volume': '4164434'},
#  '2016-04-20': {'open': '162.00',
#   'close': '166.98',
#   'high': '167.45',
#   'low': '161.94',
#   'volume': '4800787'},
#  '2016-04-19': {'open': '157.75',
#   'close': '162.65',
#   'high': '163.70',
#   'low': '157.00',
#   'volume': '5830511'},
#  '2016-04-18': {'open': '157.61',
#   'close': '159.02',
#   'high': '160.00',
#   'low': '157.15',
#   'volume': '3030489'},
#  '2016-04-15': {'open': '161.23',
#   'close': '158.52',
#   'high': '161.78',
#   'low': '158.20',
#   'volume': '3467826'},
#  '2016-04-14': {'open': '159.53',
#   'close': '160.91',
#   'high': '162.27',
#   'low': '159.15',
#   'volume': '3067064'},
#  '2016-04-13': {'open': '156.53',
#   'close': '159.85',
#   'high': '159.99',
#   'low': '156.38',
#   'volume': '5149910'},
#  '2016-04-12': {'open': '152.67',
#   'close': '154.31',
#   'high': '155.09',
#   'low': '151.30',
#   'volume': '2732861'},
#  '2016-04-11': {'open': '151.18',
#   'close': '152.20',
#   'high': '153.90',
#   'low': '150.41',
#   'volume': '3464286'},
#  '2016-04-08': {'open': '152.07',
#   'close': '150.28',
#   'high': '152.87',
#   'low': '150.01',
#   'volume': '3122198'},
#  '2016-04-07': {'open': '153.65',
#   'close': '150.41',
#   'high': '154.03',
#   'low': '149.37',
#   'volume': '4786630'},
#  '2016-04-06': {'open': '155.26',
#   'close': '155.19',
#   'high': '156.27',
#   'low': '153.92',
#   'volume': '2927106'},
#  '2016-04-05': {'open': '156.44',
#   'close': '155.35',
#   'high': '156.53',
#   'low': '154.55',
#   'volume': '2822612'},
#  '2016-04-04': {'open': '159.97',
#   'close': '157.77',
#   'high': '160.00',
#   'low': '157.39',
#   'volume': '2478545'},
#  '2016-04-01': {'open': '156.46',
#   'close': '159.82',
#   'high': '160.01',
#   'low': '155.09',
#   'volume': '3372048'},
#  '2016-03-31': {'open': '156.18',
#   'close': '156.98',
#   'high': '157.48',
#   'low': '156.06',
#   'volume': '2927046'},
#  '2016-03-30': {'open': '156.13',
#   'close': '156.50',
#   'high': '158.02',
#   'low': '154.89',
#   'volume': '3130594'},
#  '2016-03-29': {'open': '152.87',
#   'close': '155.03',
#   'high': '155.35',
#   'low': '151.50',
#   'volume': '2919290'},
#  '2016-03-28': {'open': '153.14',
#   'close': '153.84',
#   'high': '154.64',
#   'low': '152.38',
#   'volume': '2308573'},
#  '2016-03-24': {'open': '152.40',
#   'close': '153.00',
#   'high': '153.04',
#   'low': '150.13',
#   'volume': '3693399'},
#  '2016-03-23': {'open': '154.25',
#   'close': '154.08',
#   'high': '155.55',
#   'low': '153.59',
#   'volume': '3633242'},
#  '2016-03-22': {'open': '155.50',
#   'close': '154.20',
#   'high': '155.59',
#   'low': '153.36',
#   'volume': '3521394'},
#  '2016-03-21': {'open': '157.24',
#   'close': '156.29',
#   'high': '158.90',
#   'low': '155.75',
#   'volume': '4410029'},
#  '2016-03-18': {'open': '153.91',
#   'close': '157.60',
#   'high': '158.18',
#   'low': '153.87',
#   'volume': '7413169'},
#  '2016-03-17': {'open': '150.39',
#   'close': '152.91',
#   'high': '153.98',
#   'low': '148.75',
#   'volume': '2085484'},
#  ...}

# %%
df = df.astype('float')

# %%
df.pct_change()
# Out:
#                 open     close      high       low    volume
# 2020-03-06       NaN       NaN       NaN       NaN       NaN
# 2020-03-05  0.055853  0.030801  0.036526  0.040522 -0.181431
# 2020-03-04  0.022401  0.050053  0.026785  0.029195 -0.152071
# 2020-03-03  0.015352 -0.025438  0.013737 -0.002861  0.612680
# 2020-03-02 -0.036316  0.029691 -0.010246 -0.022215 -0.068991
# ...              ...       ...       ...       ...       ...
# 1999-05-10  0.048286 -0.001841  0.033319  0.010791  0.501165
# 1999-05-07 -0.074135  0.059433  0.016190 -0.049822  0.974024
# 1999-05-06  0.000883 -0.090374 -0.071094  0.004644 -0.499665
# 1999-05-05  0.023971  0.017515  0.003603 -0.011184  2.040906
# 1999-05-04  0.010771  0.018082  0.109436  0.055648  2.392750
#
# [5246 rows x 5 columns]
